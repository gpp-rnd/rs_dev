# %% [markdown]
# # Build Target Model
#
# Here we expand our on target rules to include information about the target site.
# We consider four feature classes when building this model:
#
# 1. Position within a gene, including sgRNA oriention
# 2. Protein Domain information: whether a guide targets within an annotated protein domain
# 3. Sequence conservation
# 4. Amino acid idenity and physiochemical properties

# %%
import pandas as pd
from sklearn.model_selection import StratifiedGroupKFold, train_test_split
from sklearn.base import clone
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score
import joblib
import seaborn as sns
from lightgbm import LGBMRegressor
import matplotlib.pyplot as plt
from scipy import stats
import optuna
from joblib import Parallel, delayed
from datetime import datetime
import numpy as np
import gpplot

import target_featurization as ft
from core import (get_predictive_performance,
                  setup_plots,
                  plot_spearman_heatmap,
                  plot_model_performance,
                  get_tidy_cv_df,
                  get_feature_df)
from datasets import dataset_list, get_sg_groups_df

# %%
setup_plots()

# %%
def get_fold_predictions(fold, fold_df, model_name, features,
                         aa_seq_df,
                         protein_domain_df,
                         conservation_df,
                         base_model=Pipeline([('imputer', SimpleImputer(strategy='median')),
                                              ('regressor', LGBMRegressor(random_state=7, n_jobs=8))]),
                         aa_width=16, aa_features=None,
                         cons_small_width=4, cons_large_width=32):
    """Get predictions for a given fold

    :param fold: int
    :param fold_df: DataFrame
    :param model_name: str
    :param features: list
    :param aa_seq_df: DataFrame, fed into target featurization
    :param protein_domain_df: DataFrame, fed into target featurization
    :param conservation_df: DataFrame, fed into target featurization
    :param base_model: Pipeline(Imputer, Regressor)
    :param aa_width: int
    :param aa_features: list or None, see featurize_aa_seqs for options. Will default to best options if None
    :param cons_small_width: int
    :param cons_large_width: int
    :return: DataFrame, test predictions
    """
    train_df = fold_df.query('train == True').reset_index(drop=True)
    train_feature_df, train_feature_cols = ft.build_target_feature_df(train_df,
                                                                      features=features,
                                                                      aa_seq_df=aa_seq_df, aa_width=aa_width,
                                                                      aa_features=aa_features,
                                                                      protein_domain_df=protein_domain_df,
                                                                      conservation_df=conservation_df,
                                                                      cons_small_width=cons_small_width,
                                                                      cons_large_width=cons_large_width)
    X_train = train_feature_df[train_feature_cols]
    y_train = train_df['Residual Activity']
    test_df = fold_df.query('train == False').reset_index(drop=True)
    test_feature_df, test_feature_cols = ft.build_target_feature_df(test_df,
                                                                    features=features,
                                                                    aa_seq_df=aa_seq_df, aa_width=aa_width,
                                                                    aa_features=aa_features,
                                                                    protein_domain_df=protein_domain_df,
                                                                    conservation_df=conservation_df,
                                                                    cons_small_width=cons_small_width,
                                                                    cons_large_width=cons_large_width)
    X_test = test_feature_df[test_feature_cols]
    model = clone(base_model)
    model.fit(X_train,  y_train)
    dataset_test_predictions = test_df.copy()
    dataset_test_predictions['prediction'] = model.predict(X_test)
    dataset_test_predictions['model_name'] = model_name
    dataset_test_predictions['fold'] = fold
    return dataset_test_predictions


def lgbm_training_iteration(fold_df, train_index, features,
                            aa_seq_df, protein_domain_df,
                            conservation_df,
                            test_index, base_model):
    """Train lgbm model for optuna iterations

    :param fold_df: DataFrame
    :param train_index: list-like
    :param features: list, features to us
    :param aa_seq_df: DataFrame
    :param protein_domain_df: DataFrame
    :param conservation_df: DataFrame
    :param test_index: list-like
    :param base_model: Pipeline (Imputer, Regressor
    :return: r^2
    """
    train_df = fold_df.iloc[train_index,:].reset_index(drop=True)
    train_feature_df, train_feature_cols = ft.build_target_feature_df(train_df,
                                                                      features=features,
                                                                      aa_seq_df=aa_seq_df,
                                                                      protein_domain_df=protein_domain_df,
                                                                      conservation_df=conservation_df)
    X_train_val = train_feature_df[train_feature_cols] # train and validation data
    y_train_val = train_df['Residual Activity']
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val,
                                                      test_size=0.1, random_state=7)
    model = clone(base_model)
    model.fit(X_train, y_train,
              regressor__early_stopping_rounds=20,
              regressor__eval_set=[(X_val, y_val)],
              regressor__verbose=False)
    test_df = fold_df.iloc[test_index,:].reset_index(drop=True)
    test_feature_df, test_feature_cols = ft.build_target_feature_df(test_df,
                                                                    features=features,
                                                                    aa_seq_df=aa_seq_df,
                                                                    protein_domain_df=protein_domain_df,
                                                                    conservation_df=conservation_df)
    X_test = test_feature_df[test_feature_cols]
    test_predictions = test_df.copy()
    test_predictions['prediction'] = model.predict(X_test)
    r2 = r2_score(test_predictions['Residual Activity'], test_predictions['prediction'])
    return r2


def get_lgbm_objective(fold_df, features, aa_seq_df, protein_domain_df, conservation_df):
    """Get objective function for training a lgbm model

    :param fold_df: DataFrame
    :param features: list
    :param aa_seq_df: DataFrame
    :param protein_domain_df: DataFrame
    :param conservation_df: DataFrame
    :return: obejctive function
    """
    def objective(trial):
        """For training set, get optimal hyperparameters for Pipeline

        :param trial: optuna.trial
        :return: int, pearson correlation with held out test data
        """
        sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=7)
        num_leaves = trial.suggest_int('num_leaves', 8, 256)
        min_child_samples = trial.suggest_int('min_child_samples', 8, 256)
        model = Pipeline([('imputer', SimpleImputer(strategy='median')),
                          ('regressor',
                           LGBMRegressor(random_state=7, n_jobs=1, learning_rate=0.01, n_estimators=5000,
                                         num_leaves=num_leaves,
                                         min_child_samples=min_child_samples))])
        performance = Parallel(n_jobs=5)(delayed(lgbm_training_iteration)
                                         (fold_df, train_index, features,
                                          aa_seq_df, protein_domain_df,
                                          conservation_df,
                                          test_index, model) for
                                         train_index, test_index in
                                         sgkf.split(fold_df, fold_df.dataset, fold_df.target))
        avg_performance = np.mean(performance)
        return avg_performance
    return objective

# %% [markdown]
# ## Reading Data

# %%
train_data_names = pd.read_csv('../data/processed/train_data_names.csv').name.to_list()
protein_domains = pd.read_csv('../data/interim/protein_domains.csv')
aa_seqs = pd.read_csv('../data/interim/aa_seqs.csv')
seq_model = joblib.load('../models/RuleSet3.pkl')

# %%
id_cols = ['sgRNA Context Sequence', 'Target Cut Length', 'Target Transcript', 'Orientation']

# %% [markdown]
# ## Loading Datasets

# %%
train_data_list = list()
for ds in dataset_list:
    if (ds.name in train_data_names) and ds.endogenous:
        train_data_list.append(ds)

sg_groups_df = get_sg_groups_df(train_data_list)
sg_groups_df = ft.add_target_columns(sg_groups_df)
# Out:
# Context sequences with multiple targets: 0

# %% [markdown]
# ## Protein Domain Features

# %%
domain_model_matrix = ft.get_protein_domain_features(sg_groups_df, protein_domains, sources=None,
                                                     id_cols=id_cols)

# %%
g = sns.clustermap(domain_model_matrix.set_index(id_cols),
                   cmap='binary', cbar_pos=None, metric='hamming',
                   yticklabels=False, figsize=(5, 7))
g.ax_heatmap.set_ylabel("")
gpplot.savefig('../figures/domain_clustermap.pdf')
# Out:
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/seaborn/matrix.py:649: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.

# %%
long_domain_model_matrix = domain_model_matrix.melt(id_vars=id_cols,
                                                    var_name='source',
                                                    value_name='present')
long_domain_model_matrix = long_domain_model_matrix[long_domain_model_matrix['present'] == 1]
(long_domain_model_matrix[['Target Transcript', 'source']].value_counts()
 .reset_index()['source'].value_counts())
# Out:
# PANTHER             122
# Pfam                118
# Gene3D              115
# SuperFamily         108
# Seg                  92
# Smart                76
# Prosite_profiles     69
# Prosite_patterns     67
# MobiDBLite           65
# PRINTS               35
# ncoils               31
# PIRSF                28
# HAMAP                16
# TIGRfam              14
# TMHMM                10
# SignalP               8
# Name: source, dtype: int64

# %% [markdown]
# ## Conservation of Protein Domains
#
# We'll merge conservation scores with the protein domain matrix to understand how protein domains are conserved

# %%
transcript_bases = list(sg_groups_df['Transcript Base']
                        .unique())
conservation_df = (pd.read_parquet('../data/interim/conservation.parquet',
                                   filters=[[('Transcript Base', 'in', transcript_bases)]])
                   .reset_index(drop=True))

# %%
conservation_aa_i = conservation_df.copy()
conservation_aa_i['aa_i'] = (conservation_aa_i['target position'] - 1) // 3 + 1
conservation_aa_i['loc_id'] = conservation_aa_i['Transcript Base'] + conservation_aa_i['aa_i'].astype(str)
# Filter sifts
conservation_domains = (conservation_aa_i.merge(protein_domains[protein_domains['type'] != 'sifts'],
                                                how='inner',
                                                on='Transcript Base'))
conservation_domains = (conservation_domains[conservation_domains['aa_i']
                        .between(conservation_domains['start'], conservation_domains['end'])])
conservation_non_domains = conservation_aa_i[~conservation_aa_i['loc_id'].isin(conservation_domains['loc_id'])]
conservation_cat = (pd.concat([conservation_domains, conservation_non_domains])
                    .reset_index(drop=True))
conservation_cat['type'] = conservation_cat['type'].fillna('None')
conservation_cat_summary = (conservation_cat.groupby(['type', 'genome'])
                            .agg(median_conservation = ('conservation', 'median'),
                                 n_obs = ('conservation', 'count'))
                            .reset_index()
                            .sort_values('median_conservation'))
conservation_cat_summary['name'] = (conservation_cat_summary['type'] +
                                    '(n=' +
                                    conservation_cat_summary['n_obs'].astype(str) +
                                    ')')
hg_conservation_cat_summary = conservation_cat_summary[conservation_cat_summary['genome'].str.contains('hg')]
mm_conservation_cat_summary = conservation_cat_summary[conservation_cat_summary['genome'].str.contains('mm')]
hg_conservation_cat = conservation_cat.merge(hg_conservation_cat_summary, how='inner')
hg_conservation_cat['name'] = pd.Categorical(hg_conservation_cat['name'],
                                             categories=hg_conservation_cat_summary['name'])
mm_conservation_cat = conservation_cat.merge(mm_conservation_cat_summary, how='inner')
mm_conservation_cat['name'] = pd.Categorical(mm_conservation_cat['name'],
                                             categories=mm_conservation_cat_summary['name'])

# %%
sns.catplot(data=hg_conservation_cat, y='name', x='conservation', kind='box', height=4.5)
plt.title('Human Training Data\nDomain Conservation')
gpplot.savefig('../figures/human_domain_conservation.pdf')

# %%
sns.catplot(data=mm_conservation_cat, y='name', x='conservation', kind='box', height=4.5)
plt.title('Mouse Training Data\nDomain Conservation')
# Out:
# Text(0.5, 1.0, 'Mouse Training Data\nDomain Conservation')

# %% [markdown]
# ## Calculating Residuals

# %%
sg_df_residuals = sg_groups_df.copy()
seq_X = get_feature_df(sg_df_residuals)
sg_df_residuals['Rule Set 3'] = seq_model.predict(seq_X)
(sg_df_residuals.groupby('dataset')
 .apply(lambda df: stats.pearsonr(df['Rule Set 3'], df['sgRNA Activity'])))
# Out:
# dataset
# Doench2014_human     (0.7808375117208222, 4.324227242326856e-205)
# Doench2014_mouse     (0.7404292413640493, 1.379605215185353e-203)
# Doench2016                              (0.6937302010352973, 0.0)
# Munoz2016                               (0.7588083762083931, 0.0)
# Wang2014            (0.7817756947398344, 1.9046619919131385e-211)
# dtype: object

# %%
sg_df_residuals['Residual Activity'] = sg_df_residuals['sgRNA Activity'] - sg_df_residuals['Rule Set 3']
sns.displot(data=sg_df_residuals, x='Residual Activity', hue='dataset',
            kind='kde', common_norm=False, height=2.2)
gpplot.savefig('../figures/model_residuals.pdf')

# %% [markdown]
# ## Cross Validation iterator
#
# We'll use [StratifiedGroupKFold](https://scikit-learn.org/dev/modules/generated/sklearn.model_selection.StratifiedGroupKFold.html#sklearn.model_selection.StratifiedGroupKFold)
#
# Every dataset appears as both a training and testing
# dataset in every fold, except Doench2014_human Doench2014_mouse, which have fewer than 5 genes

# %%
tidy_cv_df = get_tidy_cv_df(sg_df_residuals, random_state=1)
cv_train_data_counts = (tidy_cv_df[['cv', 'train', 'dataset']].value_counts()
                        .reset_index(name='n'))
(cv_train_data_counts[['cv', 'dataset']]
 .value_counts()
 .reset_index(name='n')
 .sort_values(['n', 'cv', 'dataset']))
# Out:
#     cv           dataset  n
# 23   2  Doench2014_human  1
# 22   2  Doench2014_mouse  1
# 24   4  Doench2014_human  1
# 0    0  Doench2014_human  2
# 1    0  Doench2014_mouse  2
# 20   0        Doench2016  2
# 19   0         Munoz2016  2
# 18   0          Wang2014  2
# 17   1  Doench2014_human  2
# 16   1  Doench2014_mouse  2
# 15   1        Doench2016  2
# 14   1         Munoz2016  2
# 13   1          Wang2014  2
# 12   2        Doench2016  2
# 11   2         Munoz2016  2
# 10   2          Wang2014  2
# 9    3  Doench2014_human  2
# 8    3  Doench2014_mouse  2
# 7    3        Doench2016  2
# 6    3         Munoz2016  2
# 5    3          Wang2014  2
# 4    4  Doench2014_mouse  2
# 3    4        Doench2016  2
# 2    4         Munoz2016  2
# 21   4          Wang2014  2

# %% [markdown]
# - Training sizes vary from 5,258 - 4,253 sgRNAs
# - Testing sizes vary from 1,469 - 464 sgRNAs

# %%
(tidy_cv_df[['cv','train']].value_counts()
 .reset_index(name='n')
 .sort_values(['cv', 'train']))
# Out:
#    cv  train      n
# 9   0  False   4272
# 0   0   True  22586
# 5   1  False   8181
# 4   1   True  18677
# 8   2  False   4372
# 1   2   True  22486
# 6   3  False   5544
# 3   3   True  21314
# 7   4  False   4489
# 2   4   True  22369

# %% [markdown]
# As expected each gene target (gene) only appears in one set in each fold

# %%
(tidy_cv_df[['cv','train', 'target']].value_counts()
 .reset_index(name='n')
 [['cv', 'target']].value_counts()  # will show up twice if train == False and True
 .reset_index(name='train_test_sum')
 .groupby('cv')
 .agg({'train_test_sum': ['max']}))
# Out:
#    train_test_sum
#               max
# cv
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %% [markdown]
# ## Testing Feature Sets
#
# ### Amino Acid Width

# %%
aa_width_prediction_list = []
aa_widths = [2, 4, 8, 16, 32]
for width in aa_widths:
    print(width)
    for fold, df in tidy_cv_df.groupby('cv'):
        print('Fold: ' + str(fold))
        predictions = get_fold_predictions(fold, df, model_name='aa ' + str(width),
                                           features=['aa'],
                                           aa_seq_df=aa_seqs,
                                           protein_domain_df=protein_domains,
                                           conservation_df=conservation_df,
                                           aa_width=width, aa_features=None)
        aa_width_prediction_list.append(predictions)
    print('\n')

aa_width_predictive_performance, aa_width_agg_performance = get_predictive_performance(aa_width_prediction_list,
                                                                                       'Residual Activity')
# Out:
# 2
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# 4
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# 8
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# 16
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# 32
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %% [markdown]
# We'll use a width of 16 as our default for Amino Acid featurization

# %%
aa_width_agg_performance
# Out:
#   model_name  mean_spearman  std_spearman  median_spearman
# 0      aa 16       0.186075      0.147755         0.198058
# 1       aa 8       0.178726      0.133223         0.208053
# 2      aa 32       0.172723      0.135843         0.180469
# 3       aa 4       0.147685      0.093290         0.164908
# 4       aa 2       0.096954      0.114068         0.104131

# %%
plot_spearman_heatmap(aa_width_predictive_performance)
# Out:
# <ggplot: (8781760726640)>

# %%
g = plot_model_performance(aa_width_predictive_performance)
g.save('../figures/target_model_aa_width.pdf', width=3, height=3)
g
# Out:
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 3 x 3 in image.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: ../figures/target_model_aa_width.pdf
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# <ggplot: (8781734385917)>

# %% [markdown]
# ### Conservation Width

# %%
cons_width_prediction_list = []
cons_small_widths = [2, 4, 8]
cons_large_widths = [16, 32, 64]
for small_width in cons_small_widths:
    print('Small: ' + str(small_width))
    for large_width in cons_large_widths:
        print('Large: ' + str(large_width))
        for fold, df in tidy_cv_df.groupby('cv'):
            print('Fold: ' + str(fold))
            predictions = get_fold_predictions(fold, df, model_name='cons ' + str(small_width) +  ', ' +
                                                                    str(large_width),
                                               features=['conservation'],
                                               aa_seq_df=aa_seqs,
                                               protein_domain_df=protein_domains,
                                               conservation_df=conservation_df,
                                               cons_small_width=small_width,
                                               cons_large_width=large_width)
            cons_width_prediction_list.append(predictions)
        print('\n')
    print('\n')

cons_width_predictive_performance, cons_width_agg_performance = get_predictive_performance(cons_width_prediction_list,
                                                                                           'Residual Activity')
# Out:
# Small: 2
# Large: 16
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# Large: 32
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# Large: 64
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
#
#
# Small: 4
# Large: 16
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# Large: 32
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# Large: 64
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
#
#
# Small: 8
# Large: 16
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# Large: 32
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# Large: 64
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %% [markdown]
# It looks like a small width of 4 and a large width of 32 is optimal for conservation

# %%
cons_width_agg_performance
# Out:
#    model_name  mean_spearman  std_spearman  median_spearman
# 0  cons 4, 32       0.109353      0.157461         0.124099
# 1  cons 8, 16       0.108433      0.136532         0.088330
# 2  cons 8, 32       0.100428      0.155942         0.057372
# 3  cons 8, 64       0.097854      0.150466         0.081314
# 4  cons 4, 16       0.095250      0.160747         0.081347
# 5  cons 2, 16       0.089690      0.167821         0.092646
# 6  cons 2, 32       0.086444      0.175432         0.079726
# 7  cons 4, 64       0.077590      0.177568         0.066384
# 8  cons 2, 64       0.075342      0.180968         0.071444

# %%
plot_spearman_heatmap(cons_width_predictive_performance)
# Out:
# <ggplot: (8781759767812)>

# %%
g = plot_model_performance(cons_width_predictive_performance)
g.save('../figures/target_model_cons_width.pdf', width=4, height=3)
g
# Out:
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 4 x 3 in image.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: ../figures/target_model_cons_width.pdf
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# <ggplot: (8782021071595)>

# %% [markdown]
# ### Single Feature Sets

# %%
single_prediction_list = []
features = ['position', 'aa', 'domain', 'conservation']
for feature in features:
    print(feature)
    for fold, df in tidy_cv_df.groupby('cv'):
        print('Fold: ' + str(fold))
        predictions = get_fold_predictions(fold, df, model_name=feature,
                                           features=[feature],
                                           aa_seq_df=aa_seqs,
                                           protein_domain_df=protein_domains,
                                           conservation_df=conservation_df)
        single_prediction_list.append(predictions)
    print('\n')

single_predictive_performance, single_agg_performance = get_predictive_performance(single_prediction_list,
                                                                                   'Residual Activity')
# Out:
# position
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# aa
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# domain
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# conservation
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %% [markdown]
# All features are able to positively predict the residual activity of sgRNAs

# %%
single_agg_performance
# Out:
#      model_name  mean_spearman  std_spearman  median_spearman
# 0        domain       0.194020      0.174449         0.184055
# 1            aa       0.186075      0.147755         0.198058
# 2  conservation       0.109353      0.157461         0.124099
# 3      position       0.078879      0.078426         0.066053

# %%
plot_spearman_heatmap(single_predictive_performance)
# Out:
# <ggplot: (8781745363878)>

# %%
g = plot_model_performance(single_predictive_performance)
g.save('../figures/target_model_single_performance.pdf', width=2.7, height=2.7)
g
# Out:
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 2.7 x 2.7 in image.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: ../figures/target_model_single_performance.pdf
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# <ggplot: (8781741882275)>

# %% [markdown]
# ### Complete Feature Set
#
# All features together are better than any one alone.

# %%
complete_feature_list = []
for fold, df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    predictions = get_fold_predictions(fold, df, model_name='All',
                                       features=features,
                                       aa_seq_df=aa_seqs,
                                       protein_domain_df=protein_domains,
                                       conservation_df=conservation_df)
    complete_feature_list.append(predictions)

complete_predictive_performance, complete_agg_performance = get_predictive_performance(complete_feature_list +
                                                                                       single_prediction_list,
                                                                                       'Residual Activity')
# Out:
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %%
complete_agg_performance
# Out:
#      model_name  mean_spearman  std_spearman  median_spearman
# 0           All       0.243202      0.146578         0.266182
# 1        domain       0.194020      0.174449         0.184055
# 2            aa       0.186075      0.147755         0.198058
# 3  conservation       0.109353      0.157461         0.124099
# 4      position       0.078879      0.078426         0.066053

# %%
plot_spearman_heatmap(complete_predictive_performance)
# Out:
# <ggplot: (8781688472516)>

# %%
g = plot_model_performance(complete_predictive_performance)
g.save('../figures/target_all_performance.pdf', width=3, height=3)
g
# Out:
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 3 x 3 in image.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: ../figures/target_all_performance.pdf
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# <ggplot: (8781607379246)>

# %% [markdown]
# ### Leave One Set Out
#
# The model with all features appears to perform best, so we will continue to use all features

# %%
leave_one_prediction_list = []
for feature in features:
    print(feature)
    curr_features = features.copy()
    curr_features.remove(feature)
    for fold, df in tidy_cv_df.groupby('cv'):
        print('Fold: ' + str(fold))
        predictions = get_fold_predictions(fold, df, model_name='No ' + feature,
                                           features=curr_features,
                                           aa_seq_df=aa_seqs,
                                           protein_domain_df=protein_domains,
                                           conservation_df=conservation_df)
        leave_one_prediction_list.append(predictions)
    print('\n')

leave_one_predictive_performance, leave_one_agg_performance = get_predictive_performance(
    leave_one_prediction_list + complete_feature_list, 'Residual Activity')
# Out:
# position
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# aa
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# domain
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
#
#
# conservation
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4

# %%
leave_one_agg_performance
# Out:
#         model_name  mean_spearman  std_spearman  median_spearman
# 0              All       0.243202      0.146578         0.266182
# 1  No conservation       0.243106      0.129201         0.246775
# 2      No position       0.242326      0.160562         0.270829
# 3            No aa       0.220374      0.172575         0.202254
# 4        No domain       0.207319      0.160478         0.193439

# %%
plot_spearman_heatmap(leave_one_predictive_performance)
# Out:
# <ggplot: (8782027338346)>

# %%
plot_model_performance(leave_one_predictive_performance)
# Out:
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff', '#000000ff', '#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# <ggplot: (8781761750908)>

# %% [markdown]
# ## Hyperparameter Tuning
#
# We'll use optuna to tune hyperparameters for the model

# %%
n_trials = 50
model_name = 'All + TPE ' + str(n_trials)
final_features = features.copy()

# %%
tpe_prediction_list = []

for fold, fold_df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    fold_train_data = fold_df.query('train == True').reset_index(drop=True)
    study = optuna.create_study(direction='maximize',
                                sampler=optuna.samplers.TPESampler(seed=7)) # maximize r^2
    objective = get_lgbm_objective(fold_train_data, features=final_features,
                                   aa_seq_df=aa_seqs, protein_domain_df=protein_domains,
                                   conservation_df=conservation_df)
    start_time = datetime.now()
    study.optimize(objective, n_trials=n_trials)
    end_time = datetime.now()
    difference = end_time - start_time
    print("Number of finished trials: {}".format(len(study.trials)))
    print("Training Time: " + str(difference))
    print("Best trial:")
    trial = study.best_trial
    print("  Value: {}".format(trial.value))
    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
    # Using optimal parameters, retrain model with full dataset
    train_df = fold_train_data.copy()
    train_feature_df, train_feature_cols = ft.build_target_feature_df(train_df,
                                                                      features=final_features,
                                                                      aa_seq_df=aa_seqs,
                                                                      protein_domain_df=protein_domains,
                                                                      conservation_df=conservation_df)
    X_train_val = train_feature_df[train_feature_cols] # train and validation data
    y_train_val = train_df['Residual Activity']
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val,
                                                      test_size=0.1, random_state=7)
    model = Pipeline([('imputer', SimpleImputer(strategy='median')),
                      ('regressor',
                       LGBMRegressor(random_state=7, n_jobs=8, learning_rate=0.01, n_estimators=5000,
                                     **trial.params))])
    model.fit(X_train, y_train,
              regressor__early_stopping_rounds=20,
              regressor__eval_set=[(X_val, y_val)],
              regressor__verbose=1000)
    fold_test_data = fold_df.query('train == False').reset_index(drop=True)
    test_feature_df, test_feature_cols = ft.build_target_feature_df(fold_test_data,
                                                                    features=final_features,
                                                                    aa_seq_df=aa_seqs,
                                                                    protein_domain_df=protein_domains,
                                                                    conservation_df=conservation_df)
    X_test = test_feature_df[test_feature_cols]
    test_predictions = fold_test_data.copy()
    test_predictions['prediction'] = model.predict(X_test)
    test_predictions['model_name'] = model_name
    test_predictions['fold'] = fold
    tpe_prediction_list.append(test_predictions)
# Out:
# [I 2021-07-06 11:19:33,247] A new study created in memory with name: no-name-b23690ce-9d9e-4c3e-88b5-995abd007490
# Fold: 0
# [I 2021-07-06 11:19:59,386] Trial 0 finished with value: 0.06201329977330232 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:20:21,643] Trial 1 finished with value: 0.0474249527374371 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:20:42,872] Trial 2 finished with value: 0.0504847974103807 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:21:03,034] Trial 3 finished with value: 0.05430555103372044 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:21:25,520] Trial 4 finished with value: 0.047640559051435605 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:21:47,968] Trial 5 finished with value: 0.04906270792975005 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:22:08,675] Trial 6 finished with value: 0.056998112317353036 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:22:32,412] Trial 7 finished with value: 0.048385083407017235 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:22:54,857] Trial 8 finished with value: 0.049721340861806816 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:23:14,014] Trial 9 finished with value: 0.04657992333775951 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:23:33,360] Trial 10 finished with value: 0.058637494412484246 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 0 with value: 0.06201329977330232.
# [I 2021-07-06 11:23:49,659] Trial 11 finished with value: 0.0782596119639422 and parameters: {'num_leaves': 10, 'min_child_samples': 74}. Best is trial 11 with value: 0.0782596119639422.
# [I 2021-07-06 11:24:06,936] Trial 12 finished with value: 0.0735012264312074 and parameters: {'num_leaves': 14, 'min_child_samples': 82}. Best is trial 11 with value: 0.0782596119639422.
# [I 2021-07-06 11:24:25,007] Trial 13 finished with value: 0.06389339164545005 and parameters: {'num_leaves': 27, 'min_child_samples': 72}. Best is trial 11 with value: 0.0782596119639422.
# [I 2021-07-06 11:24:40,642] Trial 14 finished with value: 0.07404689800199678 and parameters: {'num_leaves': 8, 'min_child_samples': 65}. Best is trial 11 with value: 0.0782596119639422.
# [I 2021-07-06 11:24:56,466] Trial 15 finished with value: 0.080127033052463 and parameters: {'num_leaves': 8, 'min_child_samples': 53}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:25:23,681] Trial 16 finished with value: 0.0414175760621055 and parameters: {'num_leaves': 165, 'min_child_samples': 46}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:25:45,132] Trial 17 finished with value: 0.05452076180586522 and parameters: {'num_leaves': 55, 'min_child_samples': 109}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:26:09,218] Trial 18 finished with value: 0.060712590507960275 and parameters: {'num_leaves': 47, 'min_child_samples': 45}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:26:33,548] Trial 19 finished with value: 0.046772333998727156 and parameters: {'num_leaves': 184, 'min_child_samples': 154}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:26:54,507] Trial 20 finished with value: 0.04537666337142423 and parameters: {'num_leaves': 219, 'min_child_samples': 95}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:27:12,249] Trial 21 finished with value: 0.07586918004085097 and parameters: {'num_leaves': 9, 'min_child_samples': 57}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:27:28,161] Trial 22 finished with value: 0.07713202541340783 and parameters: {'num_leaves': 12, 'min_child_samples': 46}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:27:48,097] Trial 23 finished with value: 0.06273770576794499 and parameters: {'num_leaves': 43, 'min_child_samples': 36}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:28:06,844] Trial 24 finished with value: 0.059404338678574045 and parameters: {'num_leaves': 86, 'min_child_samples': 11}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:28:24,735] Trial 25 finished with value: 0.07558763112985623 and parameters: {'num_leaves': 12, 'min_child_samples': 99}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:28:44,616] Trial 26 finished with value: 0.056811055443689674 and parameters: {'num_leaves': 37, 'min_child_samples': 54}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:29:04,954] Trial 27 finished with value: 0.05442566918273968 and parameters: {'num_leaves': 64, 'min_child_samples': 35}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:29:21,565] Trial 28 finished with value: 0.07620175306536767 and parameters: {'num_leaves': 8, 'min_child_samples': 87}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:29:40,093] Trial 29 finished with value: 0.07075633825615128 and parameters: {'num_leaves': 26, 'min_child_samples': 63}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:29:57,059] Trial 30 finished with value: 0.060843856969302924 and parameters: {'num_leaves': 96, 'min_child_samples': 13}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:30:12,231] Trial 31 finished with value: 0.07756180821551262 and parameters: {'num_leaves': 9, 'min_child_samples': 89}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:30:29,680] Trial 32 finished with value: 0.061991371457154346 and parameters: {'num_leaves': 35, 'min_child_samples': 108}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:30:46,830] Trial 33 finished with value: 0.07095444374575896 and parameters: {'num_leaves': 21, 'min_child_samples': 74}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:31:06,205] Trial 34 finished with value: 0.04866594763029133 and parameters: {'num_leaves': 139, 'min_child_samples': 160}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:31:24,518] Trial 35 finished with value: 0.05871683918322601 and parameters: {'num_leaves': 55, 'min_child_samples': 34}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:31:39,641] Trial 36 finished with value: 0.07665247205980637 and parameters: {'num_leaves': 9, 'min_child_samples': 122}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:32:00,418] Trial 37 finished with value: 0.05405493048680456 and parameters: {'num_leaves': 40, 'min_child_samples': 95}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:32:17,924] Trial 38 finished with value: 0.05739139446156989 and parameters: {'num_leaves': 69, 'min_child_samples': 45}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:32:38,721] Trial 39 finished with value: 0.05057163102717246 and parameters: {'num_leaves': 122, 'min_child_samples': 61}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:32:58,583] Trial 40 finished with value: 0.06752684454205322 and parameters: {'num_leaves': 22, 'min_child_samples': 134}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:33:15,604] Trial 41 finished with value: 0.07355969644817684 and parameters: {'num_leaves': 11, 'min_child_samples': 116}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:33:29,917] Trial 42 finished with value: 0.07932598866835956 and parameters: {'num_leaves': 8, 'min_child_samples': 122}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:33:49,995] Trial 43 finished with value: 0.05718790267456826 and parameters: {'num_leaves': 32, 'min_child_samples': 153}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:34:06,099] Trial 44 finished with value: 0.06885132408654356 and parameters: {'num_leaves': 19, 'min_child_samples': 179}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:34:24,868] Trial 45 finished with value: 0.06117875552740935 and parameters: {'num_leaves': 45, 'min_child_samples': 89}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:34:42,397] Trial 46 finished with value: 0.07064414957365457 and parameters: {'num_leaves': 20, 'min_child_samples': 72}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:35:00,699] Trial 47 finished with value: 0.06187860268440091 and parameters: {'num_leaves': 52, 'min_child_samples': 24}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:35:17,506] Trial 48 finished with value: 0.06430258641922663 and parameters: {'num_leaves': 30, 'min_child_samples': 137}. Best is trial 15 with value: 0.080127033052463.
# [I 2021-07-06 11:35:37,689] Trial 49 finished with value: 0.04675805365600407 and parameters: {'num_leaves': 80, 'min_child_samples': 106}. Best is trial 15 with value: 0.080127033052463.
# Number of finished trials: 50
# Training Time: 0:16:04.443175
# Best trial:
#   Value: 0.080127033052463
#   Params:
#     num_leaves: 8
#     min_child_samples: 53
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.427106
# [2000]	valid_0's l2: 0.42058
# Early stopping, best iteration is:
# [2425]	valid_0's l2: 0.41828
# [I 2021-07-06 11:35:47,486] A new study created in memory with name: no-name-07819dc7-0694-40df-8f08-61ea120b4898
# Fold: 1
# [I 2021-07-06 11:35:59,049] Trial 0 finished with value: 0.10563073280447617 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:36:14,086] Trial 1 finished with value: 0.08929757881636555 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:36:29,320] Trial 2 finished with value: 0.08608317945096575 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:36:43,265] Trial 3 finished with value: 0.09491641521754875 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:36:59,101] Trial 4 finished with value: 0.08874080510797247 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:37:15,287] Trial 5 finished with value: 0.08870150543611788 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:37:28,251] Trial 6 finished with value: 0.0961582460234168 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:37:44,379] Trial 7 finished with value: 0.09424921092487057 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:37:59,518] Trial 8 finished with value: 0.08621551231300154 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:38:12,758] Trial 9 finished with value: 0.09635925937195525 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:38:26,389] Trial 10 finished with value: 0.10077133611535949 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 0 with value: 0.10563073280447617.
# [I 2021-07-06 11:38:39,034] Trial 11 finished with value: 0.11005527070520764 and parameters: {'num_leaves': 10, 'min_child_samples': 74}. Best is trial 11 with value: 0.11005527070520764.
# [I 2021-07-06 11:38:52,693] Trial 12 finished with value: 0.10806970648946271 and parameters: {'num_leaves': 14, 'min_child_samples': 82}. Best is trial 11 with value: 0.11005527070520764.
# [I 2021-07-06 11:39:06,093] Trial 13 finished with value: 0.10476768367755585 and parameters: {'num_leaves': 27, 'min_child_samples': 72}. Best is trial 11 with value: 0.11005527070520764.
# [I 2021-07-06 11:39:18,949] Trial 14 finished with value: 0.11455030873362768 and parameters: {'num_leaves': 8, 'min_child_samples': 65}. Best is trial 14 with value: 0.11455030873362768.
# [I 2021-07-06 11:39:30,375] Trial 15 finished with value: 0.11471067121342152 and parameters: {'num_leaves': 8, 'min_child_samples': 53}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:39:45,337] Trial 16 finished with value: 0.08727386612270152 and parameters: {'num_leaves': 165, 'min_child_samples': 46}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:40:00,548] Trial 17 finished with value: 0.08837968331245234 and parameters: {'num_leaves': 55, 'min_child_samples': 109}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:40:14,250] Trial 18 finished with value: 0.09974133401779703 and parameters: {'num_leaves': 47, 'min_child_samples': 42}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:40:29,712] Trial 19 finished with value: 0.0876424751357215 and parameters: {'num_leaves': 184, 'min_child_samples': 154}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:40:43,939] Trial 20 finished with value: 0.08732588772836732 and parameters: {'num_leaves': 220, 'min_child_samples': 51}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:40:57,242] Trial 21 finished with value: 0.11324359437488854 and parameters: {'num_leaves': 9, 'min_child_samples': 98}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:41:10,540] Trial 22 finished with value: 0.1075249149661075 and parameters: {'num_leaves': 12, 'min_child_samples': 102}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:41:24,719] Trial 23 finished with value: 0.09477189870390275 and parameters: {'num_leaves': 44, 'min_child_samples': 95}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:41:40,278] Trial 24 finished with value: 0.08985408405037194 and parameters: {'num_leaves': 87, 'min_child_samples': 53}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:41:55,260] Trial 25 finished with value: 0.10543334669556273 and parameters: {'num_leaves': 12, 'min_child_samples': 164}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:42:10,872] Trial 26 finished with value: 0.09423440907316132 and parameters: {'num_leaves': 37, 'min_child_samples': 90}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:42:25,231] Trial 27 finished with value: 0.08909537249524072 and parameters: {'num_leaves': 64, 'min_child_samples': 119}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:42:38,198] Trial 28 finished with value: 0.11354308245789171 and parameters: {'num_leaves': 8, 'min_child_samples': 61}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:42:51,935] Trial 29 finished with value: 0.09799473242046483 and parameters: {'num_leaves': 32, 'min_child_samples': 32}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:43:08,757] Trial 30 finished with value: 0.09168345317734532 and parameters: {'num_leaves': 135, 'min_child_samples': 61}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:43:27,201] Trial 31 finished with value: 0.10989008272949712 and parameters: {'num_leaves': 9, 'min_child_samples': 66}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:43:45,286] Trial 32 finished with value: 0.10129060469602184 and parameters: {'num_leaves': 25, 'min_child_samples': 36}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:44:02,022] Trial 33 finished with value: 0.10600093539351459 and parameters: {'num_leaves': 10, 'min_child_samples': 94}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:44:15,314] Trial 34 finished with value: 0.10278061319073879 and parameters: {'num_leaves': 38, 'min_child_samples': 13}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:44:30,364] Trial 35 finished with value: 0.10161401879038323 and parameters: {'num_leaves': 23, 'min_child_samples': 62}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:44:44,384] Trial 36 finished with value: 0.0963466175642943 and parameters: {'num_leaves': 51, 'min_child_samples': 115}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:44:59,247] Trial 37 finished with value: 0.08841147913764309 and parameters: {'num_leaves': 100, 'min_child_samples': 86}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:45:14,484] Trial 38 finished with value: 0.09064122613079291 and parameters: {'num_leaves': 69, 'min_child_samples': 134}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:45:27,338] Trial 39 finished with value: 0.1070393946177303 and parameters: {'num_leaves': 20, 'min_child_samples': 22}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:45:41,067] Trial 40 finished with value: 0.10128476193362228 and parameters: {'num_leaves': 120, 'min_child_samples': 8}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:45:54,104] Trial 41 finished with value: 0.11020355919189158 and parameters: {'num_leaves': 11, 'min_child_samples': 77}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:46:06,747] Trial 42 finished with value: 0.11225657105516948 and parameters: {'num_leaves': 8, 'min_child_samples': 58}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:46:22,130] Trial 43 finished with value: 0.10168882237398844 and parameters: {'num_leaves': 38, 'min_child_samples': 58}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:46:37,604] Trial 44 finished with value: 0.1048016034519994 and parameters: {'num_leaves': 23, 'min_child_samples': 30}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:46:51,915] Trial 45 finished with value: 0.11361234391955052 and parameters: {'num_leaves': 9, 'min_child_samples': 101}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:47:08,288] Trial 46 finished with value: 0.08679100473411624 and parameters: {'num_leaves': 81, 'min_child_samples': 109}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:47:22,204] Trial 47 finished with value: 0.10227088270425475 and parameters: {'num_leaves': 32, 'min_child_samples': 72}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:47:36,292] Trial 48 finished with value: 0.08728524176933525 and parameters: {'num_leaves': 57, 'min_child_samples': 128}. Best is trial 15 with value: 0.11471067121342152.
# [I 2021-07-06 11:47:49,477] Trial 49 finished with value: 0.10541783563356352 and parameters: {'num_leaves': 18, 'min_child_samples': 42}. Best is trial 15 with value: 0.11471067121342152.
# Number of finished trials: 50
# Training Time: 0:12:01.987499
# Best trial:
#   Value: 0.11471067121342152
#   Params:
#     num_leaves: 8
#     min_child_samples: 53
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.392272
# Early stopping, best iteration is:
# [1119]	valid_0's l2: 0.391504
# [I 2021-07-06 11:47:58,522] A new study created in memory with name: no-name-7ee6b50b-ab3a-415f-bece-6f0a3be12616
# Fold: 2
# [I 2021-07-06 11:48:13,338] Trial 0 finished with value: 0.07396143823985395 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:48:31,235] Trial 1 finished with value: 0.06532503835817578 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:48:51,393] Trial 2 finished with value: 0.05752381262927482 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:49:09,986] Trial 3 finished with value: 0.060907749824587 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:49:28,050] Trial 4 finished with value: 0.0575234374342581 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:49:45,912] Trial 5 finished with value: 0.0622336076662924 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:50:03,858] Trial 6 finished with value: 0.06590727831847484 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:50:23,461] Trial 7 finished with value: 0.06034926732896362 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:50:41,379] Trial 8 finished with value: 0.05927723608844839 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:50:59,284] Trial 9 finished with value: 0.056255024469508405 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:51:16,872] Trial 10 finished with value: 0.0723506369095355 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 0 with value: 0.07396143823985395.
# [I 2021-07-06 11:51:36,484] Trial 11 finished with value: 0.0773476002675624 and parameters: {'num_leaves': 10, 'min_child_samples': 74}. Best is trial 11 with value: 0.0773476002675624.
# [I 2021-07-06 11:51:58,667] Trial 12 finished with value: 0.07639878235247204 and parameters: {'num_leaves': 14, 'min_child_samples': 82}. Best is trial 11 with value: 0.0773476002675624.
# [I 2021-07-06 11:52:17,933] Trial 13 finished with value: 0.07215587535713122 and parameters: {'num_leaves': 27, 'min_child_samples': 72}. Best is trial 11 with value: 0.0773476002675624.
# [I 2021-07-06 11:52:34,826] Trial 14 finished with value: 0.07773760577795141 and parameters: {'num_leaves': 8, 'min_child_samples': 65}. Best is trial 14 with value: 0.07773760577795141.
# [I 2021-07-06 11:52:52,094] Trial 15 finished with value: 0.07855808606011545 and parameters: {'num_leaves': 8, 'min_child_samples': 53}. Best is trial 15 with value: 0.07855808606011545.
# [I 2021-07-06 11:53:12,613] Trial 16 finished with value: 0.05657701030769491 and parameters: {'num_leaves': 165, 'min_child_samples': 46}. Best is trial 15 with value: 0.07855808606011545.
# [I 2021-07-06 11:53:33,293] Trial 17 finished with value: 0.06110026418287025 and parameters: {'num_leaves': 55, 'min_child_samples': 109}. Best is trial 15 with value: 0.07855808606011545.
# [I 2021-07-06 11:53:52,934] Trial 18 finished with value: 0.06926807728736169 and parameters: {'num_leaves': 47, 'min_child_samples': 42}. Best is trial 15 with value: 0.07855808606011545.
# [I 2021-07-06 11:54:14,398] Trial 19 finished with value: 0.05757235534344205 and parameters: {'num_leaves': 184, 'min_child_samples': 154}. Best is trial 15 with value: 0.07855808606011545.
# [I 2021-07-06 11:54:41,155] Trial 20 finished with value: 0.054063627829400905 and parameters: {'num_leaves': 220, 'min_child_samples': 51}. Best is trial 15 with value: 0.07855808606011545.
# [I 2021-07-06 11:54:58,748] Trial 21 finished with value: 0.08149793241352006 and parameters: {'num_leaves': 9, 'min_child_samples': 98}. Best is trial 21 with value: 0.08149793241352006.
# [I 2021-07-06 11:55:17,190] Trial 22 finished with value: 0.07795437214792685 and parameters: {'num_leaves': 12, 'min_child_samples': 102}. Best is trial 21 with value: 0.08149793241352006.
# [I 2021-07-06 11:55:38,166] Trial 23 finished with value: 0.0657776156007901 and parameters: {'num_leaves': 43, 'min_child_samples': 101}. Best is trial 21 with value: 0.08149793241352006.
# [I 2021-07-06 11:56:00,923] Trial 24 finished with value: 0.06266028736948762 and parameters: {'num_leaves': 86, 'min_child_samples': 92}. Best is trial 21 with value: 0.08149793241352006.
# [I 2021-07-06 11:56:16,917] Trial 25 finished with value: 0.07994938760728298 and parameters: {'num_leaves': 12, 'min_child_samples': 164}. Best is trial 21 with value: 0.08149793241352006.
# [I 2021-07-06 11:56:33,484] Trial 26 finished with value: 0.07025785841338608 and parameters: {'num_leaves': 37, 'min_child_samples': 164}. Best is trial 21 with value: 0.08149793241352006.
# [I 2021-07-06 11:56:52,617] Trial 27 finished with value: 0.05635557509041089 and parameters: {'num_leaves': 64, 'min_child_samples': 159}. Best is trial 21 with value: 0.08149793241352006.
# [I 2021-07-06 11:57:07,946] Trial 28 finished with value: 0.08387124672211099 and parameters: {'num_leaves': 8, 'min_child_samples': 179}. Best is trial 28 with value: 0.08387124672211099.
# [I 2021-07-06 11:57:24,373] Trial 29 finished with value: 0.07290274762908491 and parameters: {'num_leaves': 26, 'min_child_samples': 183}. Best is trial 28 with value: 0.08387124672211099.
# [I 2021-07-06 11:57:44,727] Trial 30 finished with value: 0.06599098857721779 and parameters: {'num_leaves': 95, 'min_child_samples': 255}. Best is trial 28 with value: 0.08387124672211099.
# [I 2021-07-06 11:58:00,728] Trial 31 finished with value: 0.0840434037117819 and parameters: {'num_leaves': 9, 'min_child_samples': 209}. Best is trial 31 with value: 0.0840434037117819.
# [I 2021-07-06 11:58:21,670] Trial 32 finished with value: 0.07129941765167225 and parameters: {'num_leaves': 28, 'min_child_samples': 216}. Best is trial 31 with value: 0.0840434037117819.
# [I 2021-07-06 11:58:37,914] Trial 33 finished with value: 0.08494985059575091 and parameters: {'num_leaves': 10, 'min_child_samples': 183}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 11:59:14,160] Trial 34 finished with value: 0.0652187879837812 and parameters: {'num_leaves': 38, 'min_child_samples': 186}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 11:59:32,926] Trial 35 finished with value: 0.0759373091683521 and parameters: {'num_leaves': 21, 'min_child_samples': 226}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 11:59:55,384] Trial 36 finished with value: 0.06684125704587329 and parameters: {'num_leaves': 51, 'min_child_samples': 199}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:00:17,786] Trial 37 finished with value: 0.06817567053492639 and parameters: {'num_leaves': 120, 'min_child_samples': 248}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:00:46,241] Trial 38 finished with value: 0.06131758374480019 and parameters: {'num_leaves': 149, 'min_child_samples': 138}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:01:12,074] Trial 39 finished with value: 0.05831367753213492 and parameters: {'num_leaves': 73, 'min_child_samples': 176}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:01:34,150] Trial 40 finished with value: 0.06891861277898532 and parameters: {'num_leaves': 36, 'min_child_samples': 198}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:01:51,359] Trial 41 finished with value: 0.0797774094976956 and parameters: {'num_leaves': 11, 'min_child_samples': 169}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:02:07,297] Trial 42 finished with value: 0.08252446687949752 and parameters: {'num_leaves': 8, 'min_child_samples': 149}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:02:24,691] Trial 43 finished with value: 0.06955964613063022 and parameters: {'num_leaves': 21, 'min_child_samples': 122}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:02:44,422] Trial 44 finished with value: 0.05735573161781158 and parameters: {'num_leaves': 62, 'min_child_samples': 148}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:03:02,422] Trial 45 finished with value: 0.06471522800984375 and parameters: {'num_leaves': 34, 'min_child_samples': 209}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:03:20,456] Trial 46 finished with value: 0.07531542045117061 and parameters: {'num_leaves': 20, 'min_child_samples': 193}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:03:37,606] Trial 47 finished with value: 0.06307711943628999 and parameters: {'num_leaves': 47, 'min_child_samples': 129}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:03:53,931] Trial 48 finished with value: 0.07837104898481591 and parameters: {'num_leaves': 17, 'min_child_samples': 234}. Best is trial 33 with value: 0.08494985059575091.
# [I 2021-07-06 12:04:09,873] Trial 49 finished with value: 0.08084950828506117 and parameters: {'num_leaves': 10, 'min_child_samples': 177}. Best is trial 33 with value: 0.08494985059575091.
# Number of finished trials: 50
# Training Time: 0:16:11.349709
# Best trial:
#   Value: 0.08494985059575091
#   Params:
#     num_leaves: 10
#     min_child_samples: 183
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.389865
# Early stopping, best iteration is:
# [1614]	valid_0's l2: 0.386206
# [I 2021-07-06 12:04:19,950] A new study created in memory with name: no-name-fbf60ec5-b016-401a-856c-8325edaf84ad
# Fold: 3
# [I 2021-07-06 12:04:35,370] Trial 0 finished with value: 0.06683313801277113 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:04:54,761] Trial 1 finished with value: 0.05605545369476459 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:05:12,575] Trial 2 finished with value: 0.050642027212484966 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:05:29,645] Trial 3 finished with value: 0.062140030613353714 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:05:47,945] Trial 4 finished with value: 0.052070320531130455 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:06:07,069] Trial 5 finished with value: 0.057847910520476775 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:06:23,086] Trial 6 finished with value: 0.060759534752445575 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:06:39,806] Trial 7 finished with value: 0.05875580026546194 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:06:57,812] Trial 8 finished with value: 0.05290511472078765 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:07:20,387] Trial 9 finished with value: 0.05289895455076421 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:07:39,579] Trial 10 finished with value: 0.06582485866824492 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 0 with value: 0.06683313801277113.
# [I 2021-07-06 12:07:56,211] Trial 11 finished with value: 0.08110396894676311 and parameters: {'num_leaves': 10, 'min_child_samples': 74}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:08:11,189] Trial 12 finished with value: 0.07806454030025947 and parameters: {'num_leaves': 14, 'min_child_samples': 82}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:08:26,556] Trial 13 finished with value: 0.07064255249074174 and parameters: {'num_leaves': 27, 'min_child_samples': 72}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:08:44,081] Trial 14 finished with value: 0.07862768782814691 and parameters: {'num_leaves': 8, 'min_child_samples': 65}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:08:59,683] Trial 15 finished with value: 0.07972219487960105 and parameters: {'num_leaves': 8, 'min_child_samples': 53}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:09:20,467] Trial 16 finished with value: 0.04988721226744279 and parameters: {'num_leaves': 165, 'min_child_samples': 46}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:09:40,213] Trial 17 finished with value: 0.06123962362092048 and parameters: {'num_leaves': 55, 'min_child_samples': 109}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:09:58,345] Trial 18 finished with value: 0.06134909796390344 and parameters: {'num_leaves': 47, 'min_child_samples': 45}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:10:16,682] Trial 19 finished with value: 0.04959691270416129 and parameters: {'num_leaves': 184, 'min_child_samples': 154}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:10:37,459] Trial 20 finished with value: 0.047041425998156375 and parameters: {'num_leaves': 219, 'min_child_samples': 95}. Best is trial 11 with value: 0.08110396894676311.
# [I 2021-07-06 12:10:54,842] Trial 21 finished with value: 0.08195883289185402 and parameters: {'num_leaves': 9, 'min_child_samples': 57}. Best is trial 21 with value: 0.08195883289185402.
# [I 2021-07-06 12:11:12,269] Trial 22 finished with value: 0.07655499146068281 and parameters: {'num_leaves': 12, 'min_child_samples': 46}. Best is trial 21 with value: 0.08195883289185402.
# [I 2021-07-06 12:11:29,835] Trial 23 finished with value: 0.062256231634862956 and parameters: {'num_leaves': 44, 'min_child_samples': 51}. Best is trial 21 with value: 0.08195883289185402.
# [I 2021-07-06 12:11:49,750] Trial 24 finished with value: 0.05181609620003895 and parameters: {'num_leaves': 87, 'min_child_samples': 96}. Best is trial 21 with value: 0.08195883289185402.
# [I 2021-07-06 12:12:05,469] Trial 25 finished with value: 0.07681032316398936 and parameters: {'num_leaves': 12, 'min_child_samples': 9}. Best is trial 21 with value: 0.08195883289185402.
# [I 2021-07-06 12:12:25,147] Trial 26 finished with value: 0.06561905336357157 and parameters: {'num_leaves': 37, 'min_child_samples': 30}. Best is trial 21 with value: 0.08195883289185402.
# [I 2021-07-06 12:12:43,294] Trial 27 finished with value: 0.058802379471046294 and parameters: {'num_leaves': 64, 'min_child_samples': 61}. Best is trial 21 with value: 0.08195883289185402.
# [I 2021-07-06 12:12:56,576] Trial 28 finished with value: 0.08407430786160026 and parameters: {'num_leaves': 8, 'min_child_samples': 98}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:13:13,620] Trial 29 finished with value: 0.0654727673328922 and parameters: {'num_leaves': 33, 'min_child_samples': 160}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:13:29,519] Trial 30 finished with value: 0.0733738476363595 and parameters: {'num_leaves': 24, 'min_child_samples': 104}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:13:43,172] Trial 31 finished with value: 0.08230995593330781 and parameters: {'num_leaves': 9, 'min_child_samples': 89}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:13:58,133] Trial 32 finished with value: 0.08182494621828344 and parameters: {'num_leaves': 8, 'min_child_samples': 85}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:14:16,731] Trial 33 finished with value: 0.05977872872797454 and parameters: {'num_leaves': 47, 'min_child_samples': 116}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:14:38,215] Trial 34 finished with value: 0.047388371020807486 and parameters: {'num_leaves': 140, 'min_child_samples': 89}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:14:52,191] Trial 35 finished with value: 0.07359963264106499 and parameters: {'num_leaves': 24, 'min_child_samples': 133}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:15:12,642] Trial 36 finished with value: 0.04527167080168983 and parameters: {'num_leaves': 98, 'min_child_samples': 118}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:15:27,189] Trial 37 finished with value: 0.08309489639918388 and parameters: {'num_leaves': 8, 'min_child_samples': 89}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:15:47,330] Trial 38 finished with value: 0.057452969267883035 and parameters: {'num_leaves': 69, 'min_child_samples': 152}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:16:05,778] Trial 39 finished with value: 0.061519344113041385 and parameters: {'num_leaves': 37, 'min_child_samples': 175}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:16:23,280] Trial 40 finished with value: 0.05718134436000355 and parameters: {'num_leaves': 120, 'min_child_samples': 32}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:16:39,252] Trial 41 finished with value: 0.07613472611547126 and parameters: {'num_leaves': 19, 'min_child_samples': 86}. Best is trial 28 with value: 0.08407430786160026.
# [I 2021-07-06 12:16:55,371] Trial 42 finished with value: 0.08613011648238542 and parameters: {'num_leaves': 8, 'min_child_samples': 130}. Best is trial 42 with value: 0.08613011648238542.
# [I 2021-07-06 12:17:14,541] Trial 43 finished with value: 0.05458336110961228 and parameters: {'num_leaves': 51, 'min_child_samples': 125}. Best is trial 42 with value: 0.08613011648238542.
# [I 2021-07-06 12:17:30,911] Trial 44 finished with value: 0.07416367771355384 and parameters: {'num_leaves': 21, 'min_child_samples': 136}. Best is trial 42 with value: 0.08613011648238542.
# [I 2021-07-06 12:17:46,719] Trial 45 finished with value: 0.06932060861024496 and parameters: {'num_leaves': 35, 'min_child_samples': 103}. Best is trial 42 with value: 0.08613011648238542.
# [I 2021-07-06 12:18:04,475] Trial 46 finished with value: 0.07053508669178365 and parameters: {'num_leaves': 20, 'min_child_samples': 68}. Best is trial 42 with value: 0.08613011648238542.
# [I 2021-07-06 12:18:23,319] Trial 47 finished with value: 0.06476283394953777 and parameters: {'num_leaves': 32, 'min_child_samples': 111}. Best is trial 42 with value: 0.08613011648238542.
# [I 2021-07-06 12:18:42,622] Trial 48 finished with value: 0.056043526481260056 and parameters: {'num_leaves': 80, 'min_child_samples': 126}. Best is trial 42 with value: 0.08613011648238542.
# [I 2021-07-06 12:19:03,846] Trial 49 finished with value: 0.05722695349679789 and parameters: {'num_leaves': 59, 'min_child_samples': 59}. Best is trial 42 with value: 0.08613011648238542.
# Number of finished trials: 50
# Training Time: 0:14:43.892422
# Best trial:
#   Value: 0.08613011648238542
#   Params:
#     num_leaves: 8
#     min_child_samples: 130
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.395991
# [2000]	valid_0's l2: 0.388099
# Early stopping, best iteration is:
# [2202]	valid_0's l2: 0.386732
# [I 2021-07-06 12:19:13,951] A new study created in memory with name: no-name-90b499ae-84b2-453d-b0a8-8a2fa5cf7006
# Fold: 4
# [I 2021-07-06 12:19:34,951] Trial 0 finished with value: 0.04785834745385307 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.04785834745385307.
# [I 2021-07-06 12:19:57,446] Trial 1 finished with value: 0.0368374480742039 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.04785834745385307.
# [I 2021-07-06 12:20:19,451] Trial 2 finished with value: 0.0400490189628558 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.04785834745385307.
# [I 2021-07-06 12:20:39,867] Trial 3 finished with value: 0.047548217405300616 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.04785834745385307.
# [I 2021-07-06 12:21:03,464] Trial 4 finished with value: 0.041187516893787704 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.04785834745385307.
# [I 2021-07-06 12:21:25,540] Trial 5 finished with value: 0.04067183354849073 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.04785834745385307.
# [I 2021-07-06 12:21:45,527] Trial 6 finished with value: 0.050089129381829925 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 6 with value: 0.050089129381829925.
# [I 2021-07-06 12:22:06,628] Trial 7 finished with value: 0.041506694690904 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 6 with value: 0.050089129381829925.
# [I 2021-07-06 12:22:29,530] Trial 8 finished with value: 0.04194018958318006 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 6 with value: 0.050089129381829925.
# [I 2021-07-06 12:22:52,112] Trial 9 finished with value: 0.04252775258647958 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 6 with value: 0.050089129381829925.
# [I 2021-07-06 12:23:15,202] Trial 10 finished with value: 0.036568877771216514 and parameters: {'num_leaves': 182, 'min_child_samples': 59}. Best is trial 6 with value: 0.050089129381829925.
# [I 2021-07-06 12:23:34,113] Trial 11 finished with value: 0.06221758127500439 and parameters: {'num_leaves': 10, 'min_child_samples': 253}. Best is trial 11 with value: 0.06221758127500439.
# [I 2021-07-06 12:23:54,144] Trial 12 finished with value: 0.054819667092402956 and parameters: {'num_leaves': 20, 'min_child_samples': 76}. Best is trial 11 with value: 0.06221758127500439.
# [I 2021-07-06 12:24:11,094] Trial 13 finished with value: 0.05814512461761869 and parameters: {'num_leaves': 27, 'min_child_samples': 85}. Best is trial 11 with value: 0.06221758127500439.
# [I 2021-07-06 12:24:29,268] Trial 14 finished with value: 0.0656291385539195 and parameters: {'num_leaves': 8, 'min_child_samples': 90}. Best is trial 14 with value: 0.0656291385539195.
# [I 2021-07-06 12:24:45,902] Trial 15 finished with value: 0.06637294593981816 and parameters: {'num_leaves': 8, 'min_child_samples': 255}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:25:06,105] Trial 16 finished with value: 0.04741053354489107 and parameters: {'num_leaves': 50, 'min_child_samples': 156}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:25:31,217] Trial 17 finished with value: 0.04159488811680072 and parameters: {'num_leaves': 154, 'min_child_samples': 102}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:25:53,985] Trial 18 finished with value: 0.04824463276620985 and parameters: {'num_leaves': 43, 'min_child_samples': 50}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:26:11,711] Trial 19 finished with value: 0.06098266161722632 and parameters: {'num_leaves': 13, 'min_child_samples': 160}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:26:32,313] Trial 20 finished with value: 0.04014887993791405 and parameters: {'num_leaves': 220, 'min_child_samples': 99}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:26:51,317] Trial 21 finished with value: 0.06365299832942235 and parameters: {'num_leaves': 9, 'min_child_samples': 250}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:27:07,911] Trial 22 finished with value: 0.05966708234662852 and parameters: {'num_leaves': 12, 'min_child_samples': 256}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:27:26,649] Trial 23 finished with value: 0.04421373760842236 and parameters: {'num_leaves': 37, 'min_child_samples': 231}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:27:46,137] Trial 24 finished with value: 0.041506694690904 and parameters: {'num_leaves': 87, 'min_child_samples': 234}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:28:04,016] Trial 25 finished with value: 0.06327946312198082 and parameters: {'num_leaves': 12, 'min_child_samples': 177}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:28:22,982] Trial 26 finished with value: 0.04045354637655807 and parameters: {'num_leaves': 63, 'min_child_samples': 255}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:28:39,563] Trial 27 finished with value: 0.055620785595525635 and parameters: {'num_leaves': 40, 'min_child_samples': 113}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:28:55,934] Trial 28 finished with value: 0.06464521646056313 and parameters: {'num_leaves': 8, 'min_child_samples': 53}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:29:15,236] Trial 29 finished with value: 0.05047760106318222 and parameters: {'num_leaves': 32, 'min_child_samples': 51}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:29:34,596] Trial 30 finished with value: 0.046385809544225595 and parameters: {'num_leaves': 58, 'min_child_samples': 71}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:29:52,149] Trial 31 finished with value: 0.06176898795554764 and parameters: {'num_leaves': 9, 'min_child_samples': 37}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:30:12,800] Trial 32 finished with value: 0.04839186160848354 and parameters: {'num_leaves': 27, 'min_child_samples': 199}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:30:31,098] Trial 33 finished with value: 0.06240550166992258 and parameters: {'num_leaves': 10, 'min_child_samples': 78}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:30:50,023] Trial 34 finished with value: 0.05316358594383293 and parameters: {'num_leaves': 28, 'min_child_samples': 214}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:31:18,896] Trial 35 finished with value: 0.04269654028815906 and parameters: {'num_leaves': 97, 'min_child_samples': 91}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:31:45,903] Trial 36 finished with value: 0.041447738687154054 and parameters: {'num_leaves': 50, 'min_child_samples': 123}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:32:06,138] Trial 37 finished with value: 0.04563743173868982 and parameters: {'num_leaves': 120, 'min_child_samples': 36}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:32:27,844] Trial 38 finished with value: 0.04704696159868564 and parameters: {'num_leaves': 73, 'min_child_samples': 60}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:32:50,818] Trial 39 finished with value: 0.058940721802240234 and parameters: {'num_leaves': 20, 'min_child_samples': 138}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:33:08,375] Trial 40 finished with value: 0.05977268309510564 and parameters: {'num_leaves': 36, 'min_child_samples': 8}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:33:26,603] Trial 41 finished with value: 0.06618779525679079 and parameters: {'num_leaves': 11, 'min_child_samples': 179}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:33:43,052] Trial 42 finished with value: 0.06456726297814697 and parameters: {'num_leaves': 8, 'min_child_samples': 245}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:34:05,064] Trial 43 finished with value: 0.05350134095017731 and parameters: {'num_leaves': 22, 'min_child_samples': 183}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:34:28,560] Trial 44 finished with value: 0.0360135987582755 and parameters: {'num_leaves': 51, 'min_child_samples': 224}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:34:47,849] Trial 45 finished with value: 0.05452209496727371 and parameters: {'num_leaves': 21, 'min_child_samples': 155}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:35:11,053] Trial 46 finished with value: 0.03900511965499072 and parameters: {'num_leaves': 69, 'min_child_samples': 200}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:35:30,798] Trial 47 finished with value: 0.05071508143710548 and parameters: {'num_leaves': 44, 'min_child_samples': 172}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:35:51,435] Trial 48 finished with value: 0.04346015712402425 and parameters: {'num_leaves': 199, 'min_child_samples': 246}. Best is trial 15 with value: 0.06637294593981816.
# [I 2021-07-06 12:36:14,350] Trial 49 finished with value: 0.03849269622561278 and parameters: {'num_leaves': 148, 'min_child_samples': 111}. Best is trial 15 with value: 0.06637294593981816.
# Number of finished trials: 50
# Training Time: 0:17:00.396029
# Best trial:
#   Value: 0.06637294593981816
#   Params:
#     num_leaves: 8
#     min_child_samples: 255
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.396192
# Early stopping, best iteration is:
# [1491]	valid_0's l2: 0.392851

# %% [markdown]
# Tuning hyperparameters improves performance quite a bit

# %%
top_features = complete_feature_list
tpe_predictive_performance, tpe_agg_performance = get_predictive_performance(
    top_features + tpe_prediction_list, 'Residual Activity')

# %%
tpe_agg_performance
# Out:
#      model_name  mean_spearman  std_spearman  median_spearman
# 0  All + TPE 50       0.249248      0.177982         0.248490
# 1           All       0.243202      0.146578         0.266182

# %%
plot_spearman_heatmap(tpe_predictive_performance)
# Out:
# <ggplot: (8781611777741)>

# %%
g = plot_model_performance(tpe_predictive_performance, wspace=0.4)
g.save('../figures/target_model_tpe_performance.pdf', width=2.5, height=2.5)
g
# Out:
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 2.5 x 2.5 in image.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: ../figures/target_model_tpe_performance.pdf
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# /Users/pdeweird/.conda/envs/rs_dev/lib/python3.8/site-packages/plotnine/geoms/geom_point.py:61: UserWarning: You passed a edgecolor/edgecolors (['#000000ff', '#000000ff']) for an unfilled marker ('_').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# <ggplot: (8782021946106)>

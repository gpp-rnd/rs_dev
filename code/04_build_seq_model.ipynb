# %% [markdown]
# # Build Sequence Model

# %%
import pandas as pd
from datasets import dataset_list
from sklearn.model_selection import StratifiedGroupKFold, train_test_split
from lightgbm import LGBMRegressor
from sklearn.base import clone
from sklearn.metrics import r2_score
import sglearn
from scipy import stats
import optuna
from joblib import Parallel, delayed
import numpy as np
from tensorflow import keras
from datetime import datetime
from core import get_predictive_performance, plot_pearson_heatmap

# %%
def train_test_model(train_df, model_name, fold, model, test_df, X_test):
    """Get predictions from train and test model

    :param train_df: DataFrame
    :param model_name: str, name of model
    :param fold: int
    :param model: model with a .fit function
    :param test_df: DataFrame
    :param X_test: DataFrame from sglearn.featurize_guides
    :return: DataFrame, same shape as test_df with columns prediction, model, fold
    """
    X_train = sglearn.featurize_guides(train_df['sgRNA Context Sequence'])
    y_train = train_df['sgRNA Activity']
    model.fit(X_train,  y_train)
    dataset_test_predictions = test_df.copy()
    dataset_test_predictions['prediction'] = model.predict(X_test)
    dataset_test_predictions['model_name'] = model_name
    dataset_test_predictions['fold'] = fold
    return dataset_test_predictions


def get_fold_predictions(fold, fold_df,
                         base_model=LGBMRegressor(random_state=7, n_jobs=8),
                         top_training_set=None, combine_datasets=None, model_name=None):
    """Get predictions for a given fold, allowing for each dataset to be trained separately,
    or multiple datasets trained together

    :param fold: int
    :param fold_df: DataFrame
    :param base_model: model with a .fit function
    :param top_training_set: str
    :param combine_datasets: list of
    :param model_name: str optional, only relevant if top_datasets is specified
    :return: list of DataFrame, list of test predictions
    """
    fold_train_data = fold_df.query('train == True').reset_index(drop=True)
    fold_test_data = fold_df.query('train == False').reset_index(drop=True)
    X_test = sglearn.featurize_guides(fold_test_data['sgRNA Context Sequence'])
    test_prediction_list = []
    if combine_datasets is None:
        for dataset, dataset_df in fold_train_data.groupby('dataset'):
            dataset_df = dataset_df.reset_index(drop=True)
            # Join together top training set and current dataset
            if top_training_set is not None:
                if dataset != top_training_set:
                    top_dataset_df = fold_train_data[fold_train_data.dataset == top_training_set]
                    dataset_df = pd.concat([dataset_df, top_dataset_df]).reset_index(drop=True)
                    dataset_df['sgRNA Activity'] = (dataset_df.groupby('dataset')
                                                    ['sgRNA Activity']
                                                    .rank(pct=True))
                    dataset += ' + ' + top_training_set
            model = clone(base_model)
            dataset_test_predictions = train_test_model(dataset_df, dataset, fold, model, fold_test_data, X_test)
            test_prediction_list.append(dataset_test_predictions)
    else:
        train_df = fold_train_data[fold_train_data.dataset.isin(combine_datasets)].reset_index(drop=True)
        train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                      ['sgRNA Activity']
                                      .rank(pct=True))
        model = clone(base_model)
        if model_name is None:
            model_name = ' + '.join(combine_datasets)
        dataset_test_predictions = train_test_model(train_df, model_name, fold,
                                                    model, fold_test_data, X_test)
        # For consistency we return a list of len 1
        test_prediction_list.append(dataset_test_predictions)
    return test_prediction_list

# %%
train_data_names = pd.read_csv('../data/processed/train_data_names.csv').name.to_list()

# %%
train_data_list = list()
for ds in dataset_list:
    if ds.name in train_data_names:
        train_data_list.append(ds)

for ds in train_data_list:
    ds.load_data()
    ds.get_sgrnas()

# %% [markdown]
# ## Cross-Validation Iterator
#
# We'll use [StratifiedGroupKFold](https://scikit-learn.org/dev/modules/generated/sklearn.model_selection.StratifiedGroupKFold.html#sklearn.model_selection.StratifiedGroupKFold)
#
# >This cross-validation object is a variation of StratifiedKFold attempts to return stratified folds with
# > non-overlapping groups. The folds are made by preserving the percentage of samples for each class.
#
# >The same group will not appear in two different folds (the number of distinct groups has to be at least equal to
# > the number of folds).
#
# >The difference between GroupKFold and StratifiedGroupKFold is that the former attempts to create balanced folds such
# > that the number of distinct groups is approximately the same in each fold, whereas StratifiedGroupKFold attempts to
# > create folds which preserve the percentage of samples for each class as much as possible given the
# > constraint of non-overlapping groups between splits.
#
# In our case, we define each dataset as a "class", such that the datasets are approximately equally distributed across
# folds, constrained by the notion that each "group" or gene cannot appear in both the train and test set in a given fold.
#
# First, we assign sgRNAs to genes, capitalizing gene-names from the mouse libraries, so they overlap with the human annotations.
# We can see that every context sequence uniquely targets a gene in this dataset

# %%
sg_df_list = []
for ds in train_data_list:
    sg_df = ds.get_sg_df(include_group=True, include_activity=True)
    sg_df['dataset'] = ds.name
    sg_df_list.append(sg_df)
sg_df_groups = (pd.concat(sg_df_list)
                .groupby(['sgRNA Context Sequence'])
                .agg(n_conditions = ('sgRNA Context Sequence', 'count'),
                     target = ('sgRNA Target', lambda x: ', '.join(set([s.upper() for s in x if not pd.isna(s)]))))
                .reset_index())
multi_target = sg_df_groups['target'].str.contains(',').sum()
print('Context sequences with multiple targets: ' + str(multi_target))
# Out:
# Context sequences with multiple targets: 0

# %% [markdown]
# We assign context sequences without a group to their own group. Every dataset appears as both a training and testing
# dataset in every fold, except Doench2014_human Doench2014_mouse, which have fewer than 5 genes

# %%
# handle singleton case
sg_df_groups['target'] = sg_df_groups.apply(lambda row:
                                            row['target'] if (row['target'] != '') else row['sgRNA Context Sequence'],
                                            axis=1)
# Note that 'target' is not in the sg_df_list, and is coming from the sg_df_groups df
sg_df_class_groups = (pd.concat(sg_df_list)
                      .merge(sg_df_groups, how='inner', on='sgRNA Context Sequence')
                      .sort_values(['dataset', 'target'])                      
                      .reset_index(drop=True))
sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=7)
tidy_cv_list = []
for i, (train_index, test_index) in enumerate(sgkf.split(sg_df_class_groups, sg_df_class_groups.dataset,
                                                         sg_df_class_groups.target)):
    train_df = sg_df_class_groups.iloc[train_index,:].copy()
    train_df['cv'] = i
    train_df['train'] = True
    tidy_cv_list.append(train_df)
    test_df = sg_df_class_groups.iloc[test_index,:].copy()
    test_df['cv'] = i
    test_df['train'] = False
    tidy_cv_list.append(test_df)
tidy_cv_df = pd.concat(tidy_cv_list)
cv_train_data_counts = (tidy_cv_df[['cv', 'train', 'dataset']].value_counts()
                        .reset_index(name='n'))
cv_train_data_counts
# Out:
#     cv  train           dataset      n
# 0    3   True     Kim2019_train  10604
# 1    1   True     Kim2019_train  10574
# 2    4   True     Kim2019_train  10354
# 3    0   True     Kim2019_train  10267
# 4    2   True     Kim2019_train   9529
# 5    2  False     Kim2019_train   3303
# 6    0  False     Kim2019_train   2565
# 7    4  False     Kim2019_train   2478
# 8    1   True        Doench2016   2319
# 9    1  False     Kim2019_train   2258
# 10   3  False     Kim2019_train   2228
# 11   3   True        Doench2016   2209
# 12   4   True        Doench2016   2194
# 13   0   True        Doench2016   1804
# 14   2   True        Doench2016   1618
# 15   3   True  Doench2014_mouse   1169
# 16   2   True  Doench2014_mouse   1084
# 17   3   True  Doench2014_human    995
# 18   4   True  Doench2014_human    995
# 19   0   True  Doench2014_human    995
# 20   1   True  Doench2014_mouse    957
# 21   2  False        Doench2016    918
# 22   3   True          Wang2014    870
# 23   1   True          Wang2014    843
# 24   4   True          Wang2014    836
# 25   0   True          Wang2014    830
# 26   2  False  Doench2014_human    828
# 27   1   True  Doench2014_human    828
# 28   0   True  Doench2014_mouse    815
# 29   0  False        Doench2016    732
# 30   2   True          Wang2014    709
# 31   4   True  Doench2014_mouse    651
# 32   4  False  Doench2014_mouse    518
# 33   0  False  Doench2014_mouse    354
# 34   4  False        Doench2016    342
# 35   3  False        Doench2016    327
# 36   2  False          Wang2014    313
# 37   1  False        Doench2016    217
# 38   1  False  Doench2014_mouse    212
# 39   0  False          Wang2014    192
# 40   4  False          Wang2014    186
# 41   1  False          Wang2014    179
# 42   2   True  Doench2014_human    167
# 43   1  False  Doench2014_human    167
# 44   3  False          Wang2014    152
# 45   2  False  Doench2014_mouse     85

# %%
(cv_train_data_counts[['cv', 'dataset']]
 .value_counts()
 .reset_index(name='n'))
# Out:
#     cv           dataset  n
# 0    2        Doench2016  2
# 1    2  Doench2014_mouse  2
# 2    4     Kim2019_train  2
# 3    4        Doench2016  2
# 4    4  Doench2014_mouse  2
# 5    3          Wang2014  2
# 6    3     Kim2019_train  2
# 7    3        Doench2016  2
# 8    2          Wang2014  2
# 9    2     Kim2019_train  2
# 10   0  Doench2014_mouse  2
# 11   4          Wang2014  2
# 12   2  Doench2014_human  2
# 13   1          Wang2014  2
# 14   1     Kim2019_train  2
# 15   1        Doench2016  2
# 16   1  Doench2014_mouse  2
# 17   1  Doench2014_human  2
# 18   0          Wang2014  2
# 19   0     Kim2019_train  2
# 20   0        Doench2016  2
# 21   3  Doench2014_human  1
# 22   3  Doench2014_mouse  1
# 23   4  Doench2014_human  1
# 24   0  Doench2014_human  1

# %% [markdown]
# The size of the training and testing sets are approximately equal across folds,
# with training sets varying between 13,107 (fold 2) - 15,847 (fold 3) sgRNAs and testing sets varying
# between 2,707 (fold 3) - 5,447 (fold 2) sgRNAs

# %%
(tidy_cv_df[['cv','train']].value_counts()
 .reset_index(name='n')
 .sort_values(['cv', 'train']))
# Out:
#    cv  train      n
# 6   0  False   3843
# 3   0   True  14711
# 8   1  False   3033
# 1   1   True  15521
# 5   2  False   5447
# 4   2   True  13107
# 9   3  False   2707
# 0   3   True  15847
# 7   4  False   3524
# 2   4   True  15030

# %% [markdown]
# Indeed each gene target (gene) only appears in one set in each fold

# %%
(tidy_cv_df[['cv','train', 'target']].value_counts()
 .reset_index(name='n')
 .query('n > 10')
 [['cv', 'target']].value_counts()
 .reset_index(name='train_test_sum')
 .groupby('cv')
 .agg({'train_test_sum': ['max']}))
# Out:
#    train_test_sum
#               max
# cv
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %% [markdown]
# ## Train each dataset separately
# Now we'll move onto training and first we'll train each dataset separately

# %%
single_test_prediction_list = []
for fold, df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    single_test_prediction_list.extend(get_fold_predictions(fold, df))
    print('\n')

single_predictive_performance = get_predictive_performance(single_test_prediction_list)
# Out:
# Fold: 0
#
#
# Fold: 1
#
#
# Fold: 2
#
#
# Fold: 3
#
#
# Fold: 4

# %% [markdown]
# Importantly, all training datasets are successful at predicting held-out test data

# %%
plot_pearson_heatmap(single_predictive_performance)
# Out:
# <ggplot: (8766414707029)>

# %% [markdown]
# We can see that the Kim training data outperforms all the rest, but it's also quite a bit bigger than the next biggest dataset

# %%
plot_relative_performance(single_predictive_performance)
# Out:
# <ggplot: (8766419493584)>

# %% [markdown]
# ## Combining training datasets
#
# If we merge the training datasets, can we improve our performance?
# We'll merge by normalizing activity to a percent rank.

# %%
top_training_set = (single_predictive_performance.groupby('model_name')
                    .agg({'relative_performance': 'median'})
                    .reset_index()
                    .sort_values('relative_performance', ascending=False)
                    ['model_name']
                    .values[0])
print('Top training set: ' + top_training_set)
# Out:
# Top training set: Kim2019_train

# %%
combined_test_prediction_list = []
for fold, df in tidy_cv_df.groupby('cv'):
    print('Fold: '+ str(fold))
    combined_test_prediction_list.extend(get_fold_predictions(fold, df, top_training_set=top_training_set))
    print('\n')

combined_predictive_performance = get_predictive_performance(combined_test_prediction_list)
# Out:
# Fold: 0
#
#
# Fold: 1
#
#
# Fold: 2
#
#
# Fold: 3
#
#
# Fold: 4

# %%
plot_pearson_heatmap(combined_predictive_performance)
# Out:
# <ggplot: (8772468891308)>

# %%
plot_relative_performance(combined_predictive_performance)
# Out:
# <ggplot: (8772459083210)>

# %% [markdown]
# We'll keep all training sets that don't significantly reduce predictive performance, which is all training sets

# %%
ttest_list = []
reference_scores = (combined_predictive_performance
                    .loc[combined_predictive_performance['model_name'] == top_training_set, 'pearson_r'])
for model_name, training_set_df in combined_predictive_performance.groupby('model_name'):
    compare_scores = training_set_df['pearson_r']
    t, p = stats.ttest_rel(reference_scores, compare_scores)
    ttest_list.append({'model_name': model_name, 't': t, 'p': p})
ttest_df = pd.DataFrame(ttest_list)
ttest_df.sort_values('t')
# Out:
#                          model_name         t         p
# 4        Doench2016 + Kim2019_train -1.481220  0.154132
# 3  Doench2014_mouse + Kim2019_train -0.583353  0.566177
# 1  Doench2014_human + Kim2019_train -0.355333  0.726060
# 0          Wang2014 + Kim2019_train  0.415258  0.682374
# 2                     Kim2019_train       NaN       NaN

# %% [markdown]
# We'll try combining all datasets which don't significantly decrease performance

# %%
combine_datasets =  (ttest_df
    .loc[(ttest_df.t.fillna(0) < 0) | (ttest_df.p.fillna(1) > 0.05), 'model_name']
    .str.split(' \+ ', expand=True)[0])
print('Combine datasets: ' + ', '.join(combine_datasets))
# Out:
# Combine datasets: Wang2014, Doench2014_human, Kim2019_train, Doench2014_mouse, Doench2016

# %%
top_combined_test_prediction_list = []
for fold, df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    top_combined_test_prediction_list.extend(get_fold_predictions(fold, df, combine_datasets=combine_datasets,
                                                                  model_name='All train data'))
    print('\n')

top_dual_model = ttest_df.sort_values('t')['model_name'].values[0]
print('Reference model: ' + str(top_dual_model))
top_dual_prediction_list = [df for df in combined_test_prediction_list if (df.model_name == top_dual_model).all()]
top_combined_predictive_performance = get_predictive_performance(top_combined_test_prediction_list +
                                                                 top_dual_prediction_list)
# Out:
# Fold: 0
#
#
# Fold: 1
#
#
# Fold: 2
#
#
# Fold: 3
#
#
# Fold: 4
#
#
# Reference model: Doench2016 + Kim2019_train

# %%
plot_pearson_heatmap(top_combined_predictive_performance)
# Out:
# <ggplot: (8772459070763)>

# %%
plot_relative_performance(top_combined_predictive_performance)
# Out:
# <ggplot: (8772459070922)>

# %% [markdown]
# ## Sequence Model Hyperparameter Tuning
#
# Using the combined datasets, we'll try different model architectures and use hyperparameter tuning.
# For the hyperparmeter tuning, we'll use the [optuna library](https://optuna.readthedocs.io/en/stable/index.html),
# which by default uses the Tree-structured Parzen Estimator to search the hyperparameter space.

# %%
n_trials = 50

# %% [markdown]
# ### LightGBM

# %%
def lgbm_training_iteration(fold_df, train_index, test_index, base_model):
    """Train lgbm model for optuna iterations

    :param fold_df: DataFrame
    :param train_index: list-like
    :param test_index: list-like
    :param base_model: LGBMRegressor
    :return: r^2
    """
    train_df = fold_df.iloc[train_index,:].reset_index(drop=True)
    train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                  ['sgRNA Activity']
                                  .rank(pct=True))
    X_train_val = sglearn.featurize_guides(train_df['sgRNA Context Sequence']) # train and validation data
    y_train_val = train_df['sgRNA Activity']
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val,
                                                      test_size=0.1, random_state=7)
    model = clone(base_model)
    model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_val, y_val)], verbose=False)
    test_df = fold_df.iloc[test_index,:].reset_index(drop=True)
    X_test = sglearn.featurize_guides(test_df['sgRNA Context Sequence'])
    test_predictions = test_df.copy()
    test_predictions['prediction'] = model.predict(X_test)
    test_predictions['sgRNA Activity'] = (test_predictions.groupby('dataset')
                                          ['sgRNA Activity']
                                          .rank(pct=True))
    r2 = r2_score(test_predictions['sgRNA Activity'], test_predictions['prediction'])
    return r2


def get_lgbm_objective(fold_df):
    """Get objective function for training a lgbm model

    :param fold_df: DataFrame
    :return: obejctive function
    """
    def objective(trial):
        """For training set, get optimal hyperparameters for lgbm

        :param trial: optuna.trial
        :return: int, pearson correlation with held out test data
        """
        sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=7)
        num_leaves = trial.suggest_int('num_leaves', 8, 256)
        min_child_samples = trial.suggest_int('min_child_samples', 8, 256)
        model = LGBMRegressor(random_state=7, n_jobs=1, learning_rate=0.01, n_estimators=5000,
                              num_leaves=num_leaves,
                              min_child_samples=min_child_samples)
        performance = Parallel(n_jobs=5)(delayed(lgbm_training_iteration)
                                         (fold_df, train_index, test_index, model) for
                                         train_index, test_index in
                                         sgkf.split(fold_df, fold_df.dataset, fold_df.target))
        avg_performance = np.mean(performance)
        return avg_performance
    return objective

# %%
lgbm_prediction_list = []

for fold, fold_df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    fold_train_data = fold_df.query('train == True').reset_index(drop=True)
    study = optuna.create_study(direction='maximize',
                                sampler=optuna.samplers.TPESampler(seed=7)) # maximize r^2
    objective = get_lgbm_objective(fold_train_data)
    start_time = datetime.now()
    study.optimize(objective, n_trials=n_trials)
    end_time = datetime.now()
    difference = end_time - start_time
    print("Number of finished trials: {}".format(len(study.trials)))
    print("Training Time: " + str(difference))
    print("Best trial:")
    trial = study.best_trial
    print("  Value: {}".format(trial.value))
    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
    # Using optimal parameters, retrain model with full dataset
    train_df = fold_train_data.copy()
    train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                  ['sgRNA Activity']
                                  .rank(pct=True))
    X_train_val = sglearn.featurize_guides(train_df['sgRNA Context Sequence'])
    y_train_val = train_df['sgRNA Activity']
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val,
                                                      test_size=0.1, random_state=7)
    model = LGBMRegressor(random_state=7, n_jobs=8, learning_rate=0.01, n_estimators=5000,
                          **trial.params)
    model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_val, y_val)], verbose=1000)
    # Test optimal model on test data
    fold_test_data = fold_df.query('train == False').reset_index(drop=True)
    X_test = sglearn.featurize_guides(fold_test_data['sgRNA Context Sequence'])
    test_predictions = fold_test_data.copy()
    test_predictions['prediction'] = model.predict(X_test)
    test_predictions['model_name'] = 'All train data + LGBM + TPE' + str(n_trials)
    test_predictions['fold'] = fold
    lgbm_prediction_list.append(test_predictions)
# Out:
# [I 2021-04-11 22:22:04,042] A new study created in memory with name: no-name-cd0b5fbb-5271-4948-a107-38b07c5b39a7
# [I 2021-04-11 22:22:28,149] Trial 0 finished with value: 0.4675419868118217 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:22:48,659] Trial 1 finished with value: 0.4638737194519386 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:23:09,028] Trial 2 finished with value: 0.46723959849870444 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:23:28,830] Trial 3 finished with value: 0.45097946771857894 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:23:50,168] Trial 4 finished with value: 0.4667808761921817 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:24:10,490] Trial 5 finished with value: 0.46483313687164307 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:24:30,492] Trial 6 finished with value: 0.4543602650068676 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:24:53,053] Trial 7 finished with value: 0.4657230281110314 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:25:13,484] Trial 8 finished with value: 0.464297470554239 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:25:34,781] Trial 9 finished with value: 0.4287039046367654 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.4675419868118217.
# [I 2021-04-11 22:25:55,248] Trial 10 finished with value: 0.4677150330835981 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 10 with value: 0.4677150330835981.
# [I 2021-04-11 22:26:15,195] Trial 11 finished with value: 0.4576057958002802 and parameters: {'num_leaves': 10, 'min_child_samples': 74}. Best is trial 10 with value: 0.4677150330835981.
# [I 2021-04-11 22:26:34,793] Trial 12 finished with value: 0.4622807333606863 and parameters: {'num_leaves': 14, 'min_child_samples': 82}. Best is trial 10 with value: 0.4677150330835981.
# [I 2021-04-11 22:26:55,131] Trial 13 finished with value: 0.4678860120352201 and parameters: {'num_leaves': 37, 'min_child_samples': 167}. Best is trial 13 with value: 0.4678860120352201.
# [I 2021-04-11 22:27:15,100] Trial 14 finished with value: 0.46851923248057065 and parameters: {'num_leaves': 41, 'min_child_samples': 74}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:27:35,900] Trial 15 finished with value: 0.46624161802750075 and parameters: {'num_leaves': 50, 'min_child_samples': 167}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:27:56,855] Trial 16 finished with value: 0.46531077838607615 and parameters: {'num_leaves': 161, 'min_child_samples': 252}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:28:17,569] Trial 17 finished with value: 0.46734200210621635 and parameters: {'num_leaves': 46, 'min_child_samples': 102}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:28:37,718] Trial 18 finished with value: 0.46137044288631257 and parameters: {'num_leaves': 99, 'min_child_samples': 56}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:28:57,443] Trial 19 finished with value: 0.46569267143200455 and parameters: {'num_leaves': 216, 'min_child_samples': 171}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:29:17,089] Trial 20 finished with value: 0.46466325392984115 and parameters: {'num_leaves': 36, 'min_child_samples': 49}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:29:36,320] Trial 21 finished with value: 0.4570345946423265 and parameters: {'num_leaves': 9, 'min_child_samples': 100}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:29:55,018] Trial 22 finished with value: 0.46511222203185865 and parameters: {'num_leaves': 28, 'min_child_samples': 50}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:30:15,472] Trial 23 finished with value: 0.4666696439845509 and parameters: {'num_leaves': 70, 'min_child_samples': 161}. Best is trial 14 with value: 0.46851923248057065.
# [I 2021-04-11 22:30:35,414] Trial 24 finished with value: 0.46942117794503185 and parameters: {'num_leaves': 36, 'min_child_samples': 102}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:30:54,820] Trial 25 finished with value: 0.4668802734649432 and parameters: {'num_leaves': 51, 'min_child_samples': 146}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:31:15,912] Trial 26 finished with value: 0.46484644987158924 and parameters: {'num_leaves': 83, 'min_child_samples': 111}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:31:36,919] Trial 27 finished with value: 0.4616077386470939 and parameters: {'num_leaves': 138, 'min_child_samples': 90}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:31:57,317] Trial 28 finished with value: 0.457748099604958 and parameters: {'num_leaves': 8, 'min_child_samples': 120}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:32:17,565] Trial 29 finished with value: 0.46137388841571225 and parameters: {'num_leaves': 91, 'min_child_samples': 64}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:32:41,166] Trial 30 finished with value: 0.46798207457491936 and parameters: {'num_leaves': 32, 'min_child_samples': 215}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:33:03,564] Trial 31 finished with value: 0.4659435024159132 and parameters: {'num_leaves': 38, 'min_child_samples': 215}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:33:23,659] Trial 32 finished with value: 0.4650392173050705 and parameters: {'num_leaves': 58, 'min_child_samples': 189}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:33:45,204] Trial 33 finished with value: 0.46663687699695783 and parameters: {'num_leaves': 29, 'min_child_samples': 221}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:34:05,306] Trial 34 finished with value: 0.4676147184965009 and parameters: {'num_leaves': 17, 'min_child_samples': 191}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:34:25,431] Trial 35 finished with value: 0.4643198193812445 and parameters: {'num_leaves': 117, 'min_child_samples': 253}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:34:45,362] Trial 36 finished with value: 0.4644787839869924 and parameters: {'num_leaves': 64, 'min_child_samples': 145}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:35:04,963] Trial 37 finished with value: 0.4683819827265044 and parameters: {'num_leaves': 40, 'min_child_samples': 131}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:35:25,651] Trial 38 finished with value: 0.4678168750320454 and parameters: {'num_leaves': 46, 'min_child_samples': 130}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:35:44,513] Trial 39 finished with value: 0.46175709210422494 and parameters: {'num_leaves': 20, 'min_child_samples': 37}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:36:05,140] Trial 40 finished with value: 0.46493548400381446 and parameters: {'num_leaves': 111, 'min_child_samples': 134}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:36:26,174] Trial 41 finished with value: 0.46668953716299055 and parameters: {'num_leaves': 73, 'min_child_samples': 156}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:36:47,958] Trial 42 finished with value: 0.46633951029299914 and parameters: {'num_leaves': 37, 'min_child_samples': 235}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:37:08,406] Trial 43 finished with value: 0.463625724095611 and parameters: {'num_leaves': 60, 'min_child_samples': 99}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:37:27,706] Trial 44 finished with value: 0.4686834907182182 and parameters: {'num_leaves': 25, 'min_child_samples': 113}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:37:48,541] Trial 45 finished with value: 0.4683351586919023 and parameters: {'num_leaves': 25, 'min_child_samples': 122}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:38:09,078] Trial 46 finished with value: 0.4660940139562763 and parameters: {'num_leaves': 19, 'min_child_samples': 118}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:38:28,405] Trial 47 finished with value: 0.468312923771734 and parameters: {'num_leaves': 50, 'min_child_samples': 70}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:38:48,219] Trial 48 finished with value: 0.46053779189751437 and parameters: {'num_leaves': 83, 'min_child_samples': 90}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:39:08,129] Trial 49 finished with value: 0.46836243117753984 and parameters: {'num_leaves': 22, 'min_child_samples': 110}. Best is trial 24 with value: 0.46942117794503185.
# [I 2021-04-11 22:39:20,711] A new study created in memory with name: no-name-5b25611e-853c-4798-b45f-1f6f4a6e6a6f
# [I 2021-04-11 22:39:41,171] Trial 0 finished with value: 0.44749877059942034 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:40:01,774] Trial 1 finished with value: 0.4456301004496062 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:40:22,345] Trial 2 finished with value: 0.44536508919079065 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:40:42,321] Trial 3 finished with value: 0.4298862384748928 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:41:03,004] Trial 4 finished with value: 0.44597787566068786 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:41:23,998] Trial 5 finished with value: 0.44567139954592994 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:41:48,458] Trial 6 finished with value: 0.43289233135678773 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:42:09,232] Trial 7 finished with value: 0.4448688986997146 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:42:30,001] Trial 8 finished with value: 0.44704142173684663 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:42:52,438] Trial 9 finished with value: 0.4124930925116043 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:43:11,296] Trial 10 finished with value: 0.4443194716642965 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:43:31,049] Trial 11 finished with value: 0.43860013285541355 and parameters: {'num_leaves': 10, 'min_child_samples': 92}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:43:52,716] Trial 12 finished with value: 0.44645379003047925 and parameters: {'num_leaves': 40, 'min_child_samples': 170}. Best is trial 0 with value: 0.44749877059942034.
# [I 2021-04-11 22:44:13,821] Trial 13 finished with value: 0.4481395600501429 and parameters: {'num_leaves': 51, 'min_child_samples': 93}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:44:34,868] Trial 14 finished with value: 0.4379440484186234 and parameters: {'num_leaves': 8, 'min_child_samples': 249}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:44:55,125] Trial 15 finished with value: 0.4354702259465122 and parameters: {'num_leaves': 152, 'min_child_samples': 70}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:45:15,183] Trial 16 finished with value: 0.4436160384408874 and parameters: {'num_leaves': 48, 'min_child_samples': 49}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:45:37,437] Trial 17 finished with value: 0.446004133188064 and parameters: {'num_leaves': 203, 'min_child_samples': 163}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:45:57,282] Trial 18 finished with value: 0.44568299555728996 and parameters: {'num_leaves': 17, 'min_child_samples': 110}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:46:20,788] Trial 19 finished with value: 0.4470983961885001 and parameters: {'num_leaves': 100, 'min_child_samples': 219}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:46:42,823] Trial 20 finished with value: 0.44790880032227126 and parameters: {'num_leaves': 51, 'min_child_samples': 194}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:47:04,482] Trial 21 finished with value: 0.4464447439708212 and parameters: {'num_leaves': 42, 'min_child_samples': 197}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:47:27,298] Trial 22 finished with value: 0.4447630108597217 and parameters: {'num_leaves': 72, 'min_child_samples': 256}. Best is trial 13 with value: 0.4481395600501429.
# [I 2021-04-11 22:47:49,712] Trial 23 finished with value: 0.44853595735492047 and parameters: {'num_leaves': 32, 'min_child_samples': 165}. Best is trial 23 with value: 0.44853595735492047.
# [I 2021-04-11 22:48:10,714] Trial 24 finished with value: 0.4455798949416872 and parameters: {'num_leaves': 55, 'min_child_samples': 165}. Best is trial 23 with value: 0.44853595735492047.
# [I 2021-04-11 22:48:32,087] Trial 25 finished with value: 0.44721172323383396 and parameters: {'num_leaves': 99, 'min_child_samples': 148}. Best is trial 23 with value: 0.44853595735492047.
# [I 2021-04-11 22:48:54,366] Trial 26 finished with value: 0.4496320019733848 and parameters: {'num_leaves': 27, 'min_child_samples': 106}. Best is trial 26 with value: 0.4496320019733848.
# [I 2021-04-11 22:49:15,487] Trial 27 finished with value: 0.4493613296078859 and parameters: {'num_leaves': 30, 'min_child_samples': 104}. Best is trial 26 with value: 0.4496320019733848.
# [I 2021-04-11 22:49:36,267] Trial 28 finished with value: 0.4361455907858428 and parameters: {'num_leaves': 8, 'min_child_samples': 111}. Best is trial 26 with value: 0.4496320019733848.
# [I 2021-04-11 22:49:56,332] Trial 29 finished with value: 0.44390148260809353 and parameters: {'num_leaves': 26, 'min_child_samples': 51}. Best is trial 26 with value: 0.4496320019733848.
# [I 2021-04-11 22:50:17,664] Trial 30 finished with value: 0.45006187788956586 and parameters: {'num_leaves': 30, 'min_child_samples': 123}. Best is trial 30 with value: 0.45006187788956586.
# [I 2021-04-11 22:50:38,717] Trial 31 finished with value: 0.45101188906031525 and parameters: {'num_leaves': 33, 'min_child_samples': 124}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:50:59,820] Trial 32 finished with value: 0.4361926921760462 and parameters: {'num_leaves': 8, 'min_child_samples': 93}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:51:20,908] Trial 33 finished with value: 0.4495415735920023 and parameters: {'num_leaves': 27, 'min_child_samples': 122}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:51:42,587] Trial 34 finished with value: 0.44667846380617765 and parameters: {'num_leaves': 67, 'min_child_samples': 129}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:52:03,225] Trial 35 finished with value: 0.44553342784716854 and parameters: {'num_leaves': 90, 'min_child_samples': 140}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:52:24,644] Trial 36 finished with value: 0.4478983509967419 and parameters: {'num_leaves': 20, 'min_child_samples': 126}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:52:45,350] Trial 37 finished with value: 0.44643171002789506 and parameters: {'num_leaves': 124, 'min_child_samples': 154}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:53:07,107] Trial 38 finished with value: 0.44648454860048287 and parameters: {'num_leaves': 84, 'min_child_samples': 180}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:53:26,859] Trial 39 finished with value: 0.4473666496246517 and parameters: {'num_leaves': 38, 'min_child_samples': 76}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:53:47,831] Trial 40 finished with value: 0.4474751072490334 and parameters: {'num_leaves': 65, 'min_child_samples': 139}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:54:09,648] Trial 41 finished with value: 0.4483850824850082 and parameters: {'num_leaves': 28, 'min_child_samples': 107}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:54:29,861] Trial 42 finished with value: 0.44608159161884764 and parameters: {'num_leaves': 18, 'min_child_samples': 118}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:54:50,376] Trial 43 finished with value: 0.4468649034060911 and parameters: {'num_leaves': 36, 'min_child_samples': 103}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:55:10,522] Trial 44 finished with value: 0.4445361446397872 and parameters: {'num_leaves': 19, 'min_child_samples': 64}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:55:32,061] Trial 45 finished with value: 0.4476982377203935 and parameters: {'num_leaves': 57, 'min_child_samples': 97}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:55:53,801] Trial 46 finished with value: 0.44889656626996055 and parameters: {'num_leaves': 44, 'min_child_samples': 120}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:56:14,983] Trial 47 finished with value: 0.441025696678059 and parameters: {'num_leaves': 148, 'min_child_samples': 80}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:56:35,879] Trial 48 finished with value: 0.44826729253971714 and parameters: {'num_leaves': 27, 'min_child_samples': 133}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:56:57,178] Trial 49 finished with value: 0.44407552399210104 and parameters: {'num_leaves': 77, 'min_child_samples': 85}. Best is trial 31 with value: 0.45101188906031525.
# [I 2021-04-11 22:57:08,912] A new study created in memory with name: no-name-531585e6-6a92-405b-a04f-1287d6886934
# [I 2021-04-11 22:57:26,478] Trial 0 finished with value: 0.4556383426614599 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.4556383426614599.
# [I 2021-04-11 22:57:46,095] Trial 1 finished with value: 0.4590367500617595 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 22:58:03,638] Trial 2 finished with value: 0.4558458134477025 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 22:58:23,542] Trial 3 finished with value: 0.4410883526255935 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 22:58:41,332] Trial 4 finished with value: 0.4554403359227651 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 22:58:59,731] Trial 5 finished with value: 0.45658190698562445 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 22:59:18,638] Trial 6 finished with value: 0.44589745258140534 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 22:59:36,748] Trial 7 finished with value: 0.45631704106648163 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 22:59:54,407] Trial 8 finished with value: 0.45280093102092733 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:00:14,852] Trial 9 finished with value: 0.42203836042207044 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:00:34,150] Trial 10 finished with value: 0.45209001664021037 and parameters: {'num_leaves': 170, 'min_child_samples': 78}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:00:52,821] Trial 11 finished with value: 0.45474588530991833 and parameters: {'num_leaves': 179, 'min_child_samples': 193}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:01:11,507] Trial 12 finished with value: 0.45413155949473316 and parameters: {'num_leaves': 188, 'min_child_samples': 246}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:01:30,639] Trial 13 finished with value: 0.45587920520524 and parameters: {'num_leaves': 138, 'min_child_samples': 180}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:01:50,027] Trial 14 finished with value: 0.453566031467429 and parameters: {'num_leaves': 205, 'min_child_samples': 219}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:02:07,437] Trial 15 finished with value: 0.452742375669691 and parameters: {'num_leaves': 150, 'min_child_samples': 167}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:02:26,237] Trial 16 finished with value: 0.45416384785672675 and parameters: {'num_leaves': 106, 'min_child_samples': 253}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:02:44,743] Trial 17 finished with value: 0.45745533778851166 and parameters: {'num_leaves': 212, 'min_child_samples': 160}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:03:04,042] Trial 18 finished with value: 0.4551979259784139 and parameters: {'num_leaves': 220, 'min_child_samples': 95}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:03:22,988] Trial 19 finished with value: 0.4559112967628418 and parameters: {'num_leaves': 108, 'min_child_samples': 164}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:03:40,185] Trial 20 finished with value: 0.45437159084345125 and parameters: {'num_leaves': 20, 'min_child_samples': 67}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:03:59,453] Trial 21 finished with value: 0.4541181883358011 and parameters: {'num_leaves': 156, 'min_child_samples': 203}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:04:17,118] Trial 22 finished with value: 0.45492210315109577 and parameters: {'num_leaves': 213, 'min_child_samples': 155}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:04:35,782] Trial 23 finished with value: 0.45587880236040446 and parameters: {'num_leaves': 195, 'min_child_samples': 223}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:04:53,973] Trial 24 finished with value: 0.45457652709287694 and parameters: {'num_leaves': 231, 'min_child_samples': 185}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:05:12,235] Trial 25 finished with value: 0.4547659068691541 and parameters: {'num_leaves': 173, 'min_child_samples': 107}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:05:30,833] Trial 26 finished with value: 0.45679404548796293 and parameters: {'num_leaves': 252, 'min_child_samples': 214}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:05:48,510] Trial 27 finished with value: 0.4535523422015103 and parameters: {'num_leaves': 255, 'min_child_samples': 152}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:06:07,660] Trial 28 finished with value: 0.4571411237531116 and parameters: {'num_leaves': 241, 'min_child_samples': 174}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:06:25,371] Trial 29 finished with value: 0.4539850429852793 and parameters: {'num_leaves': 39, 'min_child_samples': 169}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:06:45,460] Trial 30 finished with value: 0.45619559052884656 and parameters: {'num_leaves': 229, 'min_child_samples': 135}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:07:06,546] Trial 31 finished with value: 0.45623381678613156 and parameters: {'num_leaves': 247, 'min_child_samples': 189}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:07:25,152] Trial 32 finished with value: 0.45658190698562445 and parameters: {'num_leaves': 242, 'min_child_samples': 208}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:07:43,265] Trial 33 finished with value: 0.45394380446643356 and parameters: {'num_leaves': 117, 'min_child_samples': 175}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:08:01,729] Trial 34 finished with value: 0.45292554573614546 and parameters: {'num_leaves': 254, 'min_child_samples': 232}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:08:20,228] Trial 35 finished with value: 0.45518125250272046 and parameters: {'num_leaves': 256, 'min_child_samples': 144}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:08:38,807] Trial 36 finished with value: 0.4551064277739007 and parameters: {'num_leaves': 88, 'min_child_samples': 199}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:08:58,138] Trial 37 finished with value: 0.4573235846361158 and parameters: {'num_leaves': 124, 'min_child_samples': 120}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:09:16,213] Trial 38 finished with value: 0.455313345848258 and parameters: {'num_leaves': 134, 'min_child_samples': 123}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:09:34,467] Trial 39 finished with value: 0.45455637815798616 and parameters: {'num_leaves': 125, 'min_child_samples': 105}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:09:52,621] Trial 40 finished with value: 0.4537083675825645 and parameters: {'num_leaves': 91, 'min_child_samples': 122}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:10:11,370] Trial 41 finished with value: 0.45677340506535735 and parameters: {'num_leaves': 67, 'min_child_samples': 153}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:10:30,758] Trial 42 finished with value: 0.45508571650657254 and parameters: {'num_leaves': 147, 'min_child_samples': 217}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:10:47,955] Trial 43 finished with value: 0.4558458134477025 and parameters: {'num_leaves': 123, 'min_child_samples': 142}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:11:06,405] Trial 44 finished with value: 0.4553226644673828 and parameters: {'num_leaves': 165, 'min_child_samples': 187}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:11:24,661] Trial 45 finished with value: 0.45080016533445877 and parameters: {'num_leaves': 96, 'min_child_samples': 54}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:11:42,865] Trial 46 finished with value: 0.454873155453227 and parameters: {'num_leaves': 232, 'min_child_samples': 238}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:12:00,648] Trial 47 finished with value: 0.45394380446643356 and parameters: {'num_leaves': 204, 'min_child_samples': 175}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:12:19,194] Trial 48 finished with value: 0.4565640673120911 and parameters: {'num_leaves': 116, 'min_child_samples': 161}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:12:37,211] Trial 49 finished with value: 0.4554403359227651 and parameters: {'num_leaves': 139, 'min_child_samples': 132}. Best is trial 1 with value: 0.4590367500617595.
# [I 2021-04-11 23:12:49,484] A new study created in memory with name: no-name-0a2fec22-9fc3-498c-bfe7-f5ed9fbed2c1
# [I 2021-04-11 23:13:12,920] Trial 0 finished with value: 0.45528262105050443 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:13:34,924] Trial 1 finished with value: 0.452293593821941 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:13:57,102] Trial 2 finished with value: 0.45096243039725936 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:14:18,889] Trial 3 finished with value: 0.4371010234656148 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:14:41,308] Trial 4 finished with value: 0.45083919547640516 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:15:04,742] Trial 5 finished with value: 0.4519680169583789 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:15:26,283] Trial 6 finished with value: 0.4408330909117352 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:15:49,676] Trial 7 finished with value: 0.45110224285284106 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:16:11,294] Trial 8 finished with value: 0.4513717221020678 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:16:34,703] Trial 9 finished with value: 0.41712048064656637 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:16:55,863] Trial 10 finished with value: 0.4516812859011791 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:17:18,844] Trial 11 finished with value: 0.44719567440686275 and parameters: {'num_leaves': 10, 'min_child_samples': 192}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:17:41,817] Trial 12 finished with value: 0.45212040152573474 and parameters: {'num_leaves': 169, 'min_child_samples': 184}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:18:06,260] Trial 13 finished with value: 0.45272179612799573 and parameters: {'num_leaves': 37, 'min_child_samples': 253}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:18:30,033] Trial 14 finished with value: 0.45295711460140675 and parameters: {'num_leaves': 30, 'min_child_samples': 253}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:18:52,917] Trial 15 finished with value: 0.44447676304656386 and parameters: {'num_leaves': 8, 'min_child_samples': 256}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:19:15,657] Trial 16 finished with value: 0.45261484180991063 and parameters: {'num_leaves': 48, 'min_child_samples': 226}. Best is trial 0 with value: 0.45528262105050443.
# [I 2021-04-11 23:19:38,889] Trial 17 finished with value: 0.45561379147503145 and parameters: {'num_leaves': 23, 'min_child_samples': 159}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:20:02,251] Trial 18 finished with value: 0.45294488659271825 and parameters: {'num_leaves': 150, 'min_child_samples': 162}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:20:26,849] Trial 19 finished with value: 0.45016246198444854 and parameters: {'num_leaves': 98, 'min_child_samples': 87}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:20:48,748] Trial 20 finished with value: 0.4513472783740896 and parameters: {'num_leaves': 212, 'min_child_samples': 161}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:21:11,672] Trial 21 finished with value: 0.4457496862368801 and parameters: {'num_leaves': 9, 'min_child_samples': 225}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:21:35,260] Trial 22 finished with value: 0.4521476962287677 and parameters: {'num_leaves': 28, 'min_child_samples': 255}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:21:58,914] Trial 23 finished with value: 0.4538855050359789 and parameters: {'num_leaves': 53, 'min_child_samples': 161}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:22:21,064] Trial 24 finished with value: 0.4543794079910327 and parameters: {'num_leaves': 55, 'min_child_samples': 105}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:22:43,073] Trial 25 finished with value: 0.44875191507353057 and parameters: {'num_leaves': 13, 'min_child_samples': 103}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:23:05,513] Trial 26 finished with value: 0.45022046256464965 and parameters: {'num_leaves': 76, 'min_child_samples': 58}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:23:27,637] Trial 27 finished with value: 0.4520650067561446 and parameters: {'num_leaves': 62, 'min_child_samples': 145}. Best is trial 17 with value: 0.45561379147503145.
# [I 2021-04-11 23:23:50,984] Trial 28 finished with value: 0.4564543599690311 and parameters: {'num_leaves': 44, 'min_child_samples': 105}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:24:13,947] Trial 29 finished with value: 0.45287979273917395 and parameters: {'num_leaves': 99, 'min_child_samples': 200}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:24:36,078] Trial 30 finished with value: 0.4518406102819319 and parameters: {'num_leaves': 123, 'min_child_samples': 173}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:24:59,145] Trial 31 finished with value: 0.4561175220720095 and parameters: {'num_leaves': 39, 'min_child_samples': 112}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:25:20,350] Trial 32 finished with value: 0.4516052777402155 and parameters: {'num_leaves': 35, 'min_child_samples': 61}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:25:41,876] Trial 33 finished with value: 0.4547499588393865 and parameters: {'num_leaves': 42, 'min_child_samples': 123}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:26:04,642] Trial 34 finished with value: 0.45510090558749694 and parameters: {'num_leaves': 24, 'min_child_samples': 143}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:26:27,220] Trial 35 finished with value: 0.4502216380533386 and parameters: {'num_leaves': 88, 'min_child_samples': 107}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:26:50,224] Trial 36 finished with value: 0.45353387329878164 and parameters: {'num_leaves': 19, 'min_child_samples': 137}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:27:12,937] Trial 37 finished with value: 0.45302015923410266 and parameters: {'num_leaves': 66, 'min_child_samples': 88}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:27:36,668] Trial 38 finished with value: 0.45306295807079316 and parameters: {'num_leaves': 41, 'min_child_samples': 212}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:27:58,015] Trial 39 finished with value: 0.4498813072951441 and parameters: {'num_leaves': 72, 'min_child_samples': 45}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:28:20,791] Trial 40 finished with value: 0.45328185637114693 and parameters: {'num_leaves': 110, 'min_child_samples': 179}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:28:42,927] Trial 41 finished with value: 0.4551440097440295 and parameters: {'num_leaves': 21, 'min_child_samples': 151}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:29:06,233] Trial 42 finished with value: 0.44728510593454385 and parameters: {'num_leaves': 8, 'min_child_samples': 122}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:29:28,531] Trial 43 finished with value: 0.4548882689645886 and parameters: {'num_leaves': 21, 'min_child_samples': 152}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:29:51,925] Trial 44 finished with value: 0.45588749250473015 and parameters: {'num_leaves': 46, 'min_child_samples': 129}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:30:13,883] Trial 45 finished with value: 0.45135841529499177 and parameters: {'num_leaves': 85, 'min_child_samples': 130}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:30:36,379] Trial 46 finished with value: 0.4555783089759964 and parameters: {'num_leaves': 50, 'min_child_samples': 114}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:30:58,151] Trial 47 finished with value: 0.45449280122953983 and parameters: {'num_leaves': 49, 'min_child_samples': 95}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:31:20,864] Trial 48 finished with value: 0.45337193184604185 and parameters: {'num_leaves': 60, 'min_child_samples': 115}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:31:42,977] Trial 49 finished with value: 0.45199311244022644 and parameters: {'num_leaves': 42, 'min_child_samples': 70}. Best is trial 28 with value: 0.4564543599690311.
# [I 2021-04-11 23:31:56,156] A new study created in memory with name: no-name-8c8f8211-5260-4ee5-a262-15dea6b91224
# [I 2021-04-11 23:32:18,002] Trial 0 finished with value: 0.454847533132663 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.454847533132663.
# [I 2021-04-11 23:32:40,374] Trial 1 finished with value: 0.454922353238718 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:33:02,675] Trial 2 finished with value: 0.4533136929917029 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:33:24,264] Trial 3 finished with value: 0.43959017101093745 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:33:46,368] Trial 4 finished with value: 0.45303940598139913 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:34:07,889] Trial 5 finished with value: 0.4532977982945117 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:34:28,912] Trial 6 finished with value: 0.441197099169499 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:34:50,721] Trial 7 finished with value: 0.4511623764597351 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:35:11,791] Trial 8 finished with value: 0.4523220298254925 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:35:33,911] Trial 9 finished with value: 0.41729896718477183 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:35:54,892] Trial 10 finished with value: 0.4497156340769809 and parameters: {'num_leaves': 170, 'min_child_samples': 78}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:36:15,893] Trial 11 finished with value: 0.44965071634035264 and parameters: {'num_leaves': 10, 'min_child_samples': 192}. Best is trial 1 with value: 0.454922353238718.
# [I 2021-04-11 23:36:39,049] Trial 12 finished with value: 0.4561738345807559 and parameters: {'num_leaves': 23, 'min_child_samples': 184}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:37:01,642] Trial 13 finished with value: 0.4515589216000551 and parameters: {'num_leaves': 37, 'min_child_samples': 253}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:37:23,070] Trial 14 finished with value: 0.4525898751114733 and parameters: {'num_leaves': 130, 'min_child_samples': 168}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:37:45,495] Trial 15 finished with value: 0.4522539937835285 and parameters: {'num_leaves': 201, 'min_child_samples': 170}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:38:07,367] Trial 16 finished with value: 0.4526665309104462 and parameters: {'num_leaves': 118, 'min_child_samples': 90}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:38:30,292] Trial 17 finished with value: 0.45196090889372426 and parameters: {'num_leaves': 155, 'min_child_samples': 235}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:38:51,117] Trial 18 finished with value: 0.45222307011668955 and parameters: {'num_leaves': 223, 'min_child_samples': 173}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:39:13,454] Trial 19 finished with value: 0.4542569703678662 and parameters: {'num_leaves': 41, 'min_child_samples': 222}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:39:33,877] Trial 20 finished with value: 0.4474022564189567 and parameters: {'num_leaves': 10, 'min_child_samples': 155}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:39:55,491] Trial 21 finished with value: 0.4539770365365694 and parameters: {'num_leaves': 29, 'min_child_samples': 196}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:40:16,763] Trial 22 finished with value: 0.4518826524706225 and parameters: {'num_leaves': 92, 'min_child_samples': 256}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:40:38,945] Trial 23 finished with value: 0.45496728000181974 and parameters: {'num_leaves': 55, 'min_child_samples': 194}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:41:01,494] Trial 24 finished with value: 0.45486778928412963 and parameters: {'num_leaves': 55, 'min_child_samples': 181}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:41:23,503] Trial 25 finished with value: 0.4507600265293961 and parameters: {'num_leaves': 108, 'min_child_samples': 107}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:41:45,801] Trial 26 finished with value: 0.45462432650341417 and parameters: {'num_leaves': 58, 'min_child_samples': 152}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:42:07,839] Trial 27 finished with value: 0.45319586097823733 and parameters: {'num_leaves': 76, 'min_child_samples': 218}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:42:29,675] Trial 28 finished with value: 0.44870554171365046 and parameters: {'num_leaves': 9, 'min_child_samples': 183}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:42:51,258] Trial 29 finished with value: 0.452445933641637 and parameters: {'num_leaves': 21, 'min_child_samples': 214}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:43:12,939] Trial 30 finished with value: 0.4511623764597351 and parameters: {'num_leaves': 149, 'min_child_samples': 234}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:43:34,345] Trial 31 finished with value: 0.4528319673303212 and parameters: {'num_leaves': 53, 'min_child_samples': 185}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:43:55,922] Trial 32 finished with value: 0.453903021786357 and parameters: {'num_leaves': 47, 'min_child_samples': 155}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:44:17,240] Trial 33 finished with value: 0.4533240310773488 and parameters: {'num_leaves': 90, 'min_child_samples': 206}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:44:38,629] Trial 34 finished with value: 0.4533231846374539 and parameters: {'num_leaves': 69, 'min_child_samples': 132}. Best is trial 12 with value: 0.4561738345807559.
# [I 2021-04-11 23:45:00,676] Trial 35 finished with value: 0.4565554217523008 and parameters: {'num_leaves': 27, 'min_child_samples': 179}. Best is trial 35 with value: 0.4565554217523008.
# [I 2021-04-11 23:45:22,131] Trial 36 finished with value: 0.45430577537424927 and parameters: {'num_leaves': 24, 'min_child_samples': 199}. Best is trial 35 with value: 0.4565554217523008.
# [I 2021-04-11 23:45:43,725] Trial 37 finished with value: 0.45694556117753404 and parameters: {'num_leaves': 31, 'min_child_samples': 138}. Best is trial 37 with value: 0.45694556117753404.
# [I 2021-04-11 23:46:04,477] Trial 38 finished with value: 0.4553011815586843 and parameters: {'num_leaves': 29, 'min_child_samples': 143}. Best is trial 37 with value: 0.45694556117753404.
# [I 2021-04-11 23:46:25,295] Trial 39 finished with value: 0.45623302976538793 and parameters: {'num_leaves': 35, 'min_child_samples': 105}. Best is trial 37 with value: 0.45694556117753404.
# [I 2021-04-11 23:46:45,557] Trial 40 finished with value: 0.4474442625573717 and parameters: {'num_leaves': 19, 'min_child_samples': 66}. Best is trial 37 with value: 0.45694556117753404.
# [I 2021-04-11 23:47:05,920] Trial 41 finished with value: 0.45564022557862727 and parameters: {'num_leaves': 31, 'min_child_samples': 115}. Best is trial 37 with value: 0.45694556117753404.
# [I 2021-04-11 23:47:26,719] Trial 42 finished with value: 0.4553717062985849 and parameters: {'num_leaves': 41, 'min_child_samples': 105}. Best is trial 37 with value: 0.45694556117753404.
# [I 2021-04-11 23:47:46,954] Trial 43 finished with value: 0.44127055722781944 and parameters: {'num_leaves': 10, 'min_child_samples': 62}. Best is trial 37 with value: 0.45694556117753404.
# [I 2021-04-11 23:48:07,875] Trial 44 finished with value: 0.45525605607476194 and parameters: {'num_leaves': 35, 'min_child_samples': 118}. Best is trial 37 with value: 0.45694556117753404.
# [I 2021-04-11 23:48:28,056] Trial 45 finished with value: 0.45098492717065436 and parameters: {'num_leaves': 16, 'min_child_samples': 95}. Best is trial 37 with value: 0.45694556117753404.
# [I 2021-04-11 23:48:49,949] Trial 46 finished with value: 0.45793504127719825 and parameters: {'num_leaves': 45, 'min_child_samples': 119}. Best is trial 46 with value: 0.45793504127719825.
# [I 2021-04-11 23:49:11,958] Trial 47 finished with value: 0.45498883579233507 and parameters: {'num_leaves': 63, 'min_child_samples': 130}. Best is trial 46 with value: 0.45793504127719825.
# [I 2021-04-11 23:49:34,156] Trial 48 finished with value: 0.4533171840121512 and parameters: {'num_leaves': 85, 'min_child_samples': 146}. Best is trial 46 with value: 0.45793504127719825.
# [I 2021-04-11 23:49:54,305] Trial 49 finished with value: 0.45212641117914065 and parameters: {'num_leaves': 45, 'min_child_samples': 51}. Best is trial 46 with value: 0.45793504127719825.
# Fold: 0
# Number of finished trials: 50
# Training Time: 0:17:04.087276
# Best trial:
#   Value: 0.46942117794503185
#   Params:
#     num_leaves: 36
#     min_child_samples: 102
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.0439841
# Early stopping, best iteration is:
# [1892]	valid_0's l2: 0.0427905
# Fold: 1
# Number of finished trials: 50
# Training Time: 0:17:36.466214
# Best trial:
#   Value: 0.45101188906031525
#   Params:
#     num_leaves: 33
#     min_child_samples: 124
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.0457402
# Early stopping, best iteration is:
# [1366]	valid_0's l2: 0.0447963
# Fold: 2
# Number of finished trials: 50
# Training Time: 0:15:28.298828
# Best trial:
#   Value: 0.4590367500617595
#   Params:
#     num_leaves: 117
#     min_child_samples: 188
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.0425664
# Early stopping, best iteration is:
# [1409]	valid_0's l2: 0.0417175
# Fold: 3
# Number of finished trials: 50
# Training Time: 0:18:53.491689
# Best trial:
#   Value: 0.4564543599690311
#   Params:
#     num_leaves: 44
#     min_child_samples: 105
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.0440547
# Early stopping, best iteration is:
# [1684]	valid_0's l2: 0.043044
# Fold: 4
# Number of finished trials: 50
# Training Time: 0:17:58.146656
# Best trial:
#   Value: 0.45793504127719825
#   Params:
#     num_leaves: 45
#     min_child_samples: 119
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.04521
# Early stopping, best iteration is:
# [1454]	valid_0's l2: 0.044551

# %%
lgbm_predictive_performance = get_predictive_performance(top_combined_test_prediction_list +
                                                         lgbm_prediction_list)

# %%
plot_pearson_heatmap(lgbm_predictive_performance)
# Out:
# <ggplot: (8772433603943)>

# %%
plot_relative_performance(lgbm_predictive_performance)
# Out:
# <ggplot: (8772475296503)>

# %% [markdown]
# ### Keras Convolutional Neural Network

# %%
def get_cnn(n_conv_layers, filters_per_conv, filter_len,
            nodes_per_dense, dense_dropout_rate, n_dense_layers=1,
            input_shape=(30, 4), activation='relu', initializer='he_uniform',
            pool_size=2, loss='mse', optimizer='Adam'):
    model = keras.models.Sequential()
    model.add(keras.layers.InputLayer(input_shape=input_shape))
    for _ in range(n_conv_layers):
        model.add(keras.layers.Conv1D(filters=filters_per_conv, kernel_size=filter_len,
                                      activation=activation, kernel_initializer=initializer))
        model.add(keras.layers.AveragePooling1D(pool_size=pool_size))
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dropout(dense_dropout_rate))
    for _ in range(n_dense_layers):
        model.add(keras.layers.Dense(nodes_per_dense, activation=activation, kernel_initializer=initializer))
        model.add(keras.layers.Dropout(dense_dropout_rate))
    model.add(keras.layers.Dense(1, activation='linear'))
    model.compile(loss=loss, optimizer=optimizer)
    return model

nt_codes = {'A':[1,0,0,0],
            'C':[0,1,0,0],
            'G':[0,0,1,0],
            'T':[0,0,0,1]}

def encode_seqs(seqs):
    # 3d array with samples x position x nt
    encoded_seqs = np.array([[nt_codes.get(x) for x in seq] for seq in seqs])
    return encoded_seqs


def cnn_training_iteration(fold_df, train_index, test_index, base_model):
    """Train cnn model for optuna iterations

    :param fold_df: DataFrame
    :param train_index: list-like
    :param test_index: list-like
    :param base_model: KerasRegressor
    :return: r^2
    """
    train_df = fold_df.iloc[train_index,:].reset_index(drop=True)
    train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                  ['sgRNA Activity']
                                  .rank(pct=True))
    train_val_seqs = train_df['sgRNA Context Sequence'] # train and validation data
    y_train_val = train_df['sgRNA Activity']
    train_seqs, val_seqs, y_train, y_val = train_test_split(train_val_seqs, y_train_val,
                                                            test_size=0.1, random_state=7)
    X_train = encode_seqs(train_seqs)
    X_val = encode_seqs(val_seqs)
    model = clone(base_model)
    model.fit(X_train, y_train, verbose=0, validation_data=(X_val, y_val),
              callbacks=[keras.callbacks.EarlyStopping(patience=20)])
    test_df = fold_df.iloc[test_index,:].reset_index(drop=True)
    X_test = encode_seqs(test_df['sgRNA Context Sequence'])
    test_predictions = test_df.copy()
    test_predictions['prediction'] = model.predict(X_test)
    test_predictions['sgRNA Activity'] = (test_predictions.groupby('dataset')
                                          ['sgRNA Activity']
                                          .rank(pct=True))
    r2 = r2_score(test_predictions['sgRNA Activity'], test_predictions['prediction'])
    return r2


def get_cnn_objective(fold_df):
    """Get objective function for training a cnn model

    :param fold_df: DataFrame
    :return: objective function
    """
    def objective(trial):
        """For training set, get optimal hyperparameters for cnn

        :param trial: optuna.trial
        :return: int, pearson correlation with held out test data
        """
        sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=7)
        n_conv_layers = trial.suggest_int('n_conv_layers', 1, 2)
        filters_per_conv = trial.suggest_int('filters_per_conv', 32, 256)
        filter_len = trial.suggest_int('filter_len', 2, 8)
        nodes_per_dense = trial.suggest_int('nodes_per_dense', 8, 256)
        dense_dropout_rate = trial.suggest_float('dense_dropout_rate', 0.1, 0.5)
        model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=get_cnn, epochs=5000,
                                                           n_conv_layers=n_conv_layers,
                                                           filters_per_conv=filters_per_conv,
                                                           filter_len=filter_len,
                                                           nodes_per_dense=nodes_per_dense,
                                                           dense_dropout_rate=dense_dropout_rate)
        performance = Parallel(n_jobs=5)(delayed(cnn_training_iteration)
                                         (fold_df, train_index, test_index, model) for
                                         train_index, test_index in
                                         sgkf.split(fold_df, fold_df.dataset, fold_df.target))
        avg_performance = np.mean(performance)
        return avg_performance
    return objective

# %%
cnn_prediction_list = []

for fold, fold_df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    fold_train_data = fold_df.query('train == True').reset_index(drop=True)
    study = optuna.create_study(direction='maximize',
                                sampler=optuna.samplers.TPESampler(seed=7)) # maximize r^2
    objective = get_cnn_objective(fold_train_data)
    start_time = datetime.now()
    study.optimize(objective, n_trials=n_trials)
    end_time = datetime.now()
    difference = end_time - start_time
    print("Number of finished trials: {}".format(len(study.trials)))
    print("Training Time: " + str(difference))
    print("Best trial:")
    trial = study.best_trial
    print("  Value: {}".format(trial.value))
    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
    # Using optimal parameters, retrain model with full dataset
    train_df = fold_train_data.copy()
    train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                  ['sgRNA Activity']
                                  .rank(pct=True))
    train_val_seqs = train_df['sgRNA Context Sequence'] # train and validation data
    y_train_val = train_df['sgRNA Activity']
    train_seqs, val_seqs, y_train, y_val = train_test_split(train_val_seqs, y_train_val,
                                                            test_size=0.1, random_state=7)
    X_train = encode_seqs(train_seqs)
    X_val = encode_seqs(val_seqs)
    model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=get_cnn, epochs=5000,
                                                       **trial.params)
    model.fit(X_train, y_train, verbose=0, validation_data=(X_val, y_val),
              callbacks=[keras.callbacks.EarlyStopping(patience=20)])
    # Test optimal model on test data
    fold_test_data = fold_df.query('train == False').reset_index(drop=True)
    X_test = encode_seqs(fold_test_data['sgRNA Context Sequence'])
    test_predictions = fold_test_data.copy()
    test_predictions['prediction'] = model.predict(X_test)
    test_predictions['model_name'] = 'All train data + CNN + TPE' + str(n_trials)
    test_predictions['fold'] = fold
    cnn_prediction_list.append(test_predictions)
# Out:
# [I 2021-04-11 23:50:08,417] A new study created in memory with name: no-name-6b2ab2d8-eadc-4412-903a-338f4a70b44c
# [I 2021-04-11 23:59:28,812] Trial 0 finished with value: 0.31392490359955716 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 407, 'filter_len': 5, 'nodes_per_dense': 188, 'dense_dropout_rate': 0.4911958047986411}. Best is trial 0 with value: 0.31392490359955716.
# [I 2021-04-12 00:03:59,414] Trial 1 finished with value: 0.41647903606604986 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 273, 'filter_len': 2, 'nodes_per_dense': 74, 'dense_dropout_rate': 0.299953000330224}. Best is trial 1 with value: 0.41647903606604986.
# [I 2021-04-12 00:12:46,574] Trial 2 finished with value: 0.4173208184094596 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 418, 'filter_len': 4, 'nodes_per_dense': 24, 'dense_dropout_rate': 0.21525823972319744}. Best is trial 2 with value: 0.4173208184094596.
# [I 2021-04-12 00:14:23,481] Trial 3 finished with value: 0.3844138694859852 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 134, 'filter_len': 5, 'nodes_per_dense': 239, 'dense_dropout_rate': 0.10995969102013921}. Best is trial 2 with value: 0.4173208184094596.
# [I 2021-04-12 00:30:23,243] Trial 4 finished with value: 0.4390357518251314 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 489, 'filter_len': 3, 'nodes_per_dense': 144, 'dense_dropout_rate': 0.4636513499546925}. Best is trial 4 with value: 0.4390357518251314.
# [I 2021-04-12 00:34:52,333] Trial 5 finished with value: 0.44877119390861414 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 283, 'filter_len': 7, 'nodes_per_dense': 174, 'dense_dropout_rate': 0.2871011438979923}. Best is trial 5 with value: 0.44877119390861414.
# [I 2021-04-12 00:39:27,424] Trial 6 finished with value: 0.43702162237490877 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 268, 'filter_len': 4, 'nodes_per_dense': 126, 'dense_dropout_rate': 0.2463561543122372}. Best is trial 5 with value: 0.44877119390861414.
# [I 2021-04-12 00:49:10,309] Trial 7 finished with value: 0.4156934567954191 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 401, 'filter_len': 4, 'nodes_per_dense': 150, 'dense_dropout_rate': 0.21041961933227804}. Best is trial 5 with value: 0.44877119390861414.
# [I 2021-04-12 00:51:24,484] Trial 8 finished with value: 0.44358886898855837 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 201, 'filter_len': 6, 'nodes_per_dense': 100, 'dense_dropout_rate': 0.2836371911565726}. Best is trial 5 with value: 0.44877119390861414.
# [I 2021-04-12 00:55:00,902] Trial 9 finished with value: 0.4092461851450196 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 230, 'filter_len': 8, 'nodes_per_dense': 52, 'dense_dropout_rate': 0.3964475491653058}. Best is trial 5 with value: 0.44877119390861414.
# [I 2021-04-12 00:56:07,528] Trial 10 finished with value: 0.4111946885713339 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 53, 'filter_len': 8, 'nodes_per_dense': 235, 'dense_dropout_rate': 0.3809833266347447}. Best is trial 5 with value: 0.44877119390861414.
# [I 2021-04-12 00:57:54,600] Trial 11 finished with value: 0.4495906491888003 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 169, 'filter_len': 7, 'nodes_per_dense': 104, 'dense_dropout_rate': 0.3234823265879915}. Best is trial 11 with value: 0.4495906491888003.
# [I 2021-04-12 00:59:30,289] Trial 12 finished with value: 0.4349669288838583 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 113, 'filter_len': 7, 'nodes_per_dense': 189, 'dense_dropout_rate': 0.35549831747494653}. Best is trial 11 with value: 0.4495906491888003.
# [I 2021-04-12 01:04:52,195] Trial 13 finished with value: 0.4346904154704026 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 333, 'filter_len': 7, 'nodes_per_dense': 183, 'dense_dropout_rate': 0.1555850979261378}. Best is trial 11 with value: 0.4495906491888003.
# [I 2021-04-12 01:06:37,820] Trial 14 finished with value: 0.44988044175249675 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 154, 'filter_len': 7, 'nodes_per_dense': 112, 'dense_dropout_rate': 0.3408175954234049}. Best is trial 14 with value: 0.44988044175249675.
# [I 2021-04-12 01:08:31,602] Trial 15 finished with value: 0.45250492710494783 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 157, 'filter_len': 6, 'nodes_per_dense': 96, 'dense_dropout_rate': 0.42925681328929666}. Best is trial 15 with value: 0.45250492710494783.
# [I 2021-04-12 01:09:38,850] Trial 16 finished with value: 0.42735932549822886 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 36, 'filter_len': 6, 'nodes_per_dense': 62, 'dense_dropout_rate': 0.4351073210923929}. Best is trial 15 with value: 0.45250492710494783.
# [I 2021-04-12 01:10:54,999] Trial 17 finished with value: 0.45414319567990213 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 91, 'filter_len': 6, 'nodes_per_dense': 32, 'dense_dropout_rate': 0.4167611926119019}. Best is trial 17 with value: 0.45414319567990213.
# [I 2021-04-12 01:12:11,160] Trial 18 finished with value: 0.3891170781616723 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 80, 'filter_len': 6, 'nodes_per_dense': 8, 'dense_dropout_rate': 0.42564095919149736}. Best is trial 17 with value: 0.45414319567990213.
# [I 2021-04-12 01:13:50,033] Trial 19 finished with value: 0.4419579928279963 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 100, 'filter_len': 6, 'nodes_per_dense': 24, 'dense_dropout_rate': 0.4861114689239563}. Best is trial 17 with value: 0.45414319567990213.
# [I 2021-04-12 01:14:57,454] Trial 20 finished with value: 0.43088214949699555 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 33, 'filter_len': 5, 'nodes_per_dense': 80, 'dense_dropout_rate': 0.42550676365412177}. Best is trial 17 with value: 0.45414319567990213.
# [I 2021-04-12 01:16:29,697] Trial 21 finished with value: 0.4405095973331898 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 160, 'filter_len': 8, 'nodes_per_dense': 106, 'dense_dropout_rate': 0.357876835952295}. Best is trial 17 with value: 0.45414319567990213.
# [I 2021-04-12 01:18:37,051] Trial 22 finished with value: 0.4461223241872892 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 194, 'filter_len': 6, 'nodes_per_dense': 31, 'dense_dropout_rate': 0.38794720511242087}. Best is trial 17 with value: 0.45414319567990213.
# [I 2021-04-12 01:20:01,191] Trial 23 finished with value: 0.44779395435369124 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 144, 'filter_len': 7, 'nodes_per_dense': 49, 'dense_dropout_rate': 0.33572256511581966}. Best is trial 17 with value: 0.45414319567990213.
# [I 2021-04-12 01:21:26,706] Trial 24 finished with value: 0.44101739623056113 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 71, 'filter_len': 6, 'nodes_per_dense': 124, 'dense_dropout_rate': 0.46527503421828204}. Best is trial 17 with value: 0.45414319567990213.
# [I 2021-04-12 01:24:29,509] Trial 25 finished with value: 0.4524744571543103 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 231, 'filter_len': 7, 'nodes_per_dense': 91, 'dense_dropout_rate': 0.4078849170646246}. Best is trial 17 with value: 0.45414319567990213.
# [I 2021-04-12 01:27:33,662] Trial 26 finished with value: 0.46192499834253287 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 243, 'filter_len': 5, 'nodes_per_dense': 84, 'dense_dropout_rate': 0.44684845140115953}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:32:44,463] Trial 27 finished with value: 0.4460050501205822 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 337, 'filter_len': 5, 'nodes_per_dense': 69, 'dense_dropout_rate': 0.4724373751210745}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:36:09,817] Trial 28 finished with value: 0.44374031170102135 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 220, 'filter_len': 4, 'nodes_per_dense': 43, 'dense_dropout_rate': 0.44803759418534816}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:37:49,396] Trial 29 finished with value: 0.45776854283533225 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 113, 'filter_len': 5, 'nodes_per_dense': 86, 'dense_dropout_rate': 0.4904730517343262}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:40:17,841] Trial 30 finished with value: 0.43825506728929947 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 99, 'filter_len': 3, 'nodes_per_dense': 83, 'dense_dropout_rate': 0.49384620795090145}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:42:14,726] Trial 31 finished with value: 0.4551518932416608 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 121, 'filter_len': 5, 'nodes_per_dense': 66, 'dense_dropout_rate': 0.49790552123192855}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:44:05,799] Trial 32 finished with value: 0.3906136069253064 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 120, 'filter_len': 5, 'nodes_per_dense': 9, 'dense_dropout_rate': 0.49556232828676877}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:45:50,221] Trial 33 finished with value: 0.45193064007766826 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 80, 'filter_len': 5, 'nodes_per_dense': 63, 'dense_dropout_rate': 0.498718871204515}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:49:01,199] Trial 34 finished with value: 0.4379782667319865 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 191, 'filter_len': 4, 'nodes_per_dense': 39, 'dense_dropout_rate': 0.45508804938119607}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:50:49,686] Trial 35 finished with value: 0.43879516813612246 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 59, 'filter_len': 3, 'nodes_per_dense': 77, 'dense_dropout_rate': 0.4995014768694512}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 01:58:23,448] Trial 36 finished with value: 0.3472510869278264 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 300, 'filter_len': 5, 'nodes_per_dense': 13, 'dense_dropout_rate': 0.46908355513373073}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:00:08,493] Trial 37 finished with value: 0.4450078586550186 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 120, 'filter_len': 4, 'nodes_per_dense': 56, 'dense_dropout_rate': 0.4079426042815946}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:04:25,515] Trial 38 finished with value: 0.46118996957653674 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 5, 'nodes_per_dense': 137, 'dense_dropout_rate': 0.4453921722424371}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:09:03,127] Trial 39 finished with value: 0.41922828501813936 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 255, 'filter_len': 4, 'nodes_per_dense': 148, 'dense_dropout_rate': 0.4498344897298615}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:17:39,584] Trial 40 finished with value: 0.35839031770980095 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 377, 'filter_len': 5, 'nodes_per_dense': 162, 'dense_dropout_rate': 0.4860600839908399}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:23:56,420] Trial 41 finished with value: 0.45225823747888355 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 302, 'filter_len': 5, 'nodes_per_dense': 120, 'dense_dropout_rate': 0.4740014144534573}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:31:22,441] Trial 42 finished with value: 0.18417789207198865 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 453, 'filter_len': 6, 'nodes_per_dense': 140, 'dense_dropout_rate': 0.4415397845612207}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:35:28,600] Trial 43 finished with value: 0.45591405766737214 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 258, 'filter_len': 5, 'nodes_per_dense': 87, 'dense_dropout_rate': 0.4110536296928264}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:38:47,450] Trial 44 finished with value: 0.45377866975921444 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 242, 'filter_len': 5, 'nodes_per_dense': 89, 'dense_dropout_rate': 0.3726632108637847}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:43:53,696] Trial 45 finished with value: 0.43838798476325974 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 280, 'filter_len': 4, 'nodes_per_dense': 132, 'dense_dropout_rate': 0.25677343474617287}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:47:09,119] Trial 46 finished with value: 0.45404190455624993 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 214, 'filter_len': 4, 'nodes_per_dense': 115, 'dense_dropout_rate': 0.4004540729923849}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 02:51:32,038] Trial 47 finished with value: 0.44079232601682883 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 181, 'filter_len': 3, 'nodes_per_dense': 161, 'dense_dropout_rate': 0.4773104929095093}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 03:00:57,705] Trial 48 finished with value: 0.4572907909940854 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 345, 'filter_len': 5, 'nodes_per_dense': 208, 'dense_dropout_rate': 0.4517144089032718}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 03:10:54,521] Trial 49 finished with value: 0.4490536608475878 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 347, 'filter_len': 5, 'nodes_per_dense': 220, 'dense_dropout_rate': 0.30791727726759743}. Best is trial 26 with value: 0.46192499834253287.
# [I 2021-04-12 03:12:13,373] A new study created in memory with name: no-name-5b5d8d61-c7ad-412c-8779-459bd14781b4
# [I 2021-04-12 03:23:47,352] Trial 0 finished with value: 0.43880991840711375 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 407, 'filter_len': 5, 'nodes_per_dense': 188, 'dense_dropout_rate': 0.4911958047986411}. Best is trial 0 with value: 0.43880991840711375.
# [I 2021-04-12 03:28:02,463] Trial 1 finished with value: 0.40493170228022046 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 273, 'filter_len': 2, 'nodes_per_dense': 74, 'dense_dropout_rate': 0.299953000330224}. Best is trial 0 with value: 0.43880991840711375.
# [I 2021-04-12 03:36:27,780] Trial 2 finished with value: 0.4043160180585133 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 418, 'filter_len': 4, 'nodes_per_dense': 24, 'dense_dropout_rate': 0.21525823972319744}. Best is trial 0 with value: 0.43880991840711375.
# [I 2021-04-12 03:38:07,879] Trial 3 finished with value: 0.36538266887279247 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 134, 'filter_len': 5, 'nodes_per_dense': 239, 'dense_dropout_rate': 0.10995969102013921}. Best is trial 0 with value: 0.43880991840711375.
# [I 2021-04-12 03:52:45,938] Trial 4 finished with value: 0.42910262489166284 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 489, 'filter_len': 3, 'nodes_per_dense': 144, 'dense_dropout_rate': 0.4636513499546925}. Best is trial 0 with value: 0.43880991840711375.
# [I 2021-04-12 03:56:01,152] Trial 5 finished with value: 0.4428203357431396 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 283, 'filter_len': 7, 'nodes_per_dense': 174, 'dense_dropout_rate': 0.2871011438979923}. Best is trial 5 with value: 0.4428203357431396.
# [I 2021-04-12 04:00:31,912] Trial 6 finished with value: 0.4128251095619488 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 268, 'filter_len': 4, 'nodes_per_dense': 126, 'dense_dropout_rate': 0.2463561543122372}. Best is trial 5 with value: 0.4428203357431396.
# [I 2021-04-12 04:10:23,164] Trial 7 finished with value: 0.40275362617272864 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 401, 'filter_len': 4, 'nodes_per_dense': 150, 'dense_dropout_rate': 0.21041961933227804}. Best is trial 5 with value: 0.4428203357431396.
# [I 2021-04-12 04:12:39,932] Trial 8 finished with value: 0.42726996754919977 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 201, 'filter_len': 6, 'nodes_per_dense': 100, 'dense_dropout_rate': 0.2836371911565726}. Best is trial 5 with value: 0.4428203357431396.
# [I 2021-04-12 04:16:12,641] Trial 9 finished with value: 0.3987289321112991 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 230, 'filter_len': 8, 'nodes_per_dense': 52, 'dense_dropout_rate': 0.3964475491653058}. Best is trial 5 with value: 0.4428203357431396.
# [I 2021-04-12 04:17:12,693] Trial 10 finished with value: 0.3995208915334862 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 53, 'filter_len': 8, 'nodes_per_dense': 235, 'dense_dropout_rate': 0.3809833266347447}. Best is trial 5 with value: 0.4428203357431396.
# [I 2021-04-12 04:25:05,320] Trial 11 finished with value: 0.44454819429425196 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 354, 'filter_len': 7, 'nodes_per_dense': 192, 'dense_dropout_rate': 0.39185325502666085}. Best is trial 11 with value: 0.44454819429425196.
# [I 2021-04-12 04:30:43,737] Trial 12 finished with value: 0.4394076970842442 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 332, 'filter_len': 7, 'nodes_per_dense': 194, 'dense_dropout_rate': 0.37230945990762215}. Best is trial 11 with value: 0.44454819429425196.
# [I 2021-04-12 04:37:03,664] Trial 13 finished with value: 0.4490989521415699 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 326, 'filter_len': 7, 'nodes_per_dense': 189, 'dense_dropout_rate': 0.42859611410914555}. Best is trial 13 with value: 0.4490989521415699.
# [I 2021-04-12 04:44:37,991] Trial 14 finished with value: 0.43993378054043325 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 348, 'filter_len': 7, 'nodes_per_dense': 217, 'dense_dropout_rate': 0.4452268394827925}. Best is trial 13 with value: 0.4490989521415699.
# [I 2021-04-12 04:53:15,609] Trial 15 finished with value: 0.31523101109826346 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 500, 'filter_len': 6, 'nodes_per_dense': 206, 'dense_dropout_rate': 0.41748264914279704}. Best is trial 13 with value: 0.4490989521415699.
# [I 2021-04-12 05:01:00,593] Trial 16 finished with value: 0.44090871632902096 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 359, 'filter_len': 8, 'nodes_per_dense': 256, 'dense_dropout_rate': 0.334768394852655}. Best is trial 13 with value: 0.4490989521415699.
# [I 2021-04-12 05:12:39,474] Trial 17 finished with value: 0.44921061149631536 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 450, 'filter_len': 6, 'nodes_per_dense': 164, 'dense_dropout_rate': 0.4872449392255006}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 05:23:57,770] Trial 18 finished with value: 0.43071925093141045 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 457, 'filter_len': 6, 'nodes_per_dense': 162, 'dense_dropout_rate': 0.4994632295681929}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 05:31:40,930] Trial 19 finished with value: 0.40467537343892834 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 454, 'filter_len': 6, 'nodes_per_dense': 111, 'dense_dropout_rate': 0.45330054310083545}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 05:34:32,079] Trial 20 finished with value: 0.44180811081205934 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 176, 'filter_len': 5, 'nodes_per_dense': 168, 'dense_dropout_rate': 0.4993806182015629}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 05:41:19,632] Trial 21 finished with value: 0.44273637155937084 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 317, 'filter_len': 7, 'nodes_per_dense': 219, 'dense_dropout_rate': 0.42343022979424333}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 05:51:44,812] Trial 22 finished with value: 0.44048092265266814 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 380, 'filter_len': 7, 'nodes_per_dense': 179, 'dense_dropout_rate': 0.35887745379224867}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 06:04:30,755] Trial 23 finished with value: 0.4240042179868729 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 457, 'filter_len': 6, 'nodes_per_dense': 136, 'dense_dropout_rate': 0.4712636550864191}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 06:09:36,102] Trial 24 finished with value: 0.4376976243621874 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 311, 'filter_len': 8, 'nodes_per_dense': 204, 'dense_dropout_rate': 0.33469743517850614}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 06:22:16,722] Trial 25 finished with value: 0.4448593464203235 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 425, 'filter_len': 7, 'nodes_per_dense': 256, 'dense_dropout_rate': 0.42160658520737215}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 06:36:02,768] Trial 26 finished with value: 0.3882159889182096 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 509, 'filter_len': 6, 'nodes_per_dense': 246, 'dense_dropout_rate': 0.43401647210804695}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 06:44:38,963] Trial 27 finished with value: 0.44020561316531276 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 425, 'filter_len': 8, 'nodes_per_dense': 228, 'dense_dropout_rate': 0.4815894478139239}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 06:50:45,070] Trial 28 finished with value: 0.32215326928762816 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 477, 'filter_len': 7, 'nodes_per_dense': 107, 'dense_dropout_rate': 0.4168697137252666}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 06:58:45,876] Trial 29 finished with value: 0.3397582298412849 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 398, 'filter_len': 5, 'nodes_per_dense': 159, 'dense_dropout_rate': 0.3421376499136565}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 07:10:10,815] Trial 30 finished with value: 0.44437354571723703 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 423, 'filter_len': 6, 'nodes_per_dense': 187, 'dense_dropout_rate': 0.49367229494747183}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 07:19:10,596] Trial 31 finished with value: 0.4439996298457995 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 379, 'filter_len': 7, 'nodes_per_dense': 198, 'dense_dropout_rate': 0.39897420586564436}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 07:26:41,731] Trial 32 finished with value: 0.3524080932849407 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 361, 'filter_len': 7, 'nodes_per_dense': 182, 'dense_dropout_rate': 0.44941219275734606}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 07:30:59,905] Trial 33 finished with value: 0.4380786561903037 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 289, 'filter_len': 7, 'nodes_per_dense': 123, 'dense_dropout_rate': 0.394514546617782}. Best is trial 17 with value: 0.44921061149631536.
# [I 2021-04-12 07:40:33,872] Trial 34 finished with value: 0.44589623354613084 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 449, 'filter_len': 8, 'nodes_per_dense': 213, 'dense_dropout_rate': 0.47311969537092935}. Best is trial 17 with value: 0.44921061149631536.
# Fold: 0
# Number of finished trials: 50
# Training Time: 3:20:46.103205
# Best trial:
#   Value: 0.46192499834253287
#   Params:
#     n_conv_layers: 1
#     filters_per_conv: 243
#     filter_len: 5
#     nodes_per_dense: 84
#     dense_dropout_rate: 0.44684845140115953
# Fold: 1

# %%
cnn_predictive_performance = get_predictive_performance(lgbm_prediction_list +
                                                        cnn_prediction_list)

# %%
plot_pearson_heatmap(cnn_predictive_performance)

# %%
plot_relative_performance(cnn_predictive_performance)

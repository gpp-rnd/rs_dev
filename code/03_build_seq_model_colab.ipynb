# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterDeWeirdt/rs_dev/blob/main/notebooks/03_build_seq_model_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Build Sequence Model

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Apr 14 21:56:16 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import multiprocessing
n_cpus = multiprocessing.cpu_count()
print(n_cpus)
# Out:
# 4

# %%
# !pip install -U --pre --extra-index https://pypi.anaconda.org/scipy-wheels-nightly/simple scikit-learn
# !pip install -U lightgbm --install-option=--gpu
# !pip install sglearn
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.anaconda.org/scipy-wheels-nightly/simple
# Collecting scikit-learn
#   Downloading https://pypi.anaconda.org/scipy-wheels-nightly/simple/scikit-learn/1.0.dev0/scikit_learn-1.0.dev0-cp37-cp37m-manylinux2010_x86_64.whl (22.4MB)
#      |████████████████████████████████| 22.4MB 1.3MB/s
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn) (1.0.1)
# Installing collected packages: threadpoolctl, scikit-learn
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
# Successfully installed scikit-learn-1.0.dev0 threadpoolctl-2.1.0
# /usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# Collecting lightgbm
#   Downloading https://files.pythonhosted.org/packages/7a/6d/db0f5effd3f7982632111f37fcd2fa386b8407f1ff58ef30b71d65e1a444/lightgbm-3.2.1.tar.gz (1.5MB)
#      |████████████████████████████████| 1.5MB 8.3MB/s
# Requirement already satisfied, skipping upgrade: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm) (0.36.2)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.19.5)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.4.1)
# Requirement already satisfied, skipping upgrade: scikit-learn!=0.22.0 in /usr/local/lib/python3.7/dist-packages (from lightgbm) (1.0.dev0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm) (1.0.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.22.0->lightgbm) (2.1.0)
# Skipping wheel build for lightgbm, due to binaries being disabled for it.
# Installing collected packages: lightgbm
#   Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#     Running setup.py install for lightgbm ... done
# Successfully installed lightgbm-3.2.1
# Collecting sglearn
#   Downloading https://files.pythonhosted.org/packages/95/0c/26bb1a2d0618583277aed0f2f15f3f9ddb7aaf9b5f1e4edd13c7f9603c83/sglearn-0.2.0-py2.py3-none-any.whl
# Collecting biopython>=1.77
#   Downloading https://files.pythonhosted.org/packages/3a/cd/0098eaff841850c01da928c7f509b72fd3e1f51d77b772e24de9e2312471/biopython-1.78-cp37-cp37m-manylinux1_x86_64.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 8.3MB/s
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from sglearn) (1.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from biopython>=1.77->sglearn) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->sglearn) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->sglearn) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1->sglearn) (1.15.0)
# Installing collected packages: biopython, sglearn
# Successfully installed biopython-1.78 sglearn-0.2.0
# Collecting optuna
#   Downloading https://files.pythonhosted.org/packages/2b/21/d13081805e1e1afc71f5bb743ece324c8bd576237c51b899ecb38a717502/optuna-2.7.0-py3-none-any.whl (293kB)
#      |████████████████████████████████| 296kB 8.0MB/s
# Collecting alembic
#   Downloading https://files.pythonhosted.org/packages/72/a4/97eb6273839655cac14947986fa7a5935350fcfd4fff872e9654264c82d8/alembic-1.5.8-py2.py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 13.9MB/s
# Collecting cmaes>=0.8.2
#   Downloading https://files.pythonhosted.org/packages/01/1f/43b01223a0366171f474320c6e966c39a11587287f098a5f09809b45e05f/cmaes-0.8.2-py3-none-any.whl
# Collecting cliff
#   Downloading https://files.pythonhosted.org/packages/a2/d6/7d9acb68a77acd140be7fececb7f2701b2a29d2da9c54184cb8f93509590/cliff-3.7.0-py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 5.2MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.41.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.19.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (20.9)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.6)
# Collecting colorlog
#   Downloading https://files.pythonhosted.org/packages/32/e6/e9ddc6fa1104fda718338b341e4b3dc31cd8039ab29e52fc73b508515361/colorlog-5.0.1-py2.py3-none-any.whl
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (2.8.1)
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/f3/54/dbc07fbb20865d3b78fdb7cf7fa713e2cba4f87f71100074ef2dc9f9d1f7/Mako-1.1.4-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 8.3MB/s
# Requirement already satisfied: PyYAML>=3.12 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.13)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fb/48/69046506f6ac61c1eaa9a0d42d22d54673b69e176d30ca98e3f61513e980/pbr-5.5.1-py2.py3-none-any.whl (106kB)
#      |████████████████████████████████| 112kB 15.8MB/s
# Collecting cmd2>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/15/8b/15061b32332bb35ea2a2f6263d0f616779d576e82739ec8e7fcf3c94abf5/cmd2-1.5.0-py3-none-any.whl (133kB)
#      |████████████████████████████████| 143kB 16.9MB/s
# Collecting stevedore>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/d4/49/b602307aeac3df3384ff1fcd05da9c0376c622a6c48bb5325f28ab165b57/stevedore-3.3.0-py3-none-any.whl (49kB)
#      |████████████████████████████████| 51kB 5.8MB/s
# Requirement already satisfied: pyparsing>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.7)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.1.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (3.10.0)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->alembic->optuna) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (1.1.1)
# Collecting colorama>=0.3.7
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (20.3.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Collecting pyperclip>=1.6
#   Downloading https://files.pythonhosted.org/packages/a7/2c/4c64579f847bd5d539803c8b909e54ba087a79d01bb3aba433a95879a6c5/pyperclip-1.8.2.tar.gz
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy>=1.1.0->optuna) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->sqlalchemy>=1.1.0->optuna) (3.7.4.3)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-cp37-none-any.whl size=11107 sha256=f4c7260a25e25fe0d8e6e4382c7e76ea9ca1d2b76e509ed24607d4df1aea7fde
#   Stored in directory: /root/.cache/pip/wheels/25/af/b8/3407109267803f4015e1ee2ff23be0c8c19ce4008665931ee1
# Successfully built pyperclip
# Installing collected packages: python-editor, Mako, alembic, cmaes, pbr, colorama, pyperclip, cmd2, stevedore, cliff, colorlog, optuna
# Successfully installed Mako-1.1.4 alembic-1.5.8 cliff-3.7.0 cmaes-0.8.2 cmd2-1.5.0 colorama-0.4.4 colorlog-5.0.1 optuna-2.7.0 pbr-5.5.1 pyperclip-1.8.2 python-editor-1.0.4 stevedore-3.3.0

# %%
import pandas as pd
from datasets_colab import dataset_list
from sklearn.model_selection import StratifiedGroupKFold, train_test_split
from lightgbm import LGBMRegressor
from sklearn.base import clone
from sklearn.metrics import r2_score
import sglearn
from scipy import stats
import plotnine as gg
import optuna
from joblib import Parallel, delayed
import numpy as np
from tensorflow import keras
from datetime import datetime

# %%
def get_predictive_performance(prediction_list):
    """From a list of dataframes of predictions for each fold for each datasetset for each guide,
    get pearson correlation of each fold/dataset

    :param prediction_list: list of DataFrame
    :return: DataFrame
    """
    test_prediction_df = (pd.concat(prediction_list)
                          .rename({'dataset': 'testing_set'}, axis=1))
    predictive_performance = (test_prediction_df.groupby(['model_name', 'testing_set', 'fold'])
                              .apply(lambda df: stats.pearsonr(df['sgRNA Activity'], df['prediction'])[0])
                              .reset_index(name='pearson_r'))
    predictive_performance['relative_performance'] = (predictive_performance.groupby(['fold', 'testing_set'])
                                                      ['pearson_r']
                                                      .transform(lambda x: x/x.max()))
    median_relative_performance = (predictive_performance.groupby(['model_name'])
                                   .agg(median_performance = ('relative_performance', 'median'))
                                   .reset_index()
                                   .sort_values('median_performance'))
    predictive_performance['model_name'] = pd.Categorical(predictive_performance['model_name'],
                                                            categories=median_relative_performance['model_name'])
    if predictive_performance['testing_set'].isin(predictive_performance['model_name']).all():
        predictive_performance['testing_set'] = pd.Categorical(predictive_performance['testing_set'],
                                                               categories=median_relative_performance['model_name'])
    predictive_performance['fold'] = predictive_performance['fold'].astype('category')
    return predictive_performance


def plot_pearson_heatmap(predictive_performance):
    """Plot heatmap of pearson correlations

    :param predictive_performance: DataFrame from `get_predictive_performance`
    :return: plotnine figure
    """
    g = (gg.ggplot(predictive_performance) +
         gg.aes(x='testing_set', y='model_name', fill='pearson_r') +
         gg.geom_tile(color='black') +
         gg.scale_fill_cmap('RdBu_r', limits=(-1, 1)) +
         gg.theme_classic() +
         gg.theme(axis_text_x=gg.element_text(angle=90, hjust=0.5, vjust=1)) +
         gg.facet_wrap('fold'))
    return g


def plot_relative_performance(predictive_performance):
    """Plot boxplot of relative performance

    :param predictive_performance: predictive_performance: DataFrame from `get_predictive_performance`
    :return: plotnine figure
    """
    g = (gg.ggplot(predictive_performance) +
         gg.aes(x='model_name', y='relative_performance') +
         gg.geom_point(gg.aes(color='fold'), position=gg.position_dodge(width=0.5)) +
         gg.scale_color_brewer(type='qual', palette='Set2') +
         gg.geom_boxplot(fill=None, outlier_alpha=0) +
         gg.theme_classic() +
         gg.theme(axis_text_x=gg.element_text(angle=90, hjust=0.5, vjust=1)))
    return g


def train_test_model(train_df, model_name, fold, model, test_df, X_test):
    """Get predictions from train and test model

    :param train_df: DataFrame
    :param model_name: str, name of model
    :param fold: int
    :param model: model with a .fit function
    :param test_df: DataFrame
    :param X_test: DataFrame from sglearn.featurize_guides
    :return: DataFrame, same shape as test_df with columns prediction, model, fold
    """
    X_train = sglearn.featurize_guides(train_df['sgRNA Context Sequence'])
    y_train = train_df['sgRNA Activity']
    model.fit(X_train,  y_train)
    dataset_test_predictions = test_df.copy()
    dataset_test_predictions['prediction'] = model.predict(X_test)
    dataset_test_predictions['model_name'] = model_name
    dataset_test_predictions['fold'] = fold
    return dataset_test_predictions


def get_fold_predictions(fold, fold_df,
                         base_model=LGBMRegressor(random_state=7, n_jobs=8),
                         top_training_set=None, combine_datasets=None, model_name=None):
    """Get predictions for a given fold, allowing for each dataset to be trained separately,
    or multiple datasets trained together

    :param fold: int
    :param fold_df: DataFrame
    :param base_model: model with a .fit function
    :param top_training_set: str
    :param combine_datasets: list of
    :param model_name: str optional, only relevant if top_datasets is specified
    :return: list of DataFrame, list of test predictions
    """
    fold_train_data = fold_df.query('train == True').reset_index(drop=True)
    fold_test_data = fold_df.query('train == False').reset_index(drop=True)
    X_test = sglearn.featurize_guides(fold_test_data['sgRNA Context Sequence'])
    test_prediction_list = []
    if combine_datasets is None:
        for dataset, dataset_df in fold_train_data.groupby('dataset'):
            dataset_df = dataset_df.reset_index(drop=True)
            # Join together top training set and current dataset
            if top_training_set is not None:
                if dataset != top_training_set:
                    top_dataset_df = fold_train_data[fold_train_data.dataset == top_training_set]
                    dataset_df = pd.concat([dataset_df, top_dataset_df]).reset_index(drop=True)
                    dataset_df['sgRNA Activity'] = (dataset_df.groupby('dataset')
                                                    ['sgRNA Activity']
                                                    .rank(pct=True))
                    dataset += ' + ' + top_training_set
            model = clone(base_model)
            dataset_test_predictions = train_test_model(dataset_df, dataset, fold, model, fold_test_data, X_test)
            test_prediction_list.append(dataset_test_predictions)
    else:
        train_df = fold_train_data[fold_train_data.dataset.isin(combine_datasets)].reset_index(drop=True)
        train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                      ['sgRNA Activity']
                                      .rank(pct=True))
        model = clone(base_model)
        if model_name is None:
            model_name = ' + '.join(combine_datasets)
        dataset_test_predictions = train_test_model(train_df, model_name, fold,
                                                    model, fold_test_data, X_test)
        # For consistency we return a list of len 1
        test_prediction_list.append(dataset_test_predictions)
    return test_prediction_list

# %%
train_data_names = pd.read_csv('train_data_names.csv').name.to_list()

# %%
train_data_list = list()
for ds in dataset_list:
    if ds.name in train_data_names:
        train_data_list.append(ds)

for ds in train_data_list:
    ds.load_data()
    ds.get_sgrnas()

# %% [markdown]
# ## Cross-Validation Iterator
#
# We'll use [StratifiedGroupKFold](https://scikit-learn.org/dev/modules/generated/sklearn.model_selection.StratifiedGroupKFold.html#sklearn.model_selection.StratifiedGroupKFold)
#
# >This cross-validation object is a variation of StratifiedKFold attempts to return stratified folds with
# > non-overlapping groups. The folds are made by preserving the percentage of samples for each class.
#
# >The same group will not appear in two different folds (the number of distinct groups has to be at least equal to
# > the number of folds).
#
# >The difference between GroupKFold and StratifiedGroupKFold is that the former attempts to create balanced folds such
# > that the number of distinct groups is approximately the same in each fold, whereas StratifiedGroupKFold attempts to
# > create folds which preserve the percentage of samples for each class as much as possible given the
# > constraint of non-overlapping groups between splits.
#
# In our case, we define each dataset as a "class", such that the datasets are approximately equally distributed across
# folds, constrained by the notion that each "group" or gene cannot appear in both the train and test set in a given fold.
#
# First, we assign sgRNAs to genes, capitalizing gene-names from the mouse libraries, so they overlap with the human annotations.
# We can see that every context sequence uniquely targets a gene in this dataset

# %%
sg_df_list = []
for ds in train_data_list:
    sg_df = ds.get_sg_df(include_group=True, include_activity=True)
    sg_df['dataset'] = ds.name
    sg_df_list.append(sg_df)
sg_df_groups = (pd.concat(sg_df_list)
                .groupby(['sgRNA Context Sequence'])
                .agg(n_conditions = ('sgRNA Context Sequence', 'count'),
                     target = ('sgRNA Target', lambda x: ', '.join(set([s.upper() for s in x if not pd.isna(s)]))))
                .reset_index())
multi_target = sg_df_groups['target'].str.contains(',').sum()
print('Context sequences with multiple targets: ' + str(multi_target))
# Out:
# Context sequences with multiple targets: 0

# %% [markdown]
# We assign context sequences without a group to their own group. Every dataset appears as both a training and testing
# dataset in every fold, except Doench2014_human Doench2014_mouse, which have fewer than 5 genes

# %%
# handle singleton case
sg_df_groups['target'] = sg_df_groups.apply(lambda row:
                                            row['target'] if (row['target'] != '') else row['sgRNA Context Sequence'],
                                            axis=1)
# Note that 'target' is not in the sg_df_list, and is coming from the sg_df_groups df
sg_df_class_groups = (pd.concat(sg_df_list)
                      .merge(sg_df_groups, how='inner', on='sgRNA Context Sequence')
                      .sort_values(['dataset', 'target'])                      
                      .reset_index(drop=True))
sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=7)
tidy_cv_list = []
for i, (train_index, test_index) in enumerate(sgkf.split(sg_df_class_groups, sg_df_class_groups.dataset,
                                                         sg_df_class_groups.target)):
    train_df = sg_df_class_groups.iloc[train_index,:].copy()
    train_df['cv'] = i
    train_df['train'] = True
    tidy_cv_list.append(train_df)
    test_df = sg_df_class_groups.iloc[test_index,:].copy()
    test_df['cv'] = i
    test_df['train'] = False
    tidy_cv_list.append(test_df)
tidy_cv_df = pd.concat(tidy_cv_list)
cv_train_data_counts = (tidy_cv_df[['cv', 'train', 'dataset']].value_counts()
                        .reset_index(name='n'))
cv_train_data_counts
# Out:
#     cv  train           dataset      n
# 0    3   True     Kim2019_train  10604
# 1    1   True     Kim2019_train  10574
# 2    4   True     Kim2019_train  10354
# 3    0   True     Kim2019_train  10267
# 4    2   True     Kim2019_train   9529
# 5    2  False     Kim2019_train   3303
# 6    0  False     Kim2019_train   2565
# 7    4  False     Kim2019_train   2478
# 8    1   True        Doench2016   2319
# 9    1  False     Kim2019_train   2258
# 10   3  False     Kim2019_train   2228
# 11   3   True        Doench2016   2209
# 12   4   True        Doench2016   2194
# 13   0   True        Doench2016   1804
# 14   2   True        Doench2016   1618
# 15   3   True  Doench2014_mouse   1169
# 16   2   True  Doench2014_mouse   1084
# 17   3   True  Doench2014_human    995
# 18   4   True  Doench2014_human    995
# 19   0   True  Doench2014_human    995
# 20   1   True  Doench2014_mouse    957
# 21   2  False        Doench2016    918
# 22   3   True          Wang2014    870
# 23   1   True          Wang2014    843
# 24   4   True          Wang2014    836
# 25   0   True          Wang2014    830
# 26   1   True  Doench2014_human    828
# 27   2  False  Doench2014_human    828
# 28   0   True  Doench2014_mouse    815
# 29   0  False        Doench2016    732
# 30   2   True          Wang2014    709
# 31   4   True  Doench2014_mouse    651
# 32   4  False  Doench2014_mouse    518
# 33   0  False  Doench2014_mouse    354
# 34   4  False        Doench2016    342
# 35   3  False        Doench2016    327
# 36   2  False          Wang2014    313
# 37   1  False        Doench2016    217
# 38   1  False  Doench2014_mouse    212
# 39   0  False          Wang2014    192
# 40   4  False          Wang2014    186
# 41   1  False          Wang2014    179
# 42   1  False  Doench2014_human    167
# 43   2   True  Doench2014_human    167
# 44   3  False          Wang2014    152
# 45   2  False  Doench2014_mouse     85

# %%
(cv_train_data_counts[['cv', 'dataset']]
 .value_counts()
 .reset_index(name='n'))
# Out:
#     cv           dataset  n
# 0    4          Wang2014  2
# 1    2  Doench2014_mouse  2
# 2    0  Doench2014_mouse  2
# 3    0        Doench2016  2
# 4    0     Kim2019_train  2
# 5    0          Wang2014  2
# 6    1  Doench2014_human  2
# 7    1  Doench2014_mouse  2
# 8    1        Doench2016  2
# 9    1     Kim2019_train  2
# 10   1          Wang2014  2
# 11   2  Doench2014_human  2
# 12   2        Doench2016  2
# 13   4     Kim2019_train  2
# 14   2     Kim2019_train  2
# 15   2          Wang2014  2
# 16   3        Doench2016  2
# 17   3     Kim2019_train  2
# 18   3          Wang2014  2
# 19   4  Doench2014_mouse  2
# 20   4        Doench2016  2
# 21   3  Doench2014_human  1
# 22   3  Doench2014_mouse  1
# 23   4  Doench2014_human  1
# 24   0  Doench2014_human  1

# %% [markdown]
# The size of the training and testing sets are approximately equal across folds,
# with training sets varying between 13,107 (fold 2) - 15,847 (fold 3) sgRNAs and testing sets varying
# between 2,707 (fold 3) - 5,447 (fold 2) sgRNAs

# %%
(tidy_cv_df[['cv','train']].value_counts()
 .reset_index(name='n')
 .sort_values(['cv', 'train']))
# Out:
#    cv  train      n
# 6   0  False   3843
# 3   0   True  14711
# 8   1  False   3033
# 1   1   True  15521
# 5   2  False   5447
# 4   2   True  13107
# 9   3  False   2707
# 0   3   True  15847
# 7   4  False   3524
# 2   4   True  15030

# %% [markdown]
# Indeed each gene target (gene) only appears in one fold

# %%
(tidy_cv_df[['cv','train', 'target']].value_counts()
 .reset_index(name='n')
 .query('n > 10')
 [['cv', 'target']].value_counts()
 .reset_index(name='train_test_sum')
 .groupby('cv')
 .agg({'train_test_sum': ['max']}))
# Out:
#    train_test_sum
#               max
# cv
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %% [markdown]
# ## Train each dataset separately
# Now we'll move onto training and first we'll train each dataset separately

# %%
single_test_prediction_list = []
for fold, df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    single_test_prediction_list.extend(get_fold_predictions(fold, df))
    print('\n')

single_predictive_performance = get_predictive_performance(single_test_prediction_list)
# Out:
# Fold: 0
#
#
# Fold: 1
#
#
# Fold: 2
#
#
# Fold: 3
#
#
# Fold: 4

# %% [markdown]
# Importantly, all training datasets are successful at predicting held-out test data

# %%
plot_pearson_heatmap(single_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752395535329)>

# %% [markdown]
# We can see that the Kim training data outperforms all the rest, but it's also quite a bit bigger than the next biggest dataset

# %%
plot_relative_performance(single_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/stat_boxplot.py:86: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752392124377)>

# %% [markdown]
# ## Combining training datasets
#
# If we merge the training datasets, can we improve our performance?
# We'll merge by normalizing activity to a percent rank.

# %%
top_training_set = (single_predictive_performance.groupby('model_name')
                    .agg({'relative_performance': 'median'})
                    .reset_index()
                    .sort_values('relative_performance', ascending=False)
                    ['model_name']
                    .values[0])
print('Top training set: ' + top_training_set)
# Out:
# Top training set: Kim2019_train

# %%
combined_test_prediction_list = []
for fold, df in tidy_cv_df.groupby('cv'):
    print('Fold: '+ str(fold))
    combined_test_prediction_list.extend(get_fold_predictions(fold, df, top_training_set=top_training_set))
    print('\n')

combined_predictive_performance = get_predictive_performance(combined_test_prediction_list)
# Out:
# Fold: 0
#
#
# Fold: 1
#
#
# Fold: 2
#
#
# Fold: 3
#
#
# Fold: 4

# %%
plot_pearson_heatmap(combined_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752362772401)>

# %%
plot_relative_performance(combined_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/stat_boxplot.py:86: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752385918241)>

# %% [markdown]
# We'll keep all training sets that don't significantly reduce predictive performance, which is all training sets

# %%
ttest_list = []
reference_scores = (combined_predictive_performance
                    .loc[combined_predictive_performance['model_name'] == top_training_set, 'pearson_r'])
for model_name, training_set_df in combined_predictive_performance.groupby('model_name'):
    compare_scores = training_set_df['pearson_r']
    t, p = stats.ttest_rel(reference_scores, compare_scores)
    ttest_list.append({'model_name': model_name, 't': t, 'p': p})
ttest_df = pd.DataFrame(ttest_list)
ttest_df.sort_values('t')
# Out:
#                          model_name         t         p
# 4          Wang2014 + Kim2019_train -1.681867  0.108144
# 3  Doench2014_mouse + Kim2019_train -1.176921  0.253044
# 2        Doench2016 + Kim2019_train -0.881635  0.388447
# 0  Doench2014_human + Kim2019_train  0.191361  0.850172
# 1                     Kim2019_train       NaN       NaN

# %% [markdown]
# We'll try combining all datasets which don't significantly decrease performance

# %%
combine_datasets =  (ttest_df
    .loc[(ttest_df.t.fillna(0) < 0) | (ttest_df.p.fillna(1) > 0.05), 'model_name']
    .str.split(' \+ ', expand=True)[0])
print('Combine datasets: ' + ', '.join(combine_datasets))
# Out:
# Combine datasets: Doench2014_human, Kim2019_train, Doench2016, Doench2014_mouse, Wang2014

# %%
top_combined_test_prediction_list = []
for fold, df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    top_combined_test_prediction_list.extend(get_fold_predictions(fold, df, combine_datasets=combine_datasets,
                                                                  model_name='All train data'))
    print('\n')

top_dual_model = ttest_df.sort_values('t')['model_name'].values[0]
print('Reference model: ' + str(top_dual_model))
top_dual_prediction_list = [df for df in combined_test_prediction_list if (df.model_name == top_dual_model).all()]
top_combined_predictive_performance = get_predictive_performance(top_combined_test_prediction_list +
                                                                 top_dual_prediction_list)
# Out:
# Fold: 0
#
#
# Fold: 1
#
#
# Fold: 2
#
#
# Fold: 3
#
#
# Fold: 4
#
#
# Reference model: Wang2014 + Kim2019_train

# %%
plot_pearson_heatmap(top_combined_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752339701189)>

# %%
plot_relative_performance(top_combined_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/stat_boxplot.py:86: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752336843293)>

# %% [markdown]
# ## Sequence Model Hyperparameter Tuning
#
# Using the combined datasets, we'll try different model architectures and use hyperparameter tuning.
# For the hyperparmeter tuning, we'll use the [optuna library](https://optuna.readthedocs.io/en/stable/index.html),
# which by default uses the Tree-structured Parzen Estimator to search the hyperparameter space.

# %%
n_trials = 50

# %% [markdown]
# ### LightGBM

# %%
def lgbm_training_iteration(fold_df, train_index, test_index, base_model):
    """Train lgbm model for optuna iterations

    :param fold_df: DataFrame
    :param train_index: list-like
    :param test_index: list-like
    :param base_model: LGBMRegressor
    :return: r^2
    """
    train_df = fold_df.iloc[train_index,:].reset_index(drop=True)
    train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                  ['sgRNA Activity']
                                  .rank(pct=True))
    X_train_val = sglearn.featurize_guides(train_df['sgRNA Context Sequence']) # train and validation data
    y_train_val = train_df['sgRNA Activity']
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val,
                                                      test_size=0.1, random_state=7)
    model = clone(base_model)
    model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_val, y_val)], verbose=False)
    test_df = fold_df.iloc[test_index,:].reset_index(drop=True)
    X_test = sglearn.featurize_guides(test_df['sgRNA Context Sequence'])
    test_predictions = test_df.copy()
    test_predictions['prediction'] = model.predict(X_test)
    test_predictions['sgRNA Activity'] = (test_predictions.groupby('dataset')
                                          ['sgRNA Activity']
                                          .rank(pct=True))
    r2 = r2_score(test_predictions['sgRNA Activity'], test_predictions['prediction'])
    return r2


def get_lgbm_objective(fold_df):
    """Get objective function for training a lgbm model

    :param fold_df: DataFrame
    :return: obejctive function
    """
    def objective(trial):
        """For training set, get optimal hyperparameters for lgbm

        :param trial: optuna.trial
        :return: int, pearson correlation with held out test data
        """
        sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=7)
        num_leaves = trial.suggest_int('num_leaves', 8, 256)
        min_child_samples = trial.suggest_int('min_child_samples', 8, 256)
        model = LGBMRegressor(random_state=7, learning_rate=0.01, 
                              n_estimators=5000,
                              num_leaves=num_leaves,
                              min_child_samples=min_child_samples)
        performance = Parallel(n_jobs=5)(delayed(lgbm_training_iteration)
                                         (fold_df, train_index, test_index, model) for
                                         train_index, test_index in
                                         sgkf.split(fold_df, fold_df.dataset, fold_df.target))
        avg_performance = np.mean(performance)
        return avg_performance
    return objective

# %%
lgbm_prediction_list = []

for fold, fold_df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    fold_train_data = fold_df.query('train == True').reset_index(drop=True)
    study = optuna.create_study(direction='maximize',
                                sampler=optuna.samplers.TPESampler(seed=7)) # maximize r^2
    objective = get_lgbm_objective(fold_train_data)
    start_time = datetime.now()
    study.optimize(objective, n_trials=n_trials)
    end_time = datetime.now()
    difference = end_time - start_time
    print("Number of finished trials: {}".format(len(study.trials)))
    print("Training Time: " + str(difference))
    print("Best trial:")
    trial = study.best_trial
    print("  Value: {}".format(trial.value))
    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
    # Using optimal parameters, retrain model with full dataset
    train_df = fold_train_data.copy()
    train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                  ['sgRNA Activity']
                                  .rank(pct=True))
    X_train_val = sglearn.featurize_guides(train_df['sgRNA Context Sequence'])
    y_train_val = train_df['sgRNA Activity']
    X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val,
                                                      test_size=0.1, random_state=7)
    model = LGBMRegressor(random_state=7, learning_rate=0.01, n_estimators=5000, 
                          n_jobs=8,
                          **trial.params)
    model.fit(X_train, y_train, early_stopping_rounds=20, eval_set=[(X_val, y_val)], verbose=1000)
    # Test optimal model on test data
    fold_test_data = fold_df.query('train == False').reset_index(drop=True)
    X_test = sglearn.featurize_guides(fold_test_data['sgRNA Context Sequence'])
    test_predictions = fold_test_data.copy()
    test_predictions['prediction'] = model.predict(X_test)
    test_predictions['model_name'] = 'All train data + LGBM + TPE' + str(n_trials)
    test_predictions['fold'] = fold
    lgbm_prediction_list.append(test_predictions)
# Out:
# [I 2021-04-14 22:05:20,266] A new study created in memory with name: no-name-8d316a62-0a78-435c-9cb2-a056873b9882
# Fold: 0
# [I 2021-04-14 22:06:12,673] Trial 0 finished with value: 0.4785379582888753 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:07:00,741] Trial 1 finished with value: 0.4759026156053194 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:07:48,640] Trial 2 finished with value: 0.47498406728158366 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:08:36,352] Trial 3 finished with value: 0.4633012437037605 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:09:23,195] Trial 4 finished with value: 0.47474069302288885 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:10:11,838] Trial 5 finished with value: 0.47670710481700473 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:10:58,929] Trial 6 finished with value: 0.46648080389043856 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:11:45,834] Trial 7 finished with value: 0.47354067102180597 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:12:31,898] Trial 8 finished with value: 0.4745437293324808 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:13:22,521] Trial 9 finished with value: 0.4438952314648028 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:14:09,146] Trial 10 finished with value: 0.4777554161165912 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:14:58,615] Trial 11 finished with value: 0.46825134176451766 and parameters: {'num_leaves': 10, 'min_child_samples': 74}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:15:51,193] Trial 12 finished with value: 0.4733751381304206 and parameters: {'num_leaves': 14, 'min_child_samples': 82}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:16:42,433] Trial 13 finished with value: 0.47748225200873773 and parameters: {'num_leaves': 37, 'min_child_samples': 167}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:17:36,847] Trial 14 finished with value: 0.4695631244108691 and parameters: {'num_leaves': 8, 'min_child_samples': 249}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:18:25,693] Trial 15 finished with value: 0.47024211183743747 and parameters: {'num_leaves': 164, 'min_child_samples': 73}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:19:12,592] Trial 16 finished with value: 0.4777645598403752 and parameters: {'num_leaves': 48, 'min_child_samples': 98}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:20:01,312] Trial 17 finished with value: 0.47591475811340855 and parameters: {'num_leaves': 55, 'min_child_samples': 102}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:20:52,462] Trial 18 finished with value: 0.4772364656133844 and parameters: {'num_leaves': 41, 'min_child_samples': 163}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:21:42,146] Trial 19 finished with value: 0.47598260915383916 and parameters: {'num_leaves': 100, 'min_child_samples': 219}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:22:32,743] Trial 20 finished with value: 0.4636488895077592 and parameters: {'num_leaves': 168, 'min_child_samples': 50}. Best is trial 0 with value: 0.4785379582888753.
# [I 2021-04-14 22:23:20,674] Trial 21 finished with value: 0.47873155035739845 and parameters: {'num_leaves': 29, 'min_child_samples': 103}. Best is trial 21 with value: 0.47873155035739845.
# [I 2021-04-14 22:24:07,799] Trial 22 finished with value: 0.4790136191329328 and parameters: {'num_leaves': 29, 'min_child_samples': 104}. Best is trial 22 with value: 0.4790136191329328.
# [I 2021-04-14 22:24:57,259] Trial 23 finished with value: 0.4791461499667188 and parameters: {'num_leaves': 24, 'min_child_samples': 154}. Best is trial 23 with value: 0.4791461499667188.
# [I 2021-04-14 22:25:46,486] Trial 24 finished with value: 0.4765517014712355 and parameters: {'num_leaves': 84, 'min_child_samples': 155}. Best is trial 23 with value: 0.4791461499667188.
# [I 2021-04-14 22:26:36,338] Trial 25 finished with value: 0.47379959309215885 and parameters: {'num_leaves': 13, 'min_child_samples': 114}. Best is trial 23 with value: 0.4791461499667188.
# [I 2021-04-14 22:27:23,282] Trial 26 finished with value: 0.4751568575137982 and parameters: {'num_leaves': 63, 'min_child_samples': 50}. Best is trial 23 with value: 0.4791461499667188.
# [I 2021-04-14 22:28:12,066] Trial 27 finished with value: 0.47816864724580543 and parameters: {'num_leaves': 29, 'min_child_samples': 186}. Best is trial 23 with value: 0.4791461499667188.
# [I 2021-04-14 22:28:59,084] Trial 28 finished with value: 0.4743270411638866 and parameters: {'num_leaves': 216, 'min_child_samples': 139}. Best is trial 23 with value: 0.4791461499667188.
# [I 2021-04-14 22:29:46,402] Trial 29 finished with value: 0.47914974524407955 and parameters: {'num_leaves': 26, 'min_child_samples': 117}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:30:34,424] Trial 30 finished with value: 0.47421046875329154 and parameters: {'num_leaves': 141, 'min_child_samples': 179}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:31:21,759] Trial 31 finished with value: 0.4760770317120594 and parameters: {'num_leaves': 25, 'min_child_samples': 111}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:32:16,268] Trial 32 finished with value: 0.4680082663450874 and parameters: {'num_leaves': 8, 'min_child_samples': 149}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:33:03,481] Trial 33 finished with value: 0.4773015426711556 and parameters: {'num_leaves': 43, 'min_child_samples': 91}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:33:51,252] Trial 34 finished with value: 0.47708354043197587 and parameters: {'num_leaves': 24, 'min_child_samples': 127}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:34:39,817] Trial 35 finished with value: 0.4740865473809633 and parameters: {'num_leaves': 66, 'min_child_samples': 137}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:35:26,647] Trial 36 finished with value: 0.4705343520441117 and parameters: {'num_leaves': 94, 'min_child_samples': 48}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:36:13,697] Trial 37 finished with value: 0.47046007701568726 and parameters: {'num_leaves': 116, 'min_child_samples': 64}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:36:59,515] Trial 38 finished with value: 0.4756731873636233 and parameters: {'num_leaves': 54, 'min_child_samples': 108}. Best is trial 29 with value: 0.47914974524407955.
# [I 2021-04-14 22:37:48,686] Trial 39 finished with value: 0.48029599149133445 and parameters: {'num_leaves': 35, 'min_child_samples': 121}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:38:35,438] Trial 40 finished with value: 0.47363081567166765 and parameters: {'num_leaves': 72, 'min_child_samples': 125}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:39:27,750] Trial 41 finished with value: 0.4798908653593519 and parameters: {'num_leaves': 31, 'min_child_samples': 94}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:40:14,072] Trial 42 finished with value: 0.4781518417818341 and parameters: {'num_leaves': 40, 'min_child_samples': 91}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:41:04,664] Trial 43 finished with value: 0.47732371229877824 and parameters: {'num_leaves': 17, 'min_child_samples': 122}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:41:51,598] Trial 44 finished with value: 0.47719955816942117 and parameters: {'num_leaves': 35, 'min_child_samples': 145}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:42:40,087] Trial 45 finished with value: 0.47443707665710855 and parameters: {'num_leaves': 84, 'min_child_samples': 133}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:43:26,503] Trial 46 finished with value: 0.47697251582183375 and parameters: {'num_leaves': 51, 'min_child_samples': 90}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:44:13,366] Trial 47 finished with value: 0.47492446512143455 and parameters: {'num_leaves': 19, 'min_child_samples': 63}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:44:59,715] Trial 48 finished with value: 0.4796461714975536 and parameters: {'num_leaves': 36, 'min_child_samples': 118}. Best is trial 39 with value: 0.48029599149133445.
# [I 2021-04-14 22:45:48,882] Trial 49 finished with value: 0.47585897844711933 and parameters: {'num_leaves': 57, 'min_child_samples': 166}. Best is trial 39 with value: 0.48029599149133445.
# Number of finished trials: 50
# Training Time: 0:40:28.616044
# Best trial:
#   Value: 0.48029599149133445
#   Params:
#     num_leaves: 35
#     min_child_samples: 121
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.0432529
# Early stopping, best iteration is:
# [1452]	valid_0's l2: 0.0422828
# [I 2021-04-14 22:46:22,780] A new study created in memory with name: no-name-c3912c40-eaf9-4d27-8e82-75b74eb85c18
# Fold: 1
# [I 2021-04-14 22:47:11,379] Trial 0 finished with value: 0.45499448598780184 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.45499448598780184.
# [I 2021-04-14 22:47:59,186] Trial 1 finished with value: 0.4552953063046722 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 1 with value: 0.4552953063046722.
# [I 2021-04-14 22:48:47,119] Trial 2 finished with value: 0.4556364551598039 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 2 with value: 0.4556364551598039.
# [I 2021-04-14 22:49:35,152] Trial 3 finished with value: 0.4420992467339076 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 2 with value: 0.4556364551598039.
# [I 2021-04-14 22:50:23,398] Trial 4 finished with value: 0.45579240262481135 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 4 with value: 0.45579240262481135.
# [I 2021-04-14 22:51:11,592] Trial 5 finished with value: 0.4539515343500093 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 4 with value: 0.45579240262481135.
# [I 2021-04-14 22:51:59,052] Trial 6 finished with value: 0.4443365614477317 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 4 with value: 0.45579240262481135.
# [I 2021-04-14 22:52:46,425] Trial 7 finished with value: 0.4527547792119119 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 4 with value: 0.45579240262481135.
# [I 2021-04-14 22:53:34,579] Trial 8 finished with value: 0.45478098329744404 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 4 with value: 0.45579240262481135.
# [I 2021-04-14 22:54:24,573] Trial 9 finished with value: 0.42339548503094704 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 4 with value: 0.45579240262481135.
# [I 2021-04-14 22:55:12,470] Trial 10 finished with value: 0.4571138199611573 and parameters: {'num_leaves': 34, 'min_child_samples': 94}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 22:56:01,283] Trial 11 finished with value: 0.44884955309425345 and parameters: {'num_leaves': 10, 'min_child_samples': 99}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 22:56:49,490] Trial 12 finished with value: 0.45606819293114764 and parameters: {'num_leaves': 42, 'min_child_samples': 85}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 22:57:34,442] Trial 13 finished with value: 0.4545728556207226 and parameters: {'num_leaves': 33, 'min_child_samples': 68}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 22:58:21,447] Trial 14 finished with value: 0.44437449070521673 and parameters: {'num_leaves': 9, 'min_child_samples': 66}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 22:59:10,153] Trial 15 finished with value: 0.44922466150685436 and parameters: {'num_leaves': 157, 'min_child_samples': 69}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 22:59:57,404] Trial 16 finished with value: 0.45482805604655974 and parameters: {'num_leaves': 51, 'min_child_samples': 164}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:00:43,342] Trial 17 finished with value: 0.4493591342786466 and parameters: {'num_leaves': 203, 'min_child_samples': 83}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:01:29,923] Trial 18 finished with value: 0.4536447702479373 and parameters: {'num_leaves': 41, 'min_child_samples': 42}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:02:18,352] Trial 19 finished with value: 0.4534566759438876 and parameters: {'num_leaves': 81, 'min_child_samples': 108}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:03:08,320] Trial 20 finished with value: 0.45205528483509816 and parameters: {'num_leaves': 10, 'min_child_samples': 155}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:03:57,999] Trial 21 finished with value: 0.4564008374160635 and parameters: {'num_leaves': 79, 'min_child_samples': 125}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:04:45,295] Trial 22 finished with value: 0.4505199353750859 and parameters: {'num_leaves': 100, 'min_child_samples': 91}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:05:32,807] Trial 23 finished with value: 0.4565730858734514 and parameters: {'num_leaves': 59, 'min_child_samples': 120}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:06:20,090] Trial 24 finished with value: 0.4527604339016415 and parameters: {'num_leaves': 70, 'min_child_samples': 119}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:07:08,280] Trial 25 finished with value: 0.4539701978225891 and parameters: {'num_leaves': 100, 'min_child_samples': 164}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:07:57,324] Trial 26 finished with value: 0.45708779763562435 and parameters: {'num_leaves': 25, 'min_child_samples': 142}. Best is trial 10 with value: 0.4571138199611573.
# [I 2021-04-14 23:08:46,037] Trial 27 finished with value: 0.4576877272891905 and parameters: {'num_leaves': 23, 'min_child_samples': 147}. Best is trial 27 with value: 0.4576877272891905.
# [I 2021-04-14 23:09:35,860] Trial 28 finished with value: 0.4565728585392441 and parameters: {'num_leaves': 23, 'min_child_samples': 183}. Best is trial 27 with value: 0.4576877272891905.
# [I 2021-04-14 23:10:24,379] Trial 29 finished with value: 0.4577031393817621 and parameters: {'num_leaves': 26, 'min_child_samples': 152}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:11:14,446] Trial 30 finished with value: 0.4534408611603264 and parameters: {'num_leaves': 15, 'min_child_samples': 226}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:12:03,517] Trial 31 finished with value: 0.456897695862847 and parameters: {'num_leaves': 25, 'min_child_samples': 145}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:12:51,855] Trial 32 finished with value: 0.4572844107754472 and parameters: {'num_leaves': 34, 'min_child_samples': 174}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:13:40,673] Trial 33 finished with value: 0.4560287145715437 and parameters: {'num_leaves': 43, 'min_child_samples': 181}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:14:31,888] Trial 34 finished with value: 0.4570749309720126 and parameters: {'num_leaves': 33, 'min_child_samples': 201}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:15:23,648] Trial 35 finished with value: 0.4522272359010814 and parameters: {'num_leaves': 11, 'min_child_samples': 173}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:16:11,923] Trial 36 finished with value: 0.4538949169093261 and parameters: {'num_leaves': 56, 'min_child_samples': 199}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:17:00,172] Trial 37 finished with value: 0.45670877043879204 and parameters: {'num_leaves': 121, 'min_child_samples': 139}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:17:49,876] Trial 38 finished with value: 0.4575882609315644 and parameters: {'num_leaves': 41, 'min_child_samples': 156}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:18:42,003] Trial 39 finished with value: 0.45373359955252174 and parameters: {'num_leaves': 91, 'min_child_samples': 250}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:19:32,901] Trial 40 finished with value: 0.4561396057608721 and parameters: {'num_leaves': 140, 'min_child_samples': 155}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:20:23,324] Trial 41 finished with value: 0.45504444864441085 and parameters: {'num_leaves': 48, 'min_child_samples': 169}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:21:12,626] Trial 42 finished with value: 0.4562129829140532 and parameters: {'num_leaves': 33, 'min_child_samples': 156}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:22:01,902] Trial 43 finished with value: 0.4535738298308945 and parameters: {'num_leaves': 62, 'min_child_samples': 215}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:22:51,700] Trial 44 finished with value: 0.45579942787855776 and parameters: {'num_leaves': 19, 'min_child_samples': 192}. Best is trial 29 with value: 0.4577031393817621.
# [I 2021-04-14 23:23:42,063] Trial 45 finished with value: 0.4581253465791546 and parameters: {'num_leaves': 38, 'min_child_samples': 132}. Best is trial 45 with value: 0.4581253465791546.
# [I 2021-04-14 23:24:32,905] Trial 46 finished with value: 0.45813144840395237 and parameters: {'num_leaves': 46, 'min_child_samples': 134}. Best is trial 46 with value: 0.45813144840395237.
# [I 2021-04-14 23:25:21,547] Trial 47 finished with value: 0.45527261088530757 and parameters: {'num_leaves': 68, 'min_child_samples': 131}. Best is trial 46 with value: 0.45813144840395237.
# [I 2021-04-14 23:26:09,363] Trial 48 finished with value: 0.4554697109153564 and parameters: {'num_leaves': 52, 'min_child_samples': 112}. Best is trial 46 with value: 0.45813144840395237.
# [I 2021-04-14 23:26:57,170] Trial 49 finished with value: 0.4558370878087709 and parameters: {'num_leaves': 86, 'min_child_samples': 148}. Best is trial 46 with value: 0.45813144840395237.
# Number of finished trials: 50
# Training Time: 0:40:34.390260
# Best trial:
#   Value: 0.45813144840395237
#   Params:
#     num_leaves: 46
#     min_child_samples: 134
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.0444743
# Early stopping, best iteration is:
# [1245]	valid_0's l2: 0.0440121
# [I 2021-04-14 23:27:32,225] A new study created in memory with name: no-name-0634e25e-f7b0-4561-ab98-b1d277767dc5
# Fold: 2
# [I 2021-04-14 23:28:11,875] Trial 0 finished with value: 0.4650780498727693 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.4650780498727693.
# [I 2021-04-14 23:28:53,897] Trial 1 finished with value: 0.46626861819783993 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 1 with value: 0.46626861819783993.
# [I 2021-04-14 23:29:37,264] Trial 2 finished with value: 0.469837081171229 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:30:19,701] Trial 3 finished with value: 0.4525928629943678 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:31:01,684] Trial 4 finished with value: 0.4654039539289463 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:31:45,215] Trial 5 finished with value: 0.46870337984880034 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:32:27,813] Trial 6 finished with value: 0.4596354034861837 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:33:08,924] Trial 7 finished with value: 0.4627124349572759 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:33:52,342] Trial 8 finished with value: 0.46508227948514175 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:34:38,884] Trial 9 finished with value: 0.43732779846047887 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:35:22,009] Trial 10 finished with value: 0.46662864026740836 and parameters: {'num_leaves': 243, 'min_child_samples': 94}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:36:03,866] Trial 11 finished with value: 0.4665920990135829 and parameters: {'num_leaves': 187, 'min_child_samples': 168}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:36:45,715] Trial 12 finished with value: 0.46387865950071666 and parameters: {'num_leaves': 187, 'min_child_samples': 246}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:37:27,777] Trial 13 finished with value: 0.46246477694191857 and parameters: {'num_leaves': 189, 'min_child_samples': 70}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:38:08,291] Trial 14 finished with value: 0.4660461279875651 and parameters: {'num_leaves': 214, 'min_child_samples': 161}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:38:49,977] Trial 15 finished with value: 0.46713417491979037 and parameters: {'num_leaves': 150, 'min_child_samples': 213}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:39:29,909] Trial 16 finished with value: 0.46504949547988284 and parameters: {'num_leaves': 158, 'min_child_samples': 146}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:40:12,357] Trial 17 finished with value: 0.46360094799518 and parameters: {'num_leaves': 249, 'min_child_samples': 256}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:40:53,881] Trial 18 finished with value: 0.46640663898235674 and parameters: {'num_leaves': 213, 'min_child_samples': 101}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:41:33,492] Trial 19 finished with value: 0.4669327547051971 and parameters: {'num_leaves': 218, 'min_child_samples': 182}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:42:15,056] Trial 20 finished with value: 0.4675115735846491 and parameters: {'num_leaves': 256, 'min_child_samples': 218}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:43:00,536] Trial 21 finished with value: 0.4654522941185556 and parameters: {'num_leaves': 254, 'min_child_samples': 230}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:43:42,844] Trial 22 finished with value: 0.4645452580730959 and parameters: {'num_leaves': 165, 'min_child_samples': 217}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:44:23,677] Trial 23 finished with value: 0.465539221860438 and parameters: {'num_leaves': 226, 'min_child_samples': 199}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:45:04,266] Trial 24 finished with value: 0.45830165748265966 and parameters: {'num_leaves': 205, 'min_child_samples': 62}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:45:44,846] Trial 25 finished with value: 0.46499760407980295 and parameters: {'num_leaves': 236, 'min_child_samples': 167}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:46:27,232] Trial 26 finished with value: 0.46452528148716465 and parameters: {'num_leaves': 255, 'min_child_samples': 255}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:47:09,778] Trial 27 finished with value: 0.46586937154256985 and parameters: {'num_leaves': 197, 'min_child_samples': 229}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:47:51,519] Trial 28 finished with value: 0.4674772421972294 and parameters: {'num_leaves': 170, 'min_child_samples': 145}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:48:34,152] Trial 29 finished with value: 0.4674709643169561 and parameters: {'num_leaves': 20, 'min_child_samples': 205}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:49:17,500] Trial 30 finished with value: 0.4686376957936794 and parameters: {'num_leaves': 231, 'min_child_samples': 184}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:49:58,106] Trial 31 finished with value: 0.4647215090406819 and parameters: {'num_leaves': 231, 'min_child_samples': 192}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:50:39,678] Trial 32 finished with value: 0.465174575040394 and parameters: {'num_leaves': 253, 'min_child_samples': 183}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:51:21,207] Trial 33 finished with value: 0.4656546875452879 and parameters: {'num_leaves': 137, 'min_child_samples': 178}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:52:02,540] Trial 34 finished with value: 0.4652964059897774 and parameters: {'num_leaves': 230, 'min_child_samples': 156}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:52:44,175] Trial 35 finished with value: 0.46611461234459206 and parameters: {'num_leaves': 177, 'min_child_samples': 126}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:53:24,619] Trial 36 finished with value: 0.4655356995078142 and parameters: {'num_leaves': 110, 'min_child_samples': 220}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:54:04,321] Trial 37 finished with value: 0.46376820805061775 and parameters: {'num_leaves': 204, 'min_child_samples': 207}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:54:49,657] Trial 38 finished with value: 0.46703134297681503 and parameters: {'num_leaves': 220, 'min_child_samples': 242}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:55:30,015] Trial 39 finished with value: 0.466728926847925 and parameters: {'num_leaves': 144, 'min_child_samples': 143}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:56:12,132] Trial 40 finished with value: 0.46752409260081285 and parameters: {'num_leaves': 50, 'min_child_samples': 110}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:56:53,896] Trial 41 finished with value: 0.46526836892395096 and parameters: {'num_leaves': 54, 'min_child_samples': 105}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:57:34,269] Trial 42 finished with value: 0.46376546934945334 and parameters: {'num_leaves': 89, 'min_child_samples': 83}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:58:14,101] Trial 43 finished with value: 0.465422815974217 and parameters: {'num_leaves': 121, 'min_child_samples': 122}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:58:55,006] Trial 44 finished with value: 0.46766421462364305 and parameters: {'num_leaves': 44, 'min_child_samples': 134}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-14 23:59:36,087] Trial 45 finished with value: 0.46972452220173916 and parameters: {'num_leaves': 40, 'min_child_samples': 131}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-15 00:00:16,607] Trial 46 finished with value: 0.46861840108124914 and parameters: {'num_leaves': 34, 'min_child_samples': 137}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-15 00:00:59,062] Trial 47 finished with value: 0.46764318380013326 and parameters: {'num_leaves': 40, 'min_child_samples': 156}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-15 00:01:41,364] Trial 48 finished with value: 0.46785640668475736 and parameters: {'num_leaves': 34, 'min_child_samples': 171}. Best is trial 2 with value: 0.469837081171229.
# [I 2021-04-15 00:02:25,950] Trial 49 finished with value: 0.46749685404814983 and parameters: {'num_leaves': 71, 'min_child_samples': 135}. Best is trial 2 with value: 0.469837081171229.
# Number of finished trials: 50
# Training Time: 0:34:53.724422
# Best trial:
#   Value: 0.469837081171229
#   Params:
#     num_leaves: 251
#     min_child_samples: 142
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.0415305
# Early stopping, best iteration is:
# [1039]	valid_0's l2: 0.0415084
# [I 2021-04-15 00:03:02,507] A new study created in memory with name: no-name-55cd1574-112b-45ed-aac7-99a15ad644d9
# Fold: 3
# [I 2021-04-15 00:03:55,844] Trial 0 finished with value: 0.46242032073694916 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:04:46,368] Trial 1 finished with value: 0.4584085777410657 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:05:37,958] Trial 2 finished with value: 0.45771673573662064 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:06:28,568] Trial 3 finished with value: 0.447186520791312 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:07:19,515] Trial 4 finished with value: 0.45950677323269806 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:08:11,766] Trial 5 finished with value: 0.4612514018632196 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:09:02,754] Trial 6 finished with value: 0.4498192185112517 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:09:56,388] Trial 7 finished with value: 0.45861682078867616 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:10:48,498] Trial 8 finished with value: 0.46042921757158917 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:11:42,793] Trial 9 finished with value: 0.4247312253559491 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:12:34,010] Trial 10 finished with value: 0.4604616032843662 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:13:28,456] Trial 11 finished with value: 0.45975015494103577 and parameters: {'num_leaves': 186, 'min_child_samples': 254}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:14:23,111] Trial 12 finished with value: 0.4602644154609325 and parameters: {'num_leaves': 188, 'min_child_samples': 207}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:15:16,646] Trial 13 finished with value: 0.4599587006439423 and parameters: {'num_leaves': 177, 'min_child_samples': 186}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:16:15,098] Trial 14 finished with value: 0.45370229552348096 and parameters: {'num_leaves': 9, 'min_child_samples': 223}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:17:07,914] Trial 15 finished with value: 0.4584285723085495 and parameters: {'num_leaves': 155, 'min_child_samples': 167}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:18:04,720] Trial 16 finished with value: 0.45975015494103577 and parameters: {'num_leaves': 222, 'min_child_samples': 254}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:18:58,461] Trial 17 finished with value: 0.4593561725540754 and parameters: {'num_leaves': 212, 'min_child_samples': 162}. Best is trial 0 with value: 0.46242032073694916.
# [I 2021-04-15 00:19:50,658] Trial 18 finished with value: 0.4628543365606815 and parameters: {'num_leaves': 41, 'min_child_samples': 95}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:20:42,856] Trial 19 finished with value: 0.4623081692217069 and parameters: {'num_leaves': 39, 'min_child_samples': 74}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:21:36,093] Trial 20 finished with value: 0.45184408796832987 and parameters: {'num_leaves': 10, 'min_child_samples': 96}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:22:26,105] Trial 21 finished with value: 0.46064318542349036 and parameters: {'num_leaves': 42, 'min_child_samples': 61}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:23:17,054] Trial 22 finished with value: 0.45943287007800676 and parameters: {'num_leaves': 40, 'min_child_samples': 50}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:24:09,991] Trial 23 finished with value: 0.46005645012438323 and parameters: {'num_leaves': 24, 'min_child_samples': 103}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:25:02,282] Trial 24 finished with value: 0.46165995039512947 and parameters: {'num_leaves': 57, 'min_child_samples': 67}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:25:53,376] Trial 25 finished with value: 0.45670363229624183 and parameters: {'num_leaves': 95, 'min_child_samples': 96}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:26:43,464] Trial 26 finished with value: 0.4573677095493719 and parameters: {'num_leaves': 45, 'min_child_samples': 44}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:27:38,968] Trial 27 finished with value: 0.46142020064074024 and parameters: {'num_leaves': 23, 'min_child_samples': 119}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:28:33,483] Trial 28 finished with value: 0.44783706056327366 and parameters: {'num_leaves': 8, 'min_child_samples': 76}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:29:25,179] Trial 29 finished with value: 0.458663759059602 and parameters: {'num_leaves': 128, 'min_child_samples': 151}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:30:17,632] Trial 30 finished with value: 0.4602849641357092 and parameters: {'num_leaves': 79, 'min_child_samples': 113}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:31:11,152] Trial 31 finished with value: 0.4598819307720813 and parameters: {'num_leaves': 57, 'min_child_samples': 78}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:32:03,879] Trial 32 finished with value: 0.4623054713572884 and parameters: {'num_leaves': 58, 'min_child_samples': 60}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:32:53,209] Trial 33 finished with value: 0.45565554877910924 and parameters: {'num_leaves': 31, 'min_child_samples': 38}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:33:44,482] Trial 34 finished with value: 0.4553052476099538 and parameters: {'num_leaves': 95, 'min_child_samples': 90}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:34:35,778] Trial 35 finished with value: 0.46091168689929934 and parameters: {'num_leaves': 50, 'min_child_samples': 61}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:35:28,775] Trial 36 finished with value: 0.45919644655066677 and parameters: {'num_leaves': 69, 'min_child_samples': 136}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:36:20,451] Trial 37 finished with value: 0.45216268971836165 and parameters: {'num_leaves': 109, 'min_child_samples': 40}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:37:10,381] Trial 38 finished with value: 0.45168955682758966 and parameters: {'num_leaves': 86, 'min_child_samples': 22}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:38:05,690] Trial 39 finished with value: 0.4585795136962144 and parameters: {'num_leaves': 16, 'min_child_samples': 109}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:38:55,548] Trial 40 finished with value: 0.44952881194726146 and parameters: {'num_leaves': 65, 'min_child_samples': 8}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:39:46,360] Trial 41 finished with value: 0.4591357542549961 and parameters: {'num_leaves': 32, 'min_child_samples': 58}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:40:38,174] Trial 42 finished with value: 0.46145711325628247 and parameters: {'num_leaves': 57, 'min_child_samples': 72}. Best is trial 18 with value: 0.4628543365606815.
# [I 2021-04-15 00:41:29,635] Trial 43 finished with value: 0.4631888133217602 and parameters: {'num_leaves': 37, 'min_child_samples': 86}. Best is trial 43 with value: 0.4631888133217602.
# [I 2021-04-15 00:42:20,996] Trial 44 finished with value: 0.462550661142478 and parameters: {'num_leaves': 40, 'min_child_samples': 86}. Best is trial 43 with value: 0.4631888133217602.
# [I 2021-04-15 00:43:14,032] Trial 45 finished with value: 0.4622189337620354 and parameters: {'num_leaves': 38, 'min_child_samples': 86}. Best is trial 43 with value: 0.4631888133217602.
# [I 2021-04-15 00:44:09,209] Trial 46 finished with value: 0.46007398274253425 and parameters: {'num_leaves': 18, 'min_child_samples': 128}. Best is trial 43 with value: 0.4631888133217602.
# [I 2021-04-15 00:45:03,218] Trial 47 finished with value: 0.46272530377234133 and parameters: {'num_leaves': 48, 'min_child_samples': 85}. Best is trial 43 with value: 0.4631888133217602.
# [I 2021-04-15 00:45:55,217] Trial 48 finished with value: 0.45983703017848077 and parameters: {'num_leaves': 76, 'min_child_samples': 88}. Best is trial 43 with value: 0.4631888133217602.
# [I 2021-04-15 00:46:47,925] Trial 49 finished with value: 0.46267019003819404 and parameters: {'num_leaves': 50, 'min_child_samples': 104}. Best is trial 43 with value: 0.4631888133217602.
# Number of finished trials: 50
# Training Time: 0:43:45.418264
# Best trial:
#   Value: 0.4631888133217602
#   Params:
#     num_leaves: 37
#     min_child_samples: 86
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.0432992
# Early stopping, best iteration is:
# [1430]	valid_0's l2: 0.0426799
# [I 2021-04-15 00:47:23,062] A new study created in memory with name: no-name-8f721dbe-9f4f-4785-8a5f-c80b74713a5d
# Fold: 4
# [I 2021-04-15 00:48:14,855] Trial 0 finished with value: 0.466237400050141 and parameters: {'num_leaves': 27, 'min_child_samples': 202}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:49:08,280] Trial 1 finished with value: 0.4653147839935737 and parameters: {'num_leaves': 117, 'min_child_samples': 188}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:50:01,305] Trial 2 finished with value: 0.4635352071795344 and parameters: {'num_leaves': 251, 'min_child_samples': 142}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:50:55,274] Trial 3 finished with value: 0.450120881276226 and parameters: {'num_leaves': 132, 'min_child_samples': 25}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:51:44,949] Trial 4 finished with value: 0.4624487552958369 and parameters: {'num_leaves': 74, 'min_child_samples': 132}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:52:35,928] Trial 5 finished with value: 0.4639680686920659 and parameters: {'num_leaves': 177, 'min_child_samples': 208}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:53:26,540] Trial 6 finished with value: 0.4536132518460293 and parameters: {'num_leaves': 102, 'min_child_samples': 24}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:54:17,311] Trial 7 finished with value: 0.4628762611091707 and parameters: {'num_leaves': 79, 'min_child_samples': 234}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:55:07,394] Trial 8 finished with value: 0.46269757978258275 and parameters: {'num_leaves': 61, 'min_child_samples': 120}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:56:02,642] Trial 9 finished with value: 0.4299793493046087 and parameters: {'num_leaves': 239, 'min_child_samples': 14}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:56:49,535] Trial 10 finished with value: 0.46145510584716404 and parameters: {'num_leaves': 27, 'min_child_samples': 78}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:57:45,575] Trial 11 finished with value: 0.46002568081199763 and parameters: {'num_leaves': 10, 'min_child_samples': 192}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:58:34,613] Trial 12 finished with value: 0.46102023965802524 and parameters: {'num_leaves': 169, 'min_child_samples': 184}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 00:59:25,763] Trial 13 finished with value: 0.46391595082730197 and parameters: {'num_leaves': 37, 'min_child_samples': 253}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 01:00:16,197] Trial 14 finished with value: 0.4643017562160526 and parameters: {'num_leaves': 130, 'min_child_samples': 169}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 01:01:08,981] Trial 15 finished with value: 0.4655357613103502 and parameters: {'num_leaves': 199, 'min_child_samples': 213}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 01:02:02,078] Trial 16 finished with value: 0.4632628518673984 and parameters: {'num_leaves': 216, 'min_child_samples': 233}. Best is trial 0 with value: 0.466237400050141.
# [I 2021-04-15 01:02:55,621] Trial 17 finished with value: 0.4663246394731947 and parameters: {'num_leaves': 195, 'min_child_samples': 256}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:03:47,612] Trial 18 finished with value: 0.4633743531840384 and parameters: {'num_leaves': 157, 'min_child_samples': 254}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:04:38,780] Trial 19 finished with value: 0.46383429032072093 and parameters: {'num_leaves': 211, 'min_child_samples': 154}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:05:29,167] Trial 20 finished with value: 0.4630687102946224 and parameters: {'num_leaves': 190, 'min_child_samples': 108}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:06:21,438] Trial 21 finished with value: 0.4647087103994626 and parameters: {'num_leaves': 208, 'min_child_samples': 215}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:07:14,821] Trial 22 finished with value: 0.4663246394731947 and parameters: {'num_leaves': 230, 'min_child_samples': 256}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:08:05,728] Trial 23 finished with value: 0.46299845641309056 and parameters: {'num_leaves': 246, 'min_child_samples': 253}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:08:57,624] Trial 24 finished with value: 0.4628762611091707 and parameters: {'num_leaves': 228, 'min_child_samples': 234}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:09:50,298] Trial 25 finished with value: 0.4618777406060037 and parameters: {'num_leaves': 158, 'min_child_samples': 237}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:10:45,773] Trial 26 finished with value: 0.4663246394731947 and parameters: {'num_leaves': 227, 'min_child_samples': 256}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:11:37,557] Trial 27 finished with value: 0.4633743531840384 and parameters: {'num_leaves': 228, 'min_child_samples': 254}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:12:27,237] Trial 28 finished with value: 0.45694038150170213 and parameters: {'num_leaves': 253, 'min_child_samples': 57}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:13:21,865] Trial 29 finished with value: 0.46457733188410816 and parameters: {'num_leaves': 181, 'min_child_samples': 223}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:14:17,162] Trial 30 finished with value: 0.4663246394731947 and parameters: {'num_leaves': 226, 'min_child_samples': 256}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:15:08,357] Trial 31 finished with value: 0.4633743531840384 and parameters: {'num_leaves': 230, 'min_child_samples': 254}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:16:02,740] Trial 32 finished with value: 0.46233700767892183 and parameters: {'num_leaves': 200, 'min_child_samples': 242}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:16:54,839] Trial 33 finished with value: 0.46501939845282464 and parameters: {'num_leaves': 221, 'min_child_samples': 198}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:17:48,320] Trial 34 finished with value: 0.4640226895183104 and parameters: {'num_leaves': 252, 'min_child_samples': 218}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:18:41,525] Trial 35 finished with value: 0.4663246394731947 and parameters: {'num_leaves': 256, 'min_child_samples': 256}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:19:31,910] Trial 36 finished with value: 0.46438259904853185 and parameters: {'num_leaves': 192, 'min_child_samples': 176}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:20:24,194] Trial 37 finished with value: 0.4643163010980179 and parameters: {'num_leaves': 255, 'min_child_samples': 225}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:21:16,174] Trial 38 finished with value: 0.46628380590731366 and parameters: {'num_leaves': 238, 'min_child_samples': 203}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:22:06,293] Trial 39 finished with value: 0.4618449869214117 and parameters: {'num_leaves': 237, 'min_child_samples': 244}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:23:00,413] Trial 40 finished with value: 0.4643163010980179 and parameters: {'num_leaves': 255, 'min_child_samples': 225}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:23:52,379] Trial 41 finished with value: 0.4629474007604821 and parameters: {'num_leaves': 209, 'min_child_samples': 245}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:24:43,323] Trial 42 finished with value: 0.4633743531840384 and parameters: {'num_leaves': 219, 'min_child_samples': 254}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:25:37,210] Trial 43 finished with value: 0.4663246394731947 and parameters: {'num_leaves': 243, 'min_child_samples': 256}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:26:28,151] Trial 44 finished with value: 0.46233700767892183 and parameters: {'num_leaves': 242, 'min_child_samples': 242}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:27:21,087] Trial 45 finished with value: 0.46463043860955083 and parameters: {'num_leaves': 232, 'min_child_samples': 232}. Best is trial 17 with value: 0.4663246394731947.
# [I 2021-04-15 01:28:12,874] Trial 46 finished with value: 0.4665195425261238 and parameters: {'num_leaves': 222, 'min_child_samples': 206}. Best is trial 46 with value: 0.4665195425261238.
# [I 2021-04-15 01:29:04,800] Trial 47 finished with value: 0.4656689906532181 and parameters: {'num_leaves': 245, 'min_child_samples': 207}. Best is trial 46 with value: 0.4665195425261238.
# [I 2021-04-15 01:29:54,761] Trial 48 finished with value: 0.46469566125909073 and parameters: {'num_leaves': 178, 'min_child_samples': 141}. Best is trial 46 with value: 0.4665195425261238.
# [I 2021-04-15 01:30:44,917] Trial 49 finished with value: 0.4616788456869541 and parameters: {'num_leaves': 221, 'min_child_samples': 96}. Best is trial 46 with value: 0.4665195425261238.
# Number of finished trials: 50
# Training Time: 0:43:21.854691
# Best trial:
#   Value: 0.4665195425261238
#   Params:
#     num_leaves: 222
#     min_child_samples: 206
# Training until validation scores don't improve for 20 rounds
# [1000]	valid_0's l2: 0.0446646
# Early stopping, best iteration is:
# [1599]	valid_0's l2: 0.0438578

# %%
lgbm_predictive_performance = get_predictive_performance(top_combined_test_prediction_list +
                                                         lgbm_prediction_list)

# %%
plot_pearson_heatmap(lgbm_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752339089741)>

# %%
plot_relative_performance(lgbm_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/stat_boxplot.py:86: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752385951829)>

# %% [markdown]
# ### Keras Convolutional Neural Network

# %%
def get_cnn(n_conv_layers, filters_per_conv, filter_len,
            nodes_per_dense, dense_dropout_rate, n_dense_layers=1,
            input_shape=(30, 4), activation='relu', initializer='he_uniform',
            pool_size=2, loss='mse', optimizer='Adam'):
    model = keras.models.Sequential()
    model.add(keras.layers.InputLayer(input_shape=input_shape))
    for _ in range(n_conv_layers):
        model.add(keras.layers.Conv1D(filters=filters_per_conv, kernel_size=filter_len,
                                      activation=activation, kernel_initializer=initializer))
        model.add(keras.layers.AveragePooling1D(pool_size=pool_size))
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dropout(dense_dropout_rate))
    for _ in range(n_dense_layers):
        model.add(keras.layers.Dense(nodes_per_dense, activation=activation, kernel_initializer=initializer))
        model.add(keras.layers.Dropout(dense_dropout_rate))
    model.add(keras.layers.Dense(1, activation='linear'))
    model.compile(loss=loss, optimizer=optimizer)
    return model

nt_codes = {'A':[1,0,0,0],
            'C':[0,1,0,0],
            'G':[0,0,1,0],
            'T':[0,0,0,1]}

def encode_seqs(seqs):
    # 3d array with samples x position x nt
    encoded_seqs = np.array([[nt_codes.get(x) for x in seq] for seq in seqs])
    return encoded_seqs


def cnn_training_iteration(fold_df, train_index, test_index, base_model):
    """Train cnn model for optuna iterations

    :param fold_df: DataFrame
    :param train_index: list-like
    :param test_index: list-like
    :param base_model: KerasRegressor
    :return: r^2
    """
    train_df = fold_df.iloc[train_index,:].reset_index(drop=True)
    train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                  ['sgRNA Activity']
                                  .rank(pct=True))
    train_val_seqs = train_df['sgRNA Context Sequence'] # train and validation data
    y_train_val = train_df['sgRNA Activity']
    train_seqs, val_seqs, y_train, y_val = train_test_split(train_val_seqs, y_train_val,
                                                            test_size=0.1, random_state=7)
    X_train = encode_seqs(train_seqs)
    X_val = encode_seqs(val_seqs)
    model = clone(base_model)
    model.fit(X_train, y_train, verbose=0, validation_data=(X_val, y_val),
              callbacks=[keras.callbacks.EarlyStopping(patience=20)])
    test_df = fold_df.iloc[test_index,:].reset_index(drop=True)
    X_test = encode_seqs(test_df['sgRNA Context Sequence'])
    test_predictions = test_df.copy()
    test_predictions['prediction'] = model.predict(X_test)
    test_predictions['sgRNA Activity'] = (test_predictions.groupby('dataset')
                                          ['sgRNA Activity']
                                          .rank(pct=True))
    r2 = r2_score(test_predictions['sgRNA Activity'], test_predictions['prediction'])
    return r2


def get_cnn_objective(fold_df):
    """Get objective function for training a cnn model

    :param fold_df: DataFrame
    :return: objective function
    """
    def objective(trial):
        """For training set, get optimal hyperparameters for cnn

        :param trial: optuna.trial
        :return: int, pearson correlation with held out test data
        """
        sgkf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=7)
        n_conv_layers = trial.suggest_int('n_conv_layers', 1, 2)
        filters_per_conv = trial.suggest_int('filters_per_conv', 32, 256)
        filter_len = trial.suggest_int('filter_len', 2, 8)
        nodes_per_dense = trial.suggest_int('nodes_per_dense', 8, 256)
        dense_dropout_rate = trial.suggest_float('dense_dropout_rate', 0.1, 0.5)
        model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=get_cnn, epochs=5000,
                                                           n_conv_layers=n_conv_layers,
                                                           filters_per_conv=filters_per_conv,
                                                           filter_len=filter_len,
                                                           nodes_per_dense=nodes_per_dense,
                                                           dense_dropout_rate=dense_dropout_rate)
        performance = Parallel(n_jobs=5)(delayed(cnn_training_iteration)
                                         (fold_df, train_index, test_index, model) for
                                         train_index, test_index in
                                         sgkf.split(fold_df, fold_df.dataset, fold_df.target))
        avg_performance = np.mean(performance)
        return avg_performance
    return objective

# %%
cnn_prediction_list = []

for fold, fold_df in tidy_cv_df.groupby('cv'):
    print('Fold: ' + str(fold))
    fold_train_data = fold_df.query('train == True').reset_index(drop=True)
    study = optuna.create_study(direction='maximize',
                                sampler=optuna.samplers.TPESampler(seed=7)) # maximize r^2
    objective = get_cnn_objective(fold_train_data)
    start_time = datetime.now()
    study.optimize(objective, n_trials=n_trials)
    end_time = datetime.now()
    difference = end_time - start_time
    print("Number of finished trials: {}".format(len(study.trials)))
    print("Training Time: " + str(difference))
    print("Best trial:")
    trial = study.best_trial
    print("  Value: {}".format(trial.value))
    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
    # Using optimal parameters, retrain model with full dataset
    train_df = fold_train_data.copy()
    train_df['sgRNA Activity'] = (train_df.groupby('dataset')
                                  ['sgRNA Activity']
                                  .rank(pct=True))
    train_val_seqs = train_df['sgRNA Context Sequence'] # train and validation data
    y_train_val = train_df['sgRNA Activity']
    train_seqs, val_seqs, y_train, y_val = train_test_split(train_val_seqs, y_train_val,
                                                            test_size=0.1, random_state=7)
    X_train = encode_seqs(train_seqs)
    X_val = encode_seqs(val_seqs)
    model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=get_cnn, epochs=5000,
                                                       **trial.params)
    model.fit(X_train, y_train, verbose=0, validation_data=(X_val, y_val),
              callbacks=[keras.callbacks.EarlyStopping(patience=20)])
    # Test optimal model on test data
    fold_test_data = fold_df.query('train == False').reset_index(drop=True)
    X_test = encode_seqs(fold_test_data['sgRNA Context Sequence'])
    test_predictions = fold_test_data.copy()
    test_predictions['prediction'] = model.predict(X_test)
    test_predictions['model_name'] = 'All train data + CNN + TPE' + str(n_trials)
    test_predictions['fold'] = fold
    cnn_prediction_list.append(test_predictions)
# Out:
# [I 2021-04-15 01:31:27,158] A new study created in memory with name: no-name-d1ea1563-a96c-4262-aeca-06707e7c4419
# Fold: 0
# [I 2021-04-15 01:34:24,101] Trial 0 finished with value: 0.4528303328117538 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 207, 'filter_len': 5, 'nodes_per_dense': 188, 'dense_dropout_rate': 0.4911958047986411}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:36:47,315] Trial 1 finished with value: 0.4212413313725626 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 144, 'filter_len': 2, 'nodes_per_dense': 74, 'dense_dropout_rate': 0.299953000330224}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:38:40,036] Trial 2 finished with value: 0.4123808270385004 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 212, 'filter_len': 4, 'nodes_per_dense': 24, 'dense_dropout_rate': 0.21525823972319744}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:40:20,109] Trial 3 finished with value: 0.3738222866749605 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 80, 'filter_len': 5, 'nodes_per_dense': 239, 'dense_dropout_rate': 0.10995969102013921}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:42:59,978] Trial 4 finished with value: 0.44152442494937477 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 245, 'filter_len': 3, 'nodes_per_dense': 144, 'dense_dropout_rate': 0.4636513499546925}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:44:35,075] Trial 5 finished with value: 0.4474489063409008 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 149, 'filter_len': 7, 'nodes_per_dense': 174, 'dense_dropout_rate': 0.2871011438979923}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:46:24,645] Trial 6 finished with value: 0.4342176470234789 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 142, 'filter_len': 4, 'nodes_per_dense': 126, 'dense_dropout_rate': 0.2463561543122372}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:48:18,736] Trial 7 finished with value: 0.4120418111023296 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 204, 'filter_len': 4, 'nodes_per_dense': 150, 'dense_dropout_rate': 0.21041961933227804}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:50:01,729] Trial 8 finished with value: 0.4474472299942594 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 111, 'filter_len': 6, 'nodes_per_dense': 100, 'dense_dropout_rate': 0.2836371911565726}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:52:05,236] Trial 9 finished with value: 0.391429497232057 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 124, 'filter_len': 8, 'nodes_per_dense': 52, 'dense_dropout_rate': 0.3964475491653058}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:54:21,601] Trial 10 finished with value: 0.4472404543801963 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 204, 'filter_len': 6, 'nodes_per_dense': 235, 'dense_dropout_rate': 0.4565491145264152}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:56:16,107] Trial 11 finished with value: 0.4404057601553909 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 177, 'filter_len': 8, 'nodes_per_dense': 192, 'dense_dropout_rate': 0.39185325502666085}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:57:55,029] Trial 12 finished with value: 0.41540318520375763 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 46, 'filter_len': 7, 'nodes_per_dense': 194, 'dense_dropout_rate': 0.3708023892328119}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 01:59:57,805] Trial 13 finished with value: 0.4324908851979787 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 255, 'filter_len': 6, 'nodes_per_dense': 189, 'dense_dropout_rate': 0.1555850979261378}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 02:01:51,808] Trial 14 finished with value: 0.44742506421470374 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 170, 'filter_len': 7, 'nodes_per_dense': 170, 'dense_dropout_rate': 0.3408175954234049}. Best is trial 0 with value: 0.4528303328117538.
# [I 2021-04-15 02:04:28,008] Trial 15 finished with value: 0.4575035789387563 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 234, 'filter_len': 5, 'nodes_per_dense': 224, 'dense_dropout_rate': 0.4878584289721036}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:07:00,586] Trial 16 finished with value: 0.44794063221717495 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 236, 'filter_len': 5, 'nodes_per_dense': 256, 'dense_dropout_rate': 0.48990798704391864}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:10:20,664] Trial 17 finished with value: 0.4441432365490726 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 229, 'filter_len': 3, 'nodes_per_dense': 219, 'dense_dropout_rate': 0.4343243846768656}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:12:46,598] Trial 18 finished with value: 0.44398845561990335 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 186, 'filter_len': 5, 'nodes_per_dense': 211, 'dense_dropout_rate': 0.49948065226970684}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:15:50,272] Trial 19 finished with value: 0.44382104716540693 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 232, 'filter_len': 3, 'nodes_per_dense': 252, 'dense_dropout_rate': 0.43113913552271393}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:18:49,382] Trial 20 finished with value: 0.45068361590873496 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 255, 'filter_len': 4, 'nodes_per_dense': 220, 'dense_dropout_rate': 0.49940071190886876}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:21:47,218] Trial 21 finished with value: 0.4469469322646982 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 255, 'filter_len': 4, 'nodes_per_dense': 217, 'dense_dropout_rate': 0.49897720271683593}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:24:19,399] Trial 22 finished with value: 0.44653728533456133 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 216, 'filter_len': 5, 'nodes_per_dense': 226, 'dense_dropout_rate': 0.4985114022797195}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:26:42,913] Trial 23 finished with value: 0.45520696021071155 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 253, 'filter_len': 6, 'nodes_per_dense': 166, 'dense_dropout_rate': 0.46063470945173607}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:29:14,364] Trial 24 finished with value: 0.4520781890050237 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 194, 'filter_len': 6, 'nodes_per_dense': 117, 'dense_dropout_rate': 0.45403501951139613}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:31:26,428] Trial 25 finished with value: 0.4499103974493844 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 228, 'filter_len': 6, 'nodes_per_dense': 159, 'dense_dropout_rate': 0.41192180710576065}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:33:27,365] Trial 26 finished with value: 0.45074252705985723 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 164, 'filter_len': 7, 'nodes_per_dense': 178, 'dense_dropout_rate': 0.3594413575201454}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:36:05,040] Trial 27 finished with value: 0.45326058694684174 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 221, 'filter_len': 5, 'nodes_per_dense': 197, 'dense_dropout_rate': 0.46377505914767203}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:38:18,022] Trial 28 finished with value: 0.45551787988540865 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 6, 'nodes_per_dense': 203, 'dense_dropout_rate': 0.3266341531847951}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:40:57,483] Trial 29 finished with value: 0.45009309796051833 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 6, 'nodes_per_dense': 246, 'dense_dropout_rate': 0.3483573426370546}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:43:16,847] Trial 30 finished with value: 0.45396396944585266 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 241, 'filter_len': 7, 'nodes_per_dense': 202, 'dense_dropout_rate': 0.3270282049574378}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:45:24,580] Trial 31 finished with value: 0.4490512883835892 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 243, 'filter_len': 7, 'nodes_per_dense': 203, 'dense_dropout_rate': 0.3250168352657335}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:47:14,616] Trial 32 finished with value: 0.44606074814140306 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 242, 'filter_len': 8, 'nodes_per_dense': 169, 'dense_dropout_rate': 0.322289803147416}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:49:48,844] Trial 33 finished with value: 0.4416888079209052 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 253, 'filter_len': 6, 'nodes_per_dense': 146, 'dense_dropout_rate': 0.2617893723285068}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:51:34,625] Trial 34 finished with value: 0.44753898253246643 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 217, 'filter_len': 7, 'nodes_per_dense': 233, 'dense_dropout_rate': 0.3150162132421944}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:53:30,197] Trial 35 finished with value: 0.42995144203083413 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 242, 'filter_len': 6, 'nodes_per_dense': 207, 'dense_dropout_rate': 0.2023578167175739}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:55:48,492] Trial 36 finished with value: 0.399488220216617 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 197, 'filter_len': 5, 'nodes_per_dense': 179, 'dense_dropout_rate': 0.3813680709760473}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 02:57:47,146] Trial 37 finished with value: 0.4360979781908726 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 223, 'filter_len': 7, 'nodes_per_dense': 160, 'dense_dropout_rate': 0.24367222850089407}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:00:03,213] Trial 38 finished with value: 0.43307442526385387 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 44, 'filter_len': 6, 'nodes_per_dense': 106, 'dense_dropout_rate': 0.4139387120114304}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:01:53,899] Trial 39 finished with value: 0.36446965386081265 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 88, 'filter_len': 8, 'nodes_per_dense': 183, 'dense_dropout_rate': 0.28689177699596397}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:04:02,128] Trial 40 finished with value: 0.43844249874421626 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 210, 'filter_len': 7, 'nodes_per_dense': 138, 'dense_dropout_rate': 0.30084900964810823}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:07:12,956] Trial 41 finished with value: 0.4560013460426851 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 246, 'filter_len': 5, 'nodes_per_dense': 198, 'dense_dropout_rate': 0.4709258173927162}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:10:11,331] Trial 42 finished with value: 0.44987260949327934 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 245, 'filter_len': 5, 'nodes_per_dense': 207, 'dense_dropout_rate': 0.47649653807826875}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:12:49,358] Trial 43 finished with value: 0.44164358620569943 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 233, 'filter_len': 4, 'nodes_per_dense': 233, 'dense_dropout_rate': 0.4366831172839407}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:15:58,526] Trial 44 finished with value: 0.4547931549773021 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 250, 'filter_len': 5, 'nodes_per_dense': 162, 'dense_dropout_rate': 0.47934918175296937}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:19:02,953] Trial 45 finished with value: 0.4546311161104987 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 254, 'filter_len': 5, 'nodes_per_dense': 159, 'dense_dropout_rate': 0.4787255025674563}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:22:03,653] Trial 46 finished with value: 0.4512031584573538 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 255, 'filter_len': 4, 'nodes_per_dense': 131, 'dense_dropout_rate': 0.45365173049037616}. Best is trial 15 with value: 0.4575035789387563.
# [I 2021-04-15 03:24:29,659] Trial 47 finished with value: 0.4621975107390897 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 247, 'filter_len': 5, 'nodes_per_dense': 189, 'dense_dropout_rate': 0.4745320133621992}. Best is trial 47 with value: 0.4621975107390897.
# [I 2021-04-15 03:27:02,543] Trial 48 finished with value: 0.40863245422954153 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 209, 'filter_len': 5, 'nodes_per_dense': 14, 'dense_dropout_rate': 0.12673053313681504}. Best is trial 47 with value: 0.4621975107390897.
# [I 2021-04-15 03:29:21,863] Trial 49 finished with value: 0.45549131852153 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 224, 'filter_len': 6, 'nodes_per_dense': 189, 'dense_dropout_rate': 0.4178543910777627}. Best is trial 47 with value: 0.4621975107390897.
# Number of finished trials: 50
# Training Time: 1:57:54.705181
# Best trial:
#   Value: 0.4621975107390897
#   Params:
#     n_conv_layers: 1
#     filters_per_conv: 247
#     filter_len: 5
#     nodes_per_dense: 189
#     dense_dropout_rate: 0.4745320133621992
# [I 2021-04-15 03:30:26,453] A new study created in memory with name: no-name-630322cc-d20e-49c5-b9f4-1183fcd61324
# Fold: 1
# [I 2021-04-15 03:33:03,349] Trial 0 finished with value: 0.4365246255438563 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 207, 'filter_len': 5, 'nodes_per_dense': 188, 'dense_dropout_rate': 0.4911958047986411}. Best is trial 0 with value: 0.4365246255438563.
# [I 2021-04-15 03:35:29,542] Trial 1 finished with value: 0.40255777073657717 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 144, 'filter_len': 2, 'nodes_per_dense': 74, 'dense_dropout_rate': 0.299953000330224}. Best is trial 0 with value: 0.4365246255438563.
# [I 2021-04-15 03:37:29,475] Trial 2 finished with value: 0.40000795515824195 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 212, 'filter_len': 4, 'nodes_per_dense': 24, 'dense_dropout_rate': 0.21525823972319744}. Best is trial 0 with value: 0.4365246255438563.
# [I 2021-04-15 03:39:06,666] Trial 3 finished with value: 0.36663674548313685 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 80, 'filter_len': 5, 'nodes_per_dense': 239, 'dense_dropout_rate': 0.10995969102013921}. Best is trial 0 with value: 0.4365246255438563.
# [I 2021-04-15 03:41:45,634] Trial 4 finished with value: 0.43211155601962015 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 245, 'filter_len': 3, 'nodes_per_dense': 144, 'dense_dropout_rate': 0.4636513499546925}. Best is trial 0 with value: 0.4365246255438563.
# [I 2021-04-15 03:43:30,723] Trial 5 finished with value: 0.4303081009614054 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 149, 'filter_len': 7, 'nodes_per_dense': 174, 'dense_dropout_rate': 0.2871011438979923}. Best is trial 0 with value: 0.4365246255438563.
# [I 2021-04-15 03:45:27,393] Trial 6 finished with value: 0.42642103231102285 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 142, 'filter_len': 4, 'nodes_per_dense': 126, 'dense_dropout_rate': 0.2463561543122372}. Best is trial 0 with value: 0.4365246255438563.
# [I 2021-04-15 03:47:19,035] Trial 7 finished with value: 0.4054385823965217 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 204, 'filter_len': 4, 'nodes_per_dense': 150, 'dense_dropout_rate': 0.21041961933227804}. Best is trial 0 with value: 0.4365246255438563.
# [I 2021-04-15 03:49:00,048] Trial 8 finished with value: 0.43679421947475855 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 111, 'filter_len': 6, 'nodes_per_dense': 100, 'dense_dropout_rate': 0.2836371911565726}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 03:51:04,081] Trial 9 finished with value: 0.38088326813705226 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 124, 'filter_len': 8, 'nodes_per_dense': 52, 'dense_dropout_rate': 0.3964475491653058}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 03:53:16,392] Trial 10 finished with value: 0.4275698654466565 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 42, 'filter_len': 7, 'nodes_per_dense': 89, 'dense_dropout_rate': 0.37884060421617366}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 03:55:14,627] Trial 11 finished with value: 0.41904766470753857 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 88, 'filter_len': 6, 'nodes_per_dense': 207, 'dense_dropout_rate': 0.47833324054818516}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 03:57:26,472] Trial 12 finished with value: 0.42952683157740523 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 185, 'filter_len': 6, 'nodes_per_dense': 197, 'dense_dropout_rate': 0.3708023892328119}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 03:59:31,942] Trial 13 finished with value: 0.4322172437019719 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 6, 'nodes_per_dense': 109, 'dense_dropout_rate': 0.15354015474775157}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 04:01:10,435] Trial 14 finished with value: 0.41958376568200856 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 99, 'filter_len': 5, 'nodes_per_dense': 250, 'dense_dropout_rate': 0.3408175954234049}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 04:03:08,240] Trial 15 finished with value: 0.43311139762283324 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 178, 'filter_len': 8, 'nodes_per_dense': 175, 'dense_dropout_rate': 0.4323923313544761}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 04:04:27,307] Trial 16 finished with value: 0.40201047876601115 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 45, 'filter_len': 7, 'nodes_per_dense': 221, 'dense_dropout_rate': 0.25875989804526217}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 04:07:31,850] Trial 17 finished with value: 0.4336886681543892 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 229, 'filter_len': 5, 'nodes_per_dense': 33, 'dense_dropout_rate': 0.3246645369970379}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 04:09:21,398] Trial 18 finished with value: 0.4069984313291914 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 114, 'filter_len': 3, 'nodes_per_dense': 104, 'dense_dropout_rate': 0.1696849776140957}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 04:11:24,904] Trial 19 finished with value: 0.410079706709176 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 64, 'filter_len': 6, 'nodes_per_dense': 170, 'dense_dropout_rate': 0.4187238113881042}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 04:13:54,095] Trial 20 finished with value: 0.43084164500345395 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 162, 'filter_len': 7, 'nodes_per_dense': 127, 'dense_dropout_rate': 0.4989363746124555}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 04:16:47,344] Trial 21 finished with value: 0.3876855842668615 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 232, 'filter_len': 5, 'nodes_per_dense': 10, 'dense_dropout_rate': 0.3390699061852477}. Best is trial 8 with value: 0.43679421947475855.
# [I 2021-04-15 04:19:33,244] Trial 22 finished with value: 0.43690123363267064 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 223, 'filter_len': 5, 'nodes_per_dense': 51, 'dense_dropout_rate': 0.331958808935573}. Best is trial 22 with value: 0.43690123363267064.
# [I 2021-04-15 04:21:55,701] Trial 23 finished with value: 0.4390437364232914 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 203, 'filter_len': 4, 'nodes_per_dense': 65, 'dense_dropout_rate': 0.2559791031168289}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:24:43,841] Trial 24 finished with value: 0.42532467574664334 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 189, 'filter_len': 3, 'nodes_per_dense': 64, 'dense_dropout_rate': 0.27216310150638107}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:26:46,592] Trial 25 finished with value: 0.43861742604795506 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 117, 'filter_len': 4, 'nodes_per_dense': 48, 'dense_dropout_rate': 0.22884074127163598}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:29:58,831] Trial 26 finished with value: 0.4158550585480862 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 165, 'filter_len': 4, 'nodes_per_dense': 44, 'dense_dropout_rate': 0.21449709117373672}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:31:56,788] Trial 27 finished with value: 0.2554481068648054 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 222, 'filter_len': 2, 'nodes_per_dense': 11, 'dense_dropout_rate': 0.1776971899120302}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:34:45,271] Trial 28 finished with value: 0.33356591871552965 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 3, 'nodes_per_dense': 75, 'dense_dropout_rate': 0.23578021130358282}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:37:41,914] Trial 29 finished with value: 0.4287136688518648 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 200, 'filter_len': 4, 'nodes_per_dense': 50, 'dense_dropout_rate': 0.31791277828529185}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:39:59,593] Trial 30 finished with value: 0.43218556915302464 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 130, 'filter_len': 4, 'nodes_per_dense': 30, 'dense_dropout_rate': 0.12355851923995755}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:41:47,177] Trial 31 finished with value: 0.43869828747816886 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 109, 'filter_len': 5, 'nodes_per_dense': 92, 'dense_dropout_rate': 0.27750445100490584}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:43:46,610] Trial 32 finished with value: 0.43491908969458937 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 69, 'filter_len': 5, 'nodes_per_dense': 81, 'dense_dropout_rate': 0.3001885579304296}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:46:08,584] Trial 33 finished with value: 0.42669344366147827 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 102, 'filter_len': 4, 'nodes_per_dense': 62, 'dense_dropout_rate': 0.23748655475520217}. Best is trial 23 with value: 0.4390437364232914.
# [I 2021-04-15 04:48:20,760] Trial 34 finished with value: 0.44085844365970894 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 131, 'filter_len': 5, 'nodes_per_dense': 66, 'dense_dropout_rate': 0.25934365767277834}. Best is trial 34 with value: 0.44085844365970894.
# [I 2021-04-15 04:51:03,308] Trial 35 finished with value: 0.40720374882095844 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 138, 'filter_len': 2, 'nodes_per_dense': 89, 'dense_dropout_rate': 0.21455180163799417}. Best is trial 34 with value: 0.44085844365970894.
# [I 2021-04-15 04:52:56,254] Trial 36 finished with value: 0.40401351823088466 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 156, 'filter_len': 4, 'nodes_per_dense': 60, 'dense_dropout_rate': 0.2646578011215086}. Best is trial 34 with value: 0.44085844365970894.
# [I 2021-04-15 04:54:38,680] Trial 37 finished with value: 0.4225385146501261 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 123, 'filter_len': 3, 'nodes_per_dense': 113, 'dense_dropout_rate': 0.18117319979437238}. Best is trial 34 with value: 0.44085844365970894.
# [I 2021-04-15 04:58:22,981] Trial 38 finished with value: 0.4417463068837888 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 87, 'filter_len': 5, 'nodes_per_dense': 21, 'dense_dropout_rate': 0.29250555379245435}. Best is trial 38 with value: 0.4417463068837888.
# [I 2021-04-15 05:00:22,672] Trial 39 finished with value: 0.3966329807360303 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 87, 'filter_len': 5, 'nodes_per_dense': 19, 'dense_dropout_rate': 0.3022427443318085}. Best is trial 38 with value: 0.4417463068837888.
# [I 2021-04-15 05:03:56,367] Trial 40 finished with value: 0.44074640550370414 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 74, 'filter_len': 5, 'nodes_per_dense': 35, 'dense_dropout_rate': 0.36162116397058724}. Best is trial 38 with value: 0.4417463068837888.
# [I 2021-04-15 05:07:10,261] Trial 41 finished with value: 0.4407309790959865 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 60, 'filter_len': 5, 'nodes_per_dense': 35, 'dense_dropout_rate': 0.3652818696989247}. Best is trial 38 with value: 0.4417463068837888.
# [I 2021-04-15 05:10:22,983] Trial 42 finished with value: 0.43425953897208147 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 56, 'filter_len': 6, 'nodes_per_dense': 30, 'dense_dropout_rate': 0.3514780571940561}. Best is trial 38 with value: 0.4417463068837888.
# [I 2021-04-15 05:13:02,207] Trial 43 finished with value: 0.43405936566067416 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 68, 'filter_len': 5, 'nodes_per_dense': 39, 'dense_dropout_rate': 0.3647502482369616}. Best is trial 38 with value: 0.4417463068837888.
# [I 2021-04-15 05:16:25,082] Trial 44 finished with value: 0.41893734250191556 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 35, 'filter_len': 6, 'nodes_per_dense': 18, 'dense_dropout_rate': 0.4034119895386125}. Best is trial 38 with value: 0.4417463068837888.
# [I 2021-04-15 05:18:21,271] Trial 45 finished with value: 0.44268189465549507 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 84, 'filter_len': 5, 'nodes_per_dense': 65, 'dense_dropout_rate': 0.3105099867714865}. Best is trial 45 with value: 0.44268189465549507.
# [I 2021-04-15 05:21:35,791] Trial 46 finished with value: 0.41550610161623347 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 80, 'filter_len': 5, 'nodes_per_dense': 10, 'dense_dropout_rate': 0.38745672712765916}. Best is trial 45 with value: 0.44268189465549507.
# [I 2021-04-15 05:23:44,088] Trial 47 finished with value: 0.4314155831644303 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 57, 'filter_len': 6, 'nodes_per_dense': 23, 'dense_dropout_rate': 0.3167289320347306}. Best is trial 45 with value: 0.44268189465549507.
# [I 2021-04-15 05:26:46,529] Trial 48 finished with value: 0.43841509362282827 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 76, 'filter_len': 5, 'nodes_per_dense': 75, 'dense_dropout_rate': 0.44686738433705586}. Best is trial 45 with value: 0.44268189465549507.
# [I 2021-04-15 05:29:15,024] Trial 49 finished with value: 0.43821805893073745 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 91, 'filter_len': 6, 'nodes_per_dense': 38, 'dense_dropout_rate': 0.353012849461638}. Best is trial 45 with value: 0.44268189465549507.
# Number of finished trials: 50
# Training Time: 1:58:48.569923
# Best trial:
#   Value: 0.44268189465549507
#   Params:
#     n_conv_layers: 1
#     filters_per_conv: 84
#     filter_len: 5
#     nodes_per_dense: 65
#     dense_dropout_rate: 0.3105099867714865
# [I 2021-04-15 05:30:02,564] A new study created in memory with name: no-name-28dae6ea-d272-4e2a-a290-4b59d85af101
# Fold: 2
# [I 2021-04-15 05:32:10,961] Trial 0 finished with value: 0.44903488613564335 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 207, 'filter_len': 5, 'nodes_per_dense': 188, 'dense_dropout_rate': 0.4911958047986411}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:34:23,802] Trial 1 finished with value: 0.4150866678973581 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 144, 'filter_len': 2, 'nodes_per_dense': 74, 'dense_dropout_rate': 0.299953000330224}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:36:06,041] Trial 2 finished with value: 0.39538688976378117 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 212, 'filter_len': 4, 'nodes_per_dense': 24, 'dense_dropout_rate': 0.21525823972319744}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:37:28,162] Trial 3 finished with value: 0.3736320850496502 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 80, 'filter_len': 5, 'nodes_per_dense': 239, 'dense_dropout_rate': 0.10995969102013921}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:39:41,483] Trial 4 finished with value: 0.4387955524492112 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 245, 'filter_len': 3, 'nodes_per_dense': 144, 'dense_dropout_rate': 0.4636513499546925}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:41:06,354] Trial 5 finished with value: 0.4283938050631845 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 149, 'filter_len': 7, 'nodes_per_dense': 174, 'dense_dropout_rate': 0.2871011438979923}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:42:35,121] Trial 6 finished with value: 0.4308443739807526 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 142, 'filter_len': 4, 'nodes_per_dense': 126, 'dense_dropout_rate': 0.2463561543122372}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:44:17,806] Trial 7 finished with value: 0.4053726948565838 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 204, 'filter_len': 4, 'nodes_per_dense': 150, 'dense_dropout_rate': 0.21041961933227804}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:45:45,628] Trial 8 finished with value: 0.43578390839053976 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 111, 'filter_len': 6, 'nodes_per_dense': 100, 'dense_dropout_rate': 0.2836371911565726}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:47:32,436] Trial 9 finished with value: 0.38738888490928586 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 124, 'filter_len': 8, 'nodes_per_dense': 52, 'dense_dropout_rate': 0.3964475491653058}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:49:39,142] Trial 10 finished with value: 0.44009762624359716 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 204, 'filter_len': 6, 'nodes_per_dense': 235, 'dense_dropout_rate': 0.4565491145264152}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:51:48,929] Trial 11 finished with value: 0.4418062515499998 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 196, 'filter_len': 6, 'nodes_per_dense': 246, 'dense_dropout_rate': 0.48781997587377574}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:54:08,035] Trial 12 finished with value: 0.44361664628154873 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 244, 'filter_len': 6, 'nodes_per_dense': 203, 'dense_dropout_rate': 0.38613618789170856}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:56:00,698] Trial 13 finished with value: 0.43710286184913294 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 8, 'nodes_per_dense': 195, 'dense_dropout_rate': 0.3786190240795454}. Best is trial 0 with value: 0.44903488613564335.
# [I 2021-04-15 05:58:20,046] Trial 14 finished with value: 0.45529713127602606 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 234, 'filter_len': 5, 'nodes_per_dense': 199, 'dense_dropout_rate': 0.3921994016619403}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:00:17,746] Trial 15 finished with value: 0.4476807052942231 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 174, 'filter_len': 5, 'nodes_per_dense': 202, 'dense_dropout_rate': 0.42543184805941964}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:02:41,340] Trial 16 finished with value: 0.436450554412251 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 236, 'filter_len': 3, 'nodes_per_dense': 175, 'dense_dropout_rate': 0.3524119931484054}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:04:54,241] Trial 17 finished with value: 0.44690317063845963 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 176, 'filter_len': 5, 'nodes_per_dense': 219, 'dense_dropout_rate': 0.4872974049831808}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:06:52,324] Trial 18 finished with value: 0.4428692932388138 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 223, 'filter_len': 7, 'nodes_per_dense': 168, 'dense_dropout_rate': 0.3441010208742732}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:10:00,931] Trial 19 finished with value: 0.4415068099065877 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 179, 'filter_len': 3, 'nodes_per_dense': 110, 'dense_dropout_rate': 0.43144883448692106}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:11:54,059] Trial 20 finished with value: 0.3999979223712579 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 44, 'filter_len': 7, 'nodes_per_dense': 220, 'dense_dropout_rate': 0.49940071190886876}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:13:49,584] Trial 21 finished with value: 0.4516269277707073 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 176, 'filter_len': 5, 'nodes_per_dense': 196, 'dense_dropout_rate': 0.4265835052398782}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:16:12,747] Trial 22 finished with value: 0.4424992982773068 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 226, 'filter_len': 4, 'nodes_per_dense': 256, 'dense_dropout_rate': 0.425416753001318}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:18:27,446] Trial 23 finished with value: 0.45512581411329756 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 189, 'filter_len': 5, 'nodes_per_dense': 186, 'dense_dropout_rate': 0.45595645472667967}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:20:06,076] Trial 24 finished with value: 0.4460206422980413 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 163, 'filter_len': 5, 'nodes_per_dense': 153, 'dense_dropout_rate': 0.3387952331120977}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:22:04,801] Trial 25 finished with value: 0.4411303979554604 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 192, 'filter_len': 4, 'nodes_per_dense': 212, 'dense_dropout_rate': 0.45079080641559055}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:23:57,731] Trial 26 finished with value: 0.4473190524684715 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 184, 'filter_len': 6, 'nodes_per_dense': 182, 'dense_dropout_rate': 0.39876175797168806}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:25:51,289] Trial 27 finished with value: 0.4414670994654938 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 160, 'filter_len': 5, 'nodes_per_dense': 225, 'dense_dropout_rate': 0.32787999394896394}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:28:35,083] Trial 28 finished with value: 0.4499149615773998 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 4, 'nodes_per_dense': 127, 'dense_dropout_rate': 0.40154865334292095}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:30:32,963] Trial 29 finished with value: 0.45012120395544997 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 220, 'filter_len': 5, 'nodes_per_dense': 190, 'dense_dropout_rate': 0.46986648079526727}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:32:08,453] Trial 30 finished with value: 0.4352182267977426 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 117, 'filter_len': 6, 'nodes_per_dense': 163, 'dense_dropout_rate': 0.3630040870852772}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:34:33,145] Trial 31 finished with value: 0.4454494793096594 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 219, 'filter_len': 5, 'nodes_per_dense': 181, 'dense_dropout_rate': 0.46949105578560446}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:36:49,885] Trial 32 finished with value: 0.44191291440510894 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 231, 'filter_len': 5, 'nodes_per_dense': 191, 'dense_dropout_rate': 0.4343616419859805}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:39:14,134] Trial 33 finished with value: 0.4500237510600207 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 211, 'filter_len': 5, 'nodes_per_dense': 203, 'dense_dropout_rate': 0.498718871204515}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:41:32,085] Trial 34 finished with value: 0.4414499212638291 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 193, 'filter_len': 4, 'nodes_per_dense': 230, 'dense_dropout_rate': 0.41713729837856495}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:43:19,923] Trial 35 finished with value: 0.4435723779261605 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 160, 'filter_len': 6, 'nodes_per_dense': 249, 'dense_dropout_rate': 0.4751309917049696}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:45:38,250] Trial 36 finished with value: 0.43267437409110443 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 242, 'filter_len': 3, 'nodes_per_dense': 158, 'dense_dropout_rate': 0.4466400899363812}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:47:08,970] Trial 37 finished with value: 0.43933260682953473 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 216, 'filter_len': 5, 'nodes_per_dense': 188, 'dense_dropout_rate': 0.1160607111805636}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:48:54,943] Trial 38 finished with value: 0.4453890463664404 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 202, 'filter_len': 7, 'nodes_per_dense': 141, 'dense_dropout_rate': 0.3169042209751132}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:50:49,173] Trial 39 finished with value: 0.4126368614689654 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 136, 'filter_len': 4, 'nodes_per_dense': 205, 'dense_dropout_rate': 0.37216546276700047}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:52:56,853] Trial 40 finished with value: 0.4366278994256675 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 97, 'filter_len': 4, 'nodes_per_dense': 170, 'dense_dropout_rate': 0.4095140505961865}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:54:58,980] Trial 41 finished with value: 0.45390126390462393 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 208, 'filter_len': 5, 'nodes_per_dense': 212, 'dense_dropout_rate': 0.4996480423626717}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:57:14,890] Trial 42 finished with value: 0.443113742388881 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 188, 'filter_len': 5, 'nodes_per_dense': 214, 'dense_dropout_rate': 0.47056672518219655}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 06:59:17,825] Trial 43 finished with value: 0.44607208088471817 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 208, 'filter_len': 5, 'nodes_per_dense': 235, 'dense_dropout_rate': 0.4470113958714803}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 07:01:07,652] Trial 44 finished with value: 0.4456312942031337 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 168, 'filter_len': 6, 'nodes_per_dense': 192, 'dense_dropout_rate': 0.4820682512317227}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 07:03:11,484] Trial 45 finished with value: 0.43682265616250254 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 151, 'filter_len': 6, 'nodes_per_dense': 180, 'dense_dropout_rate': 0.4978478747768319}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 07:05:41,563] Trial 46 finished with value: 0.4178976039217542 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 200, 'filter_len': 4, 'nodes_per_dense': 19, 'dense_dropout_rate': 0.2620480951288311}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 07:08:15,823] Trial 47 finished with value: 0.45247307017665256 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 254, 'filter_len': 5, 'nodes_per_dense': 242, 'dense_dropout_rate': 0.4543202246082589}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 07:10:35,784] Trial 48 finished with value: 0.44601020840273903 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 253, 'filter_len': 6, 'nodes_per_dense': 244, 'dense_dropout_rate': 0.4390171525233065}. Best is trial 14 with value: 0.45529713127602606.
# [I 2021-04-15 07:12:37,934] Trial 49 finished with value: 0.44484613123945477 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 232, 'filter_len': 5, 'nodes_per_dense': 254, 'dense_dropout_rate': 0.3840443603738494}. Best is trial 14 with value: 0.45529713127602606.
# Number of finished trials: 50
# Training Time: 1:42:35.370351
# Best trial:
#   Value: 0.45529713127602606
#   Params:
#     n_conv_layers: 1
#     filters_per_conv: 234
#     filter_len: 5
#     nodes_per_dense: 199
#     dense_dropout_rate: 0.3921994016619403
# [I 2021-04-15 07:13:33,595] A new study created in memory with name: no-name-8836cc46-e465-4c68-b7a7-53b52112143d
# Fold: 3
# [I 2021-04-15 07:16:13,574] Trial 0 finished with value: 0.44074765298570134 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 207, 'filter_len': 5, 'nodes_per_dense': 188, 'dense_dropout_rate': 0.4911958047986411}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:18:28,746] Trial 1 finished with value: 0.40972100958996505 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 144, 'filter_len': 2, 'nodes_per_dense': 74, 'dense_dropout_rate': 0.299953000330224}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:20:29,424] Trial 2 finished with value: 0.40312926735520316 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 212, 'filter_len': 4, 'nodes_per_dense': 24, 'dense_dropout_rate': 0.21525823972319744}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:22:08,676] Trial 3 finished with value: 0.36542284948120624 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 80, 'filter_len': 5, 'nodes_per_dense': 239, 'dense_dropout_rate': 0.10995969102013921}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:25:04,887] Trial 4 finished with value: 0.43136676111840977 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 245, 'filter_len': 3, 'nodes_per_dense': 144, 'dense_dropout_rate': 0.4636513499546925}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:26:52,601] Trial 5 finished with value: 0.42450002282447735 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 149, 'filter_len': 7, 'nodes_per_dense': 174, 'dense_dropout_rate': 0.2871011438979923}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:28:47,735] Trial 6 finished with value: 0.42522281855992305 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 142, 'filter_len': 4, 'nodes_per_dense': 126, 'dense_dropout_rate': 0.2463561543122372}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:30:49,574] Trial 7 finished with value: 0.39990867471797653 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 204, 'filter_len': 4, 'nodes_per_dense': 150, 'dense_dropout_rate': 0.21041961933227804}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:32:28,199] Trial 8 finished with value: 0.43577705721824656 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 111, 'filter_len': 6, 'nodes_per_dense': 100, 'dense_dropout_rate': 0.2836371911565726}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:34:36,595] Trial 9 finished with value: 0.3821374643015167 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 124, 'filter_len': 8, 'nodes_per_dense': 52, 'dense_dropout_rate': 0.3964475491653058}. Best is trial 0 with value: 0.44074765298570134.
# [I 2021-04-15 07:37:01,535] Trial 10 finished with value: 0.4408620595533576 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 204, 'filter_len': 6, 'nodes_per_dense': 235, 'dense_dropout_rate': 0.4565491145264152}. Best is trial 10 with value: 0.4408620595533576.
# [I 2021-04-15 07:39:05,787] Trial 11 finished with value: 0.4389286337654548 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 196, 'filter_len': 6, 'nodes_per_dense': 246, 'dense_dropout_rate': 0.48781997587377574}. Best is trial 10 with value: 0.4408620595533576.
# [I 2021-04-15 07:41:40,250] Trial 12 finished with value: 0.43587908578271417 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 244, 'filter_len': 6, 'nodes_per_dense': 203, 'dense_dropout_rate': 0.39698283393990524}. Best is trial 10 with value: 0.4408620595533576.
# [I 2021-04-15 07:43:41,471] Trial 13 finished with value: 0.4237934326641847 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 179, 'filter_len': 8, 'nodes_per_dense': 207, 'dense_dropout_rate': 0.4162922708264427}. Best is trial 10 with value: 0.4408620595533576.
# [I 2021-04-15 07:46:31,862] Trial 14 finished with value: 0.4484756572624392 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 5, 'nodes_per_dense': 199, 'dense_dropout_rate': 0.4868940539545979}. Best is trial 14 with value: 0.4484756572624392.
# [I 2021-04-15 07:48:57,989] Trial 15 finished with value: 0.43951365229512385 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 254, 'filter_len': 7, 'nodes_per_dense': 226, 'dense_dropout_rate': 0.44068369774892036}. Best is trial 14 with value: 0.4484756572624392.
# [I 2021-04-15 07:50:56,798] Trial 16 finished with value: 0.42928916695317054 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 236, 'filter_len': 7, 'nodes_per_dense': 256, 'dense_dropout_rate': 0.3498228690982537}. Best is trial 14 with value: 0.4484756572624392.
# [I 2021-04-15 07:53:05,462] Trial 17 finished with value: 0.4298574965978773 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 173, 'filter_len': 5, 'nodes_per_dense': 170, 'dense_dropout_rate': 0.36085278197404297}. Best is trial 14 with value: 0.4484756572624392.
# [I 2021-04-15 07:56:26,313] Trial 18 finished with value: 0.4346209763841287 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 229, 'filter_len': 3, 'nodes_per_dense': 224, 'dense_dropout_rate': 0.4994616386600682}. Best is trial 14 with value: 0.4484756572624392.
# [I 2021-04-15 07:58:04,624] Trial 19 finished with value: 0.39309064122541315 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 177, 'filter_len': 6, 'nodes_per_dense': 208, 'dense_dropout_rate': 0.12499900756573668}. Best is trial 14 with value: 0.4484756572624392.
# [I 2021-04-15 07:59:45,571] Trial 20 finished with value: 0.40242376188487194 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 46, 'filter_len': 7, 'nodes_per_dense': 251, 'dense_dropout_rate': 0.3495118303768986}. Best is trial 14 with value: 0.4484756572624392.
# ...
# [I 2021-04-15 09:10:26,869] Trial 44 finished with value: 0.4443804270773958 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 201, 'filter_len': 5, 'nodes_per_dense': 108, 'dense_dropout_rate': 0.4597033661875157}. Best is trial 34 with value: 0.4541174394425864.
# [I 2021-04-15 09:13:43,439] Trial 45 finished with value: 0.43318827483773215 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 211, 'filter_len': 6, 'nodes_per_dense': 59, 'dense_dropout_rate': 0.4806777172609109}. Best is trial 34 with value: 0.4541174394425864.
# [I 2021-04-15 09:16:42,462] Trial 46 finished with value: 0.44845362961391855 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 243, 'filter_len': 5, 'nodes_per_dense': 136, 'dense_dropout_rate': 0.43806580256639926}. Best is trial 34 with value: 0.4541174394425864.
# [I 2021-04-15 09:19:49,377] Trial 47 finished with value: 0.4027240431891185 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 108, 'filter_len': 4, 'nodes_per_dense': 12, 'dense_dropout_rate': 0.41216378265917974}. Best is trial 34 with value: 0.4541174394425864.
# [I 2021-04-15 09:22:15,995] Trial 48 finished with value: 0.432848539269996 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 179, 'filter_len': 6, 'nodes_per_dense': 148, 'dense_dropout_rate': 0.49944800575154386}. Best is trial 34 with value: 0.4541174394425864.
# [I 2021-04-15 09:24:40,924] Trial 49 finished with value: 0.4453201641400649 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 171, 'filter_len': 5, 'nodes_per_dense': 119, 'dense_dropout_rate': 0.4501414437849063}. Best is trial 34 with value: 0.4541174394425864.
# Number of finished trials: 50
# Training Time: 2:11:07.327629
# Best trial:
#   Value: 0.4541174394425864
#   Params:
#     n_conv_layers: 1
#     filters_per_conv: 206
#     filter_len: 5
#     nodes_per_dense: 96
#     dense_dropout_rate: 0.45092888550767346
# [I 2021-04-15 09:25:47,145] A new study created in memory with name: no-name-7c17828d-58fd-4764-9f71-9a08a3c5ce87
# Fold: 4
# [I 2021-04-15 09:28:47,997] Trial 0 finished with value: 0.43256173710614976 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 207, 'filter_len': 5, 'nodes_per_dense': 188, 'dense_dropout_rate': 0.4911958047986411}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:31:28,416] Trial 1 finished with value: 0.39510313266124397 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 144, 'filter_len': 2, 'nodes_per_dense': 74, 'dense_dropout_rate': 0.299953000330224}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:33:29,855] Trial 2 finished with value: 0.3966064952870835 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 212, 'filter_len': 4, 'nodes_per_dense': 24, 'dense_dropout_rate': 0.21525823972319744}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:35:06,816] Trial 3 finished with value: 0.3653490436967165 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 80, 'filter_len': 5, 'nodes_per_dense': 239, 'dense_dropout_rate': 0.10995969102013921}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:37:52,016] Trial 4 finished with value: 0.4259265449557093 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 245, 'filter_len': 3, 'nodes_per_dense': 144, 'dense_dropout_rate': 0.4636513499546925}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:39:40,042] Trial 5 finished with value: 0.41636653597773465 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 149, 'filter_len': 7, 'nodes_per_dense': 174, 'dense_dropout_rate': 0.2871011438979923}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:41:44,751] Trial 6 finished with value: 0.41665409385185265 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 142, 'filter_len': 4, 'nodes_per_dense': 126, 'dense_dropout_rate': 0.2463561543122372}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:43:40,748] Trial 7 finished with value: 0.40641464293992635 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 204, 'filter_len': 4, 'nodes_per_dense': 150, 'dense_dropout_rate': 0.21041961933227804}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:45:33,888] Trial 8 finished with value: 0.42414893915545077 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 111, 'filter_len': 6, 'nodes_per_dense': 100, 'dense_dropout_rate': 0.2836371911565726}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:47:37,288] Trial 9 finished with value: 0.37388952038283113 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 124, 'filter_len': 8, 'nodes_per_dense': 52, 'dense_dropout_rate': 0.3964475491653058}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:49:48,137] Trial 10 finished with value: 0.4280385673026979 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 204, 'filter_len': 6, 'nodes_per_dense': 235, 'dense_dropout_rate': 0.4565491145264152}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:52:07,120] Trial 11 finished with value: 0.4287358772635962 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 196, 'filter_len': 6, 'nodes_per_dense': 246, 'dense_dropout_rate': 0.48781997587377574}. Best is trial 0 with value: 0.43256173710614976.
# [I 2021-04-15 09:54:25,362] Trial 12 finished with value: 0.43811996519660956 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 244, 'filter_len': 6, 'nodes_per_dense': 203, 'dense_dropout_rate': 0.38613618789170856}. Best is trial 12 with value: 0.43811996519660956.
# [I 2021-04-15 09:56:28,270] Trial 13 finished with value: 0.4270153544080048 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 8, 'nodes_per_dense': 195, 'dense_dropout_rate': 0.3786190240795454}. Best is trial 12 with value: 0.43811996519660956.
# [I 2021-04-15 09:59:07,830] Trial 14 finished with value: 0.4443168426543961 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 234, 'filter_len': 5, 'nodes_per_dense': 199, 'dense_dropout_rate': 0.3921994016619403}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:01:08,540] Trial 15 finished with value: 0.42599861111055237 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 240, 'filter_len': 7, 'nodes_per_dense': 212, 'dense_dropout_rate': 0.37611985806482306}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:03:17,711] Trial 16 finished with value: 0.3870999409723658 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 47, 'filter_len': 7, 'nodes_per_dense': 219, 'dense_dropout_rate': 0.4154493383160913}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:05:23,663] Trial 17 finished with value: 0.4282375668582071 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 173, 'filter_len': 5, 'nodes_per_dense': 166, 'dense_dropout_rate': 0.33764002696368245}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:09:24,107] Trial 18 finished with value: 0.43081992618811515 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 232, 'filter_len': 3, 'nodes_per_dense': 115, 'dense_dropout_rate': 0.33944542315460474}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:11:38,376] Trial 19 finished with value: 0.43575844932219326 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 175, 'filter_len': 6, 'nodes_per_dense': 203, 'dense_dropout_rate': 0.42811370977795316}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:13:54,707] Trial 20 finished with value: 0.42994520328139496 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 7, 'nodes_per_dense': 251, 'dense_dropout_rate': 0.34600013680849084}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:16:07,708] Trial 21 finished with value: 0.43064641082139143 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 174, 'filter_len': 6, 'nodes_per_dense': 199, 'dense_dropout_rate': 0.4268282644647138}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:18:34,590] Trial 22 finished with value: 0.43788082051365695 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 227, 'filter_len': 6, 'nodes_per_dense': 217, 'dense_dropout_rate': 0.44342093545470485}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:21:08,417] Trial 23 finished with value: 0.43110404881136877 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 225, 'filter_len': 5, 'nodes_per_dense': 224, 'dense_dropout_rate': 0.450969303061221}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:23:31,675] Trial 24 finished with value: 0.4355276639927993 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 227, 'filter_len': 6, 'nodes_per_dense': 180, 'dense_dropout_rate': 0.363827116283476}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:26:34,405] Trial 25 finished with value: 0.43013656042435233 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 249, 'filter_len': 4, 'nodes_per_dense': 256, 'dense_dropout_rate': 0.4004424485310346}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:28:52,429] Trial 26 finished with value: 0.4290620291144863 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 185, 'filter_len': 5, 'nodes_per_dense': 169, 'dense_dropout_rate': 0.3246129836561507}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:31:28,492] Trial 27 finished with value: 0.43728875176851983 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 221, 'filter_len': 7, 'nodes_per_dense': 157, 'dense_dropout_rate': 0.49203928860002166}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:33:55,804] Trial 28 finished with value: 0.42686405297338476 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 256, 'filter_len': 6, 'nodes_per_dense': 227, 'dense_dropout_rate': 0.4363370815599912}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:36:55,569] Trial 29 finished with value: 0.433421059379212 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 235, 'filter_len': 5, 'nodes_per_dense': 187, 'dense_dropout_rate': 0.48014791987553174}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:39:26,934] Trial 30 finished with value: 0.4339175097897886 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 196, 'filter_len': 5, 'nodes_per_dense': 209, 'dense_dropout_rate': 0.37736356058500464}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:41:41,104] Trial 31 finished with value: 0.4379750222684488 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 220, 'filter_len': 7, 'nodes_per_dense': 150, 'dense_dropout_rate': 0.49663542289187046}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:44:02,071] Trial 32 finished with value: 0.4262156940593579 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 216, 'filter_len': 8, 'nodes_per_dense': 186, 'dense_dropout_rate': 0.49556232828676877}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:46:22,804] Trial 33 finished with value: 0.4377738037900264 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 240, 'filter_len': 7, 'nodes_per_dense': 139, 'dense_dropout_rate': 0.4023455301191534}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:49:09,052] Trial 34 finished with value: 0.4430840400783234 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 211, 'filter_len': 6, 'nodes_per_dense': 121, 'dense_dropout_rate': 0.45631568986213455}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:51:39,917] Trial 35 finished with value: 0.44422193439846785 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 211, 'filter_len': 7, 'nodes_per_dense': 87, 'dense_dropout_rate': 0.47450461367455266}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:54:13,889] Trial 36 finished with value: 0.36708766860731545 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 189, 'filter_len': 6, 'nodes_per_dense': 80, 'dense_dropout_rate': 0.4612674301549189}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:56:04,939] Trial 37 finished with value: 0.41144179133467385 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 153, 'filter_len': 3, 'nodes_per_dense': 92, 'dense_dropout_rate': 0.1160607111805636}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 10:59:11,509] Trial 38 finished with value: 0.43409738396375824 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 206, 'filter_len': 4, 'nodes_per_dense': 57, 'dense_dropout_rate': 0.3140220556806827}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 11:01:46,084] Trial 39 finished with value: 0.38273423094032155 and parameters: {'n_conv_layers': 2, 'filters_per_conv': 163, 'filter_len': 8, 'nodes_per_dense': 122, 'dense_dropout_rate': 0.4739035978788813}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 11:05:09,127] Trial 40 finished with value: 0.39758782921537944 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 247, 'filter_len': 5, 'nodes_per_dense': 19, 'dense_dropout_rate': 0.26333798159290267}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 11:08:11,448] Trial 41 finished with value: 0.4393528772129084 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 214, 'filter_len': 7, 'nodes_per_dense': 98, 'dense_dropout_rate': 0.49967543983510326}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 11:10:46,292] Trial 42 finished with value: 0.43593141042716377 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 212, 'filter_len': 7, 'nodes_per_dense': 105, 'dense_dropout_rate': 0.47057516626474205}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 11:13:22,420] Trial 43 finished with value: 0.43750545405012475 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 194, 'filter_len': 7, 'nodes_per_dense': 59, 'dense_dropout_rate': 0.4087783788025412}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 11:16:21,723] Trial 44 finished with value: 0.44378390168430215 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 210, 'filter_len': 6, 'nodes_per_dense': 76, 'dense_dropout_rate': 0.4457829226586008}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 11:18:52,785] Trial 45 finished with value: 0.4268022958548663 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 205, 'filter_len': 8, 'nodes_per_dense': 77, 'dense_dropout_rate': 0.4481806023863687}. Best is trial 14 with value: 0.4443168426543961.
# [I 2021-04-15 11:22:36,271] Trial 46 finished with value: 0.4462495516238076 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 180, 'filter_len': 6, 'nodes_per_dense': 41, 'dense_dropout_rate': 0.49784588587786344}. Best is trial 46 with value: 0.4462495516238076.
# [I 2021-04-15 11:25:30,125] Trial 47 finished with value: 0.4393505527074636 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 133, 'filter_len': 6, 'nodes_per_dense': 45, 'dense_dropout_rate': 0.42306036830792393}. Best is trial 46 with value: 0.4462495516238076.
# [I 2021-04-15 11:29:17,278] Trial 48 finished with value: 0.4424891631954038 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 177, 'filter_len': 6, 'nodes_per_dense': 38, 'dense_dropout_rate': 0.4672883072632951}. Best is trial 46 with value: 0.4462495516238076.
# [I 2021-04-15 11:33:13,151] Trial 49 finished with value: 0.4155452577785123 and parameters: {'n_conv_layers': 1, 'filters_per_conv': 157, 'filter_len': 4, 'nodes_per_dense': 30, 'dense_dropout_rate': 0.47913442687410523}. Best is trial 46 with value: 0.4462495516238076.
# Number of finished trials: 50
# Training Time: 2:07:26.004911
# Best trial:
#   Value: 0.4462495516238076
#   Params:
#     n_conv_layers: 1
#     filters_per_conv: 180
#     filter_len: 6
#     nodes_per_dense: 41
#     dense_dropout_rate: 0.49784588587786344

# %%
cnn_predictive_performance = get_predictive_performance(lgbm_prediction_list +
                                                        cnn_prediction_list)

# %%
plot_pearson_heatmap(cnn_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752343963753)>

# %%
plot_relative_performance(cnn_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/stat_boxplot.py:86: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752364960333)>

# %% [markdown]
# ## Outputs

# %%
all_prediction_list = (single_test_prediction_list + 
                       combined_test_prediction_list +
                       top_combined_test_prediction_list +
                       cnn_prediction_list +
                       lgbm_prediction_list)
all_predictive_performance = get_predictive_performance(all_prediction_list)

# %%
plot_pearson_heatmap(all_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752341966965)>

# %%
plot_relative_performance(all_predictive_performance)
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/stat_boxplot.py:86: FutureWarning:
#
# is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (8752344890561)>

# %% [markdown]
# **Remember to download the predictive performance dataframe, as the local store is not permanent**

# %%
pd.options.display.max_rows = 999
all_predictive_performance
# Out:
#                            model_name  ... relative_performance
# 0                      All train data  ...             0.957130
# 1                      All train data  ...             0.996588
# 2                      All train data  ...             0.959176
# 3                      All train data  ...             0.956135
# 4                      All train data  ...             1.000000
# 5                      All train data  ...             0.948894
# 6                      All train data  ...             0.923818
# 7                      All train data  ...             0.958663
# 8                      All train data  ...             0.956384
# 9                      All train data  ...             0.979112
# 10                     All train data  ...             0.969203
# 11                     All train data  ...             0.988461
# 12                     All train data  ...             0.984620
# 13                     All train data  ...             0.980041
# 14                     All train data  ...             0.988861
# 15                     All train data  ...             0.988239
# 16                     All train data  ...             0.999019
# 17                     All train data  ...             0.972925
# 18                     All train data  ...             0.995692
# 19                     All train data  ...             0.927959
# 20                     All train data  ...             0.897395
# 21       All train data + CNN + TPE50  ...             0.977943
# 22       All train data + CNN + TPE50  ...             0.927796
# 23       All train data + CNN + TPE50  ...             1.000000
# 24       All train data + CNN + TPE50  ...             0.960246
# 25       All train data + CNN + TPE50  ...             0.938930
# 26       All train data + CNN + TPE50  ...             1.000000
# 27       All train data + CNN + TPE50  ...             1.000000
# 28       All train data + CNN + TPE50  ...             1.000000
# 29       All train data + CNN + TPE50  ...             0.925526
# 30       All train data + CNN + TPE50  ...             0.932579
# 31       All train data + CNN + TPE50  ...             0.895111
# 32       All train data + CNN + TPE50  ...             0.968993
# 33       All train data + CNN + TPE50  ...             0.976676
# 34       All train data + CNN + TPE50  ...             0.981584
# 35       All train data + CNN + TPE50  ...             0.989217
# 36       All train data + CNN + TPE50  ...             0.984630
# 37       All train data + CNN + TPE50  ...             0.992601
# 38       All train data + CNN + TPE50  ...             0.954616
# 39       All train data + CNN + TPE50  ...             0.917033
# 40       All train data + CNN + TPE50  ...             1.000000
# 41       All train data + CNN + TPE50  ...             1.000000
# 42      All train data + LGBM + TPE50  ...             0.995239
# 43      All train data + LGBM + TPE50  ...             1.000000
# 44      All train data + LGBM + TPE50  ...             0.987047
# 45      All train data + LGBM + TPE50  ...             1.000000
# 46      All train data + LGBM + TPE50  ...             0.926808
# 47      All train data + LGBM + TPE50  ...             0.956157
# 48      All train data + LGBM + TPE50  ...             0.987317
# 49      All train data + LGBM + TPE50  ...             0.957201
# 50      All train data + LGBM + TPE50  ...             1.000000
# 51      All train data + LGBM + TPE50  ...             1.000000
# 52      All train data + LGBM + TPE50  ...             0.968680
# 53      All train data + LGBM + TPE50  ...             1.000000
# 54      All train data + LGBM + TPE50  ...             1.000000
# 55      All train data + LGBM + TPE50  ...             1.000000
# 56      All train data + LGBM + TPE50  ...             0.999609
# 57      All train data + LGBM + TPE50  ...             0.997617
# 58      All train data + LGBM + TPE50  ...             1.000000
# 59      All train data + LGBM + TPE50  ...             1.000000
# 60      All train data + LGBM + TPE50  ...             1.000000
# 61      All train data + LGBM + TPE50  ...             0.964416
# 62      All train data + LGBM + TPE50  ...             0.909989
# 63                   Doench2014_human  ...             0.774730
# 64                   Doench2014_human  ...             0.405425
# 65                   Doench2014_human  ...             0.755303
# 66                   Doench2014_human  ...             0.704851
# 67                   Doench2014_human  ...             0.588976
# 68                   Doench2014_human  ...             0.807651
# 69                   Doench2014_human  ...             0.593073
# 70                   Doench2014_human  ...             0.571712
# 71                   Doench2014_human  ...             0.505809
# 72                   Doench2014_human  ...             0.711709
# 73                   Doench2014_human  ...             0.723539
# 74                   Doench2014_human  ...             0.729088
# 75                   Doench2014_human  ...             0.680897
# 76                   Doench2014_human  ...             0.472054
# 77                   Doench2014_human  ...             0.701089
# 78                   Doench2014_human  ...             0.719062
# 79                   Doench2014_human  ...             0.803604
# 80                   Doench2014_human  ...             0.603691
# 81                   Doench2014_human  ...             0.521425
# 82                   Doench2014_human  ...             0.556637
# 83                   Doench2014_human  ...             0.544871
# 84   Doench2014_human + Kim2019_train  ...             0.989219
# 85   Doench2014_human + Kim2019_train  ...             0.963089
# 86   Doench2014_human + Kim2019_train  ...             0.930770
# 87   Doench2014_human + Kim2019_train  ...             0.874819
# 88   Doench2014_human + Kim2019_train  ...             0.924734
# 89   Doench2014_human + Kim2019_train  ...             0.927814
# 90   Doench2014_human + Kim2019_train  ...             0.910619
# 91   Doench2014_human + Kim2019_train  ...             0.959503
# 92   Doench2014_human + Kim2019_train  ...             0.950317
# 93   Doench2014_human + Kim2019_train  ...             0.908258
# 94   Doench2014_human + Kim2019_train  ...             0.942121
# 95   Doench2014_human + Kim2019_train  ...             0.989458
# 96   Doench2014_human + Kim2019_train  ...             0.983250
# 97   Doench2014_human + Kim2019_train  ...             0.992906
# 98   Doench2014_human + Kim2019_train  ...             0.998765
# 99   Doench2014_human + Kim2019_train  ...             0.996449
# 100  Doench2014_human + Kim2019_train  ...             0.912962
# 101  Doench2014_human + Kim2019_train  ...             0.910968
# 102  Doench2014_human + Kim2019_train  ...             0.945739
# 103  Doench2014_human + Kim2019_train  ...             0.899406
# 104  Doench2014_human + Kim2019_train  ...             0.923629
# 105                  Doench2014_mouse  ...             0.643727
# 106                  Doench2014_mouse  ...             0.784158
# 107                  Doench2014_mouse  ...             0.769150
# 108                  Doench2014_mouse  ...             0.906568
# 109                  Doench2014_mouse  ...             0.797237
# 110                  Doench2014_mouse  ...             0.684116
# 111                  Doench2014_mouse  ...             0.555611
# 112                  Doench2014_mouse  ...             0.627314
# 113                  Doench2014_mouse  ...             0.766038
# 114                  Doench2014_mouse  ...             0.631730
# 115                  Doench2014_mouse  ...             0.589582
# 116                  Doench2014_mouse  ...             0.617572
# 117                  Doench2014_mouse  ...             0.652883
# 118                  Doench2014_mouse  ...             0.688884
# 119                  Doench2014_mouse  ...             0.697936
# 120                  Doench2014_mouse  ...             0.564972
# 121                  Doench2014_mouse  ...             0.629887
# 122                  Doench2014_mouse  ...             0.731766
# 123                  Doench2014_mouse  ...             0.722838
# 124                  Doench2014_mouse  ...             0.624734
# 125                  Doench2014_mouse  ...             0.413378
# 126  Doench2014_mouse + Kim2019_train  ...             0.979919
# 127  Doench2014_mouse + Kim2019_train  ...             0.968690
# 128  Doench2014_mouse + Kim2019_train  ...             0.928851
# 129  Doench2014_mouse + Kim2019_train  ...             0.939652
# 130  Doench2014_mouse + Kim2019_train  ...             0.980875
# 131  Doench2014_mouse + Kim2019_train  ...             0.933232
# 132  Doench2014_mouse + Kim2019_train  ...             0.917563
# 133  Doench2014_mouse + Kim2019_train  ...             0.926139
# 134  Doench2014_mouse + Kim2019_train  ...             0.951599
# 135  Doench2014_mouse + Kim2019_train  ...             0.868639
# 136  Doench2014_mouse + Kim2019_train  ...             0.952246
# 137  Doench2014_mouse + Kim2019_train  ...             0.998268
# 138  Doench2014_mouse + Kim2019_train  ...             0.986830
# 139  Doench2014_mouse + Kim2019_train  ...             0.984210
# 140  Doench2014_mouse + Kim2019_train  ...             0.994154
# 141  Doench2014_mouse + Kim2019_train  ...             0.993087
# 142  Doench2014_mouse + Kim2019_train  ...             0.950754
# 143  Doench2014_mouse + Kim2019_train  ...             0.959060
# 144  Doench2014_mouse + Kim2019_train  ...             0.962443
# 145  Doench2014_mouse + Kim2019_train  ...             0.934054
# 146  Doench2014_mouse + Kim2019_train  ...             0.925978
# 147                        Doench2016  ...             0.825182
# 148                        Doench2016  ...             0.638161
# 149                        Doench2016  ...             0.697802
# 150                        Doench2016  ...             0.966570
# 151                        Doench2016  ...             0.687201
# 152                        Doench2016  ...             0.775749
# 153                        Doench2016  ...             0.871633
# 154                        Doench2016  ...             0.738194
# 155                        Doench2016  ...             0.766793
# 156                        Doench2016  ...             0.956809
# 157                        Doench2016  ...             0.621511
# 158                        Doench2016  ...             0.736482
# 159                        Doench2016  ...             0.704462
# 160                        Doench2016  ...             0.636466
# 161                        Doench2016  ...             0.727584
# 162                        Doench2016  ...             0.672135
# 163                        Doench2016  ...             0.656203
# 164                        Doench2016  ...             0.606399
# 165                        Doench2016  ...             0.600004
# 166                        Doench2016  ...             0.697111
# 167                        Doench2016  ...             0.553793
# 168        Doench2016 + Kim2019_train  ...             0.982010
# 169        Doench2016 + Kim2019_train  ...             0.952044
# 170        Doench2016 + Kim2019_train  ...             0.948963
# 171        Doench2016 + Kim2019_train  ...             0.925118
# 172        Doench2016 + Kim2019_train  ...             0.919677
# 173        Doench2016 + Kim2019_train  ...             0.956620
# 174        Doench2016 + Kim2019_train  ...             0.954666
# 175        Doench2016 + Kim2019_train  ...             0.942060
# 176        Doench2016 + Kim2019_train  ...             0.959886
# 177        Doench2016 + Kim2019_train  ...             0.952911
# 178        Doench2016 + Kim2019_train  ...             1.000000
# 179        Doench2016 + Kim2019_train  ...             0.986815
# 180        Doench2016 + Kim2019_train  ...             0.982161
# 181        Doench2016 + Kim2019_train  ...             0.984297
# 182        Doench2016 + Kim2019_train  ...             0.991827
# 183        Doench2016 + Kim2019_train  ...             0.991549
# 184        Doench2016 + Kim2019_train  ...             0.924837
# 185        Doench2016 + Kim2019_train  ...             0.928697
# 186        Doench2016 + Kim2019_train  ...             0.954949
# 187        Doench2016 + Kim2019_train  ...             0.907222
# 188        Doench2016 + Kim2019_train  ...             0.895183
# 189                     Kim2019_train  ...             0.995977
# 190                     Kim2019_train  ...             0.974156
# 191                     Kim2019_train  ...             0.952934
# 192                     Kim2019_train  ...             0.805744
# 193                     Kim2019_train  ...             0.972817
# 194                     Kim2019_train  ...             0.924039
# 195                     Kim2019_train  ...             0.931188
# 196                     Kim2019_train  ...             0.943814
# 197                     Kim2019_train  ...             0.936188
# 198                     Kim2019_train  ...             0.880270
# 199                     Kim2019_train  ...             0.929500
# 200                     Kim2019_train  ...             0.991933
# 201                     Kim2019_train  ...             0.988036
# 202                     Kim2019_train  ...             0.992601
# 203                     Kim2019_train  ...             1.000000
# 204                     Kim2019_train  ...             1.000000
# 205                     Kim2019_train  ...             0.864647
# 206                     Kim2019_train  ...             0.910933
# 207                     Kim2019_train  ...             0.983627
# 208                     Kim2019_train  ...             0.922772
# 209                     Kim2019_train  ...             0.918676
# 210                          Wang2014  ...             0.722860
# 211                          Wang2014  ...             0.614844
# 212                          Wang2014  ...             0.723747
# 213                          Wang2014  ...             0.595519
# 214                          Wang2014  ...             0.623699
# 215                          Wang2014  ...             0.727636
# 216                          Wang2014  ...             0.550724
# 217                          Wang2014  ...             0.564108
# 218                          Wang2014  ...             0.639308
# 219                          Wang2014  ...             0.761727
# 220                          Wang2014  ...             0.649192
# 221                          Wang2014  ...             0.625256
# 222                          Wang2014  ...             0.694520
# 223                          Wang2014  ...             0.685784
# 224                          Wang2014  ...             0.682208
# 225                          Wang2014  ...             0.703468
# 226                          Wang2014  ...             0.701541
# 227                          Wang2014  ...             0.855381
# 228                          Wang2014  ...             0.930702
# 229                          Wang2014  ...             0.769331
# 230                          Wang2014  ...             0.840693
# 231          Wang2014 + Kim2019_train  ...             1.000000
# 232          Wang2014 + Kim2019_train  ...             0.952246
# 233          Wang2014 + Kim2019_train  ...             0.954262
# 234          Wang2014 + Kim2019_train  ...             0.842898
# 235          Wang2014 + Kim2019_train  ...             0.928260
# 236          Wang2014 + Kim2019_train  ...             0.928480
# 237          Wang2014 + Kim2019_train  ...             0.919627
# 238          Wang2014 + Kim2019_train  ...             0.960633
# 239          Wang2014 + Kim2019_train  ...             0.959350
# 240          Wang2014 + Kim2019_train  ...             0.895076
# 241          Wang2014 + Kim2019_train  ...             0.950061
# 242          Wang2014 + Kim2019_train  ...             0.989618
# 243          Wang2014 + Kim2019_train  ...             0.993001
# 244          Wang2014 + Kim2019_train  ...             0.992284
# 245          Wang2014 + Kim2019_train  ...             0.996814
# 246          Wang2014 + Kim2019_train  ...             0.995263
# 247          Wang2014 + Kim2019_train  ...             0.965355
# 248          Wang2014 + Kim2019_train  ...             0.968658
# 249          Wang2014 + Kim2019_train  ...             0.980296
# 250          Wang2014 + Kim2019_train  ...             0.933273
# 251          Wang2014 + Kim2019_train  ...             0.947826
#
# [252 rows x 5 columns]

# %%
all_predictive_performance.to_csv('Build_Seq_Models_CV_Results.csv', index=False)
